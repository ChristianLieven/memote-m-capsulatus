# %%
import cameo
from cobra import Model, Reaction, Metabolite
from cobra.io import read_sbml_model
from cobra.io import save_json_model
from cameo.flux_analysis.simulation import pfba
import cobra.test
import os
from Functions_Modules.curation_tools import *

# %%
relative_directory = os.getcwd()
filename = relative_directory + '/Reconstructions/MethylococcusModel8.xml'
model = cameo.load_model(filename)

# %% [markdown]
# Final 'clean-up' step. I'll get rid of all MNXR or MNXM tagged reactions or metabolites.

# %%
for met in list(model.metabolites):
    if met.id.startswith('MNXM'):
        print(met.id, met.reactions)
        model.remove_reactions(met.reactions)
        if met.id in model.metabolites:
            met.remove_from_model('destructive')
# Out:
# ('MNXM21342_c', frozenset([<Reaction MNXR85991_c at 0x10dacb750>, <Reaction MNXM21342_out at 0x10dc36f50>]))
# ('MNXM5285_c', frozenset([<Reaction MNXM5285_out at 0x10dc36fd0>]))
# ('MNXM7549_c', frozenset([<Reaction MNXM7549_out at 0x10dc3f090>]))
# ('MNXM4463_c', frozenset([<Reaction MNXM4463_out at 0x10dc3f110>]))
# ('MNXM6386_c', frozenset([<Reaction MNXM6386_out at 0x10dc3f190>]))
# ('MNXM2142_c', frozenset([<Reaction MNXM2142_out at 0x10dc3f590>]))
# ('MNXM7231_c', frozenset([<Reaction MNXM7231_out at 0x10dc3f810>, <Reaction MNXR68614_c at 0x10dad7e50>]))
# ('MNXM95609_c', frozenset([<Reaction MNXM95609_out at 0x10dc492d0>]))
# ('MNXM96150_c', frozenset([<Reaction MNXM96150_out at 0x10dc499d0>, <Reaction MNXR85732_c at 0x10dae9950>]))
# ('MNXM92688_c', frozenset([<Reaction MNXM92688_out at 0x10dc53290>, <Reaction MNXR59223_c at 0x10db0e0d0>]))
# ('MNXM1740_c', frozenset([<Reaction MNXM1740_out at 0x10dc53390>, <Reaction MNXR73718_c at 0x10db0e310>]))
# ('MNXM2120_c', frozenset([<Reaction MNXM2120_out at 0x10dc53410>, <Reaction MNXR16109_c at 0x10db0e6d0>]))
# ('MNXM3563_c', frozenset([<Reaction MNXM3563_out at 0x10dc53490>]))
# ('MNXM1682_c', frozenset([<Reaction MNXM1682_out at 0x10dc53690>]))
# ('MNXM5588_c', frozenset([<Reaction MNXR85034_c at 0x10db33e10>, <Reaction MNXM5588_out at 0x10dc53910>]))
# ('MNXM12690_c', frozenset([<Reaction MNXM12690_out at 0x10dc53b10>, <Reaction MNXR59619_c at 0x10db392d0>]))
# ('MNXM1293_c', frozenset([<Reaction MNXM1293_out at 0x10dc53b90>]))
# ('MNXM5412_c', frozenset([<Reaction MNXM5412_out at 0x10dc53c10>, <Reaction MNXR74776_c at 0x10db39450>]))
# ('MNXM5511_c', frozenset([<Reaction MNXM5511_out at 0x10dc53c90>]))
# ('MNXM3034_c', frozenset([<Reaction MNXM3034_out at 0x10dc53d90>, <Reaction MNXR6705_c at 0x10db39bd0>]))
# ('MNXM6152_c', frozenset([<Reaction MNXM6152_out at 0x10dc53e10>]))
# ('MNXM6177_c', frozenset([<Reaction MNXM6177_out at 0x10dc53e90>]))
# ('MNXM1651_c', frozenset([<Reaction MNXR7517_c at 0x10db40110>, <Reaction MNXM1651_out at 0x10dc53f10>]))
# ('MNXM1731_c', frozenset([<Reaction MNXM1731_out at 0x10dc53f90>]))
# ('MNXM4764_c', frozenset([<Reaction MNXR15981_c at 0x10db40590>, <Reaction MNXM4764_out at 0x10dc5d050>]))
# ('MNXM2354_c', frozenset([<Reaction MNXM2354_out at 0x10dc5d0d0>]))
# ('MNXM2709_c', frozenset([<Reaction MNXR17615_c at 0x10db40710>, <Reaction MNXM2709_out at 0x10dc5d150>]))
# ('MNXM114652_c', frozenset([<Reaction MNXM114652_out at 0x10dc5d1d0>]))
# ('MNXM1289_c', frozenset([<Reaction MNXR5404_c at 0x10db46290>, <Reaction MNXM1289_out at 0x10dc5d250>, <Reaction MNXR35657_c at 0x10db46110>]))

# %%
MNXR_rxns = [rxn for rxn in model.reactions if rxn.id.startswith('MNXR')]
model.remove_reactions(MNXR_rxns)

# %% [markdown]
# Check for funktioning FBA after import:

# %%
model.objective.variables
# Out:
# {0 <= BIOMASS_REACTION_reverse_42726 <= 0, 0.1 <= BIOMASS_REACTION <= 1000.0}

# %%
solution = show_uptake_excretion(model,model.reactions.get_by_id('BIOMASS_REACTION'))
# Out:
# so4_in 0.0273340396411
# pi_in 0.0742559453479
# o2_in 27.6123082969
# co2_out 9.73776818209
# h2o_out 29.7680791941
# ACP_out 3.15502832193e-17
# hco3_out 2.37162203479
# h2o2_out 0.00108844802029
# co_out 4.66477722983e-06
# 2dhp_out 0.045398233971
# 5prdmbz_out 0.000155492574328
# EX_no3_e -1.3686798476
# ch4_in 18.405
# Fe_in 0.000951614554886
# BIOMASS_REACTION 0.155492574328

# %%
model.remove_reactions([model.reactions.ATPM])

# %% [markdown]
# Demand and Sink reactions in the models are tagged either with an \_out or \_in suffix, while they should bear the prefix EX\_. Transporters in the model have not been predicted properly. So far the only Transport-RXN that have been added denote simple diffusion of a few basic compounds. Transporter information will be inferred from Merlin's curated TCDB selection or from http://www.membranetransport.org/ output.

# %%
demands = [rxn for rxn in model.reactions if rxn.id.endswith('_out')]

for rxn in demands:
    if rxn.reactants != []:
        new_id = rxn.reactants[0].id
        descriptive_name = rxn.reactants[0].name
                
        try: 
            model.reactions.get_by_id('EX_' + new_id)
        except KeyError:
            rxn.name = '{} exchange'.format(descriptive_name)
            rxn.id = 'EX_' + new_id
            print rxn
# Out:
# EX_fdp_c: fdp_c -->
# EX_g3p_c: g3p_c -->
# EX_dhap_c: dhap_c -->
# EX_h_c: h_c -->
# EX_nadh_c: nadh_c -->
# EX_acald_c: acald_c -->
# EX_etoh_c: etoh_c -->
# EX_nad_c: nad_c -->
# EX_pyr_c: pyr_c -->
# EX_thmpp_c: thmpp_c -->
# EX_co2_c: co2_c -->
# EX_2ahethmpp_c: 2ahethmpp_c -->
# EX_dhlpro_c: dhlpro_c -->
# EX_accoa_c: accoa_c -->
# EX_coa_c: coa_c -->
# EX_atp_c: atp_c -->
# EX_adp_c: adp_c -->
# EX_pep_c: pep_c -->
# EX_h2o_c: h2o_c -->
# EX_2pg_c: 2pg_c -->
# EX_3pg_c: 3pg_c -->
# EX_13dpg_c: 13dpg_c -->
# EX_pi_c: pi_c -->
# EX_f6p_c: f6p_c -->
# EX_g6p_A_c: g6p_A_c -->
# EX_g1p_c: g1p_c -->
# EX_g6p_c: g6p_c -->
# EX_glc_bD_c: glc_bD_c -->
# EX_Glc_aD_c: Glc_aD_c -->
# EX_ppi_c: ppi_c -->
# EX_amp_c: amp_c -->
# EX_ac_c: ac_c -->
# EX_fum_c: fum_c -->
# EX_succ_c: succ_c -->
# EX_akg_c: akg_c -->
# EX_succoa_c: succoa_c -->
# EX_icit_c: icit_c -->
# EX_mal__L_c: mal__L_c -->
# EX_acon_C_c: acon_C_c -->
# EX_cit_c: cit_c -->
# EX_oaa_c: oaa_c -->
# EX_2ddg6p_c: 2ddg6p_c -->
# EX_prpp_c: prpp_c -->
# EX_r5p_c: r5p_c -->
# EX_s7p_c: s7p_c -->
# EX_xu5p_D_c: xu5p_D_c -->
# EX_ru5p_D_c: ru5p_D_c -->
# EX_e4p_c: e4p_c -->
# EX_nadph_c: nadph_c -->
# EX_6pgc_c: 6pgc_c -->
# EX_nadp_c: nadp_c -->
# EX_6pgl_c: 6pgl_c -->
# EX_r1p_c: r1p_c -->
# EX_actp_c: actp_c -->
# EX_fald_c: fald_c -->
# EX_ah6p__D_c: ah6p__D_c -->
# EX_udpg_c: udpg_c -->
# EX_utp_c: utp_c -->
# EX_udpglcur_c: udpglcur_c -->
# EX_man6p_c: man6p_c -->
# EX_man1p_c: man1p_c -->
# EX_gdpddman_c: gdpddman_c -->
# EX_gdpfuc_c: gdpfuc_c -->
# EX_gdpmann_c: gdpmann_c -->
# EX_gtp_c: gtp_c -->
# EX_glyald_c: glyald_c -->
# EX_f1p_c: f1p_c -->
# EX_tagdp_D_c: tagdp_D_c -->
# EX_tag6p_D_c: tag6p_D_c -->
# EX_cdp_c: cdp_c -->
# EX_ctp_c: ctp_c -->
# EX_udp_c: udp_c -->
# EX_idp_c: idp_c -->
# EX_itp_c: itp_c -->
# EX_sucr_c: sucr_c -->
# EX_fru_c: fru_c -->
# EX_glc__D_c: glc__D_c -->
# EX_udpgal_c: udpgal_c -->
# EX_gal_c: gal_c -->
# EX_toctd2eACP_c: toctd2eACP_c -->
# EX_ocdcaACP_c: ocdcaACP_c -->
# EX_3hoctaACP_c: 3hoctaACP_c -->
# EX_3ooctdACP_c: 3ooctdACP_c -->
# EX_ACP_c: ACP_c -->
# EX_malACP_c: malACP_c -->
# EX_palmACP_c: palmACP_c -->
# EX_acACP_c: acACP_c -->
# EX_actACP_c: actACP_c -->
# EX_3opalmACP_c: 3opalmACP_c -->
# EX_myrsACP_c: myrsACP_c -->
# EX_3omrsACP_c: 3omrsACP_c -->
# EX_ddcaACP_c: ddcaACP_c -->
# EX_3oddecACP_c: 3oddecACP_c -->
# EX_dcaACP_c: dcaACP_c -->
# EX_3odecACP_c: 3odecACP_c -->
# EX_ocACP_c: ocACP_c -->
# EX_3ooctACP_c: 3ooctACP_c -->
# EX_hexACP_c: hexACP_c -->
# EX_3ohexACP_c: 3ohexACP_c -->
# EX_butACP_c: butACP_c -->
# EX_tpalm2eACP_c: tpalm2eACP_c -->
# EX_3hpalmACP_c: 3hpalmACP_c -->
# EX_tmrs2eACP_c: tmrs2eACP_c -->
# EX_3hmrsACP_c: 3hmrsACP_c -->
# EX_tddec2eACP_c: tddec2eACP_c -->
# EX_3hddecACP_c: 3hddecACP_c -->
# EX_tdec2eACP_c: tdec2eACP_c -->
# EX_3hdecACP_c: 3hdecACP_c -->
# EX_toct2eACP_c: toct2eACP_c -->
# EX_3hoctACP_c: 3hoctACP_c -->
# EX_thex2eACP_c: thex2eACP_c -->
# EX_3hhexACP_c: 3hhexACP_c -->
# EX_but2eACP_c: but2eACP_c -->
# EX_3hbutACP_c: 3hbutACP_c -->
# EX_malcoa_c: malcoa_c -->
# EX_hco3_c: hco3_c -->
# EX_btnCCP_c: btnCCP_c -->
# EX_cbtnCCP_c: cbtnCCP_c -->
# EX_pmtcoa_c: pmtcoa_c -->
# EX_hdca_c: hdca_c -->
# EX_dsmsterol_c: dsmsterol_c -->
# EX_chsterol_c: chsterol_c -->
# EX_ddsmsterol_c: ddsmsterol_c -->
# EX_7dhchsterol_c: 7dhchsterol_c -->
# EX_chlstol_c: chlstol_c -->
# EX_lthstrl_c: lthstrl_c -->
# EX_zymst_c: zymst_c -->
# EX_zymstnl_c: zymstnl_c -->
# EX_44mzym_c: 44mzym_c -->
# EX_for_c: for_c -->
# EX_mergtrol_c: mergtrol_c -->
# EX_o2_c: o2_c -->
# EX_lanost_c: lanost_c -->
# EX_ahcys_c: ahcys_c -->
# EX_amet_c: amet_c -->
# EX_2omph_c: 2omph_c -->
# EX_2ohph_c: 2ohph_c -->
# EX_2oph_c: 2oph_c -->
# EX_3ophb_c: 3ophb_c -->
# EX_q8_im: q8_im -->
# EX_4hbz_c: 4hbz_c -->
# EX_chor_c: chor_c -->
# EX_octdp_c: octdp_c -->
# EX_phyQ_c: phyQ_c -->
# EX_dmtphllqne_c: dmtphllqne_c -->
# EX_2ombz_c: 2ombz_c -->
# EX_2ommb_c: 2ommb_c -->
# EX_trdrd_c: trdrd_c -->
# EX_gdp_c: gdp_c -->
# EX_trdox_c: trdox_c -->
# EX_dgdp_c: dgdp_c -->
# EX_gln__L_c: gln__L_c -->
# EX_pram_c: pram_c -->
# EX_glu__L_c: glu__L_c -->
# EX_gar_c: gar_c -->
# EX_gly_c: gly_c -->
# EX_fgam_c: fgam_c -->
# EX_thf_c: thf_c -->
# EX_10fthf_c: 10fthf_c -->
# EX_fpram_c: fpram_c -->
# EX_air_c: air_c -->
# EX_aicar_c: aicar_c -->
# EX_fprica_c: fprica_c -->
# EX_25aics_c: 25aics_c -->
# EX_asp__L_c: asp__L_c -->
# EX_5aizc_c: 5aizc_c -->
# EX_dna_c: dna_c -->
# EX_datp_c: datp_c -->
# EX_dadp_c: dadp_c -->
# EX_dcamp_c: dcamp_c -->
# EX_imp_c: imp_c -->
# EX_adn_c: adn_c -->
# EX_ade_c: ade_c -->
# EX_damp_c: damp_c -->
# EX_dad_2_c: dad_2_c -->
# EX_ins_c: ins_c -->
# EX_xmp_c: xmp_c -->
# EX_gmp_c: gmp_c -->
# EX_nh3_c: nh3_c -->
# EX_hxan_c: hxan_c -->
# EX_gsn_c: gsn_c -->
# EX_xan_c: xan_c -->
# EX_xtsn_c: xtsn_c -->
# EX_gua_c: gua_c -->
# EX_ppgpp_c: ppgpp_c -->
# EX_gdptp_c: gdptp_c -->
# EX_dgmp_c: dgmp_c -->
# EX_dgtp_c: dgtp_c -->
# EX_dgsn_c: dgsn_c -->
# EX_ap4a_c: ap4a_c -->
# EX_so4_c: so4_c -->
# EX_aps_c: aps_c -->
# EX_paps_c: paps_c -->
# EX_xtp_c: xtp_c -->
# EX_adprib_c: adprib_c -->
# EX_didp_c: didp_c -->
# EX_ditp_c: ditp_c -->
# EX_dimp_c: dimp_c -->
# EX_C04051_c: C04051_c -->
# EX_5caiz_c: 5caiz_c -->
# EX_dudp_c: dudp_c -->
# EX_ump_c: ump_c -->
# EX_cbp_c: cbp_c -->
# EX_cbasp_c: cbasp_c -->
# EX_dhor_S_c: dhor_S_c -->
# EX_orot_c: orot_c -->
# EX_orot5p_c: orot5p_c -->
# EX_ura_c: ura_c -->
# EX_uri_c: uri_c -->
# EX_cmp_c: cmp_c -->
# EX_cytd_c: cytd_c -->
# EX_csn_c: csn_c -->
# EX_dcdp_c: dcdp_c -->
# EX_dctp_c: dctp_c -->
# EX_dutp_c: dutp_c -->
# EX_dcmp_c: dcmp_c -->
# EX_dcyt_c: dcyt_c -->
# EX_dump_c: dump_c -->
# EX_duri_c: duri_c -->
# EX_2dr1p_c: 2dr1p_c -->
# EX_mlthf_c: mlthf_c -->
# EX_dtmp_c: dtmp_c -->
# EX_dhf_c: dhf_c -->
# EX_dttp_c: dttp_c -->
# EX_dtdp_c: dtdp_c -->
# EX_thymd_c: thymd_c -->
# EX_thym_c: thym_c -->
# EX_5mcsn_c: 5mcsn_c -->
# EX_asn__L_c: asn__L_c -->
# EX_h2o2_c: h2o2_c -->
# EX_argsuc_c: argsuc_c -->
# EX_citr__L_c: citr__L_c -->
# EX_arg__L_c: arg__L_c -->
# EX_ala__L_c: ala__L_c -->
# EX_glx_c: glx_c -->
# EX_sucsal_c: sucsal_c -->
# EX_gam6p_c: gam6p_c -->
# EX_glyc_R_c: glyc_R_c -->
# EX_ser__L_c: ser__L_c -->
# EX_hpyr_c: hpyr_c -->
# EX_4pasp_c: 4pasp_c -->
# EX_pser__L_c: pser__L_c -->
# EX_3php_c: 3php_c -->
# EX_2obut_c: 2obut_c -->
# EX_thr__L_c: thr__L_c -->
# EX_phom_c: phom_c -->
# EX_aspsa_c: aspsa_c -->
# EX_alpro_c: alpro_c -->
# EX_lpro_c: lpro_c -->
# EX_hom__L_c: hom__L_c -->
# EX_trp__L_c: trp__L_c -->
# EX_3ig3p_c: 3ig3p_c -->
# EX_suchms_c: suchms_c -->
# EX_h2s_c: h2s_c -->
# EX_hcys__L_c: hcys__L_c -->
# EX_2kmb_c: 2kmb_c -->
# EX_12dmpo_c: 12dmpo_c -->
# EX_3mtpa_c: 3mtpa_c -->
# EX_co_c: co_c -->
# EX_2h3kmtp_c: 2h3kmtp_c -->
# EX_5mdru1p_c: 5mdru1p_c -->
# EX_5mdr1p_c: 5mdr1p_c -->
# EX_5mta_c: 5mta_c -->
# EX_5mtr_c: 5mtr_c -->
# EX_spmd_c: spmd_c -->
# EX_ptrc_c: ptrc_c -->
# EX_ametam_c: ametam_c -->
# EX_met__L_c: met__L_c -->
# EX_5mthf_c: 5mthf_c -->
# EX_cyst__L_c: cyst__L_c -->
# EX_5mthglu_c: 5mthglu_c -->
# EX_hpglu_c: hpglu_c -->
# EX_dna5mtc_c: dna5mtc_c -->
# EX_dnac_c: dnac_c -->
# EX_rhcys_c: rhcys_c -->
# EX_cys__L_c: cys__L_c -->
# EX_acser_c: acser_c -->
# EX_tsul_c: tsul_c -->
# EX_so3_c: so3_c -->
# EX_scys__L_c: scys__L_c -->
# EX_Lcyst_c: Lcyst_c -->
# EX_3spyr_c: 3spyr_c -->
# EX_Lcystin_c: Lcystin_c -->
# EX_thcys_c: thcys_c -->
# EX_3sala_c: 3sala_c -->
# EX_3snpyr_c: 3snpyr_c -->
# EX_mercppyr_c: mercppyr_c -->
# EX_3mob_c: 3mob_c -->
# EX_val__L_c: val__L_c -->
# EX_ile__L_c: ile__L_c -->
# EX_3mop_c: 3mop_c -->
# EX_4mop_c: 4mop_c -->
# EX_leu__L_c: leu__L_c -->
# EX_citac_c: citac_c -->
# EX_r3mmal_c: r3mmal_c -->
# EX_3hmop_c: 3hmop_c -->
# EX_23dhmp_c: 23dhmp_c -->
# EX_3c3hmp_c: 3c3hmp_c -->
# EX_2ippm_c: 2ippm_c -->
# EX_3c4mop_c: 3c4mop_c -->
# EX_3c2hmp_c: 3c2hmp_c -->
# EX_23dhmb_c: 23dhmb_c -->
# EX_2ahbut_c: 2ahbut_c -->
# EX_3hmoa_c: 3hmoa_c -->
# EX_alac_S_c: alac_S_c -->
# EX_ugmda_c: ugmda_c -->
# EX_ugmd_c: ugmd_c -->
# EX_alaala_c: alaala_c -->
# EX_23dhdp_c: 23dhdp_c -->
# EX_thdp_c: thdp_c -->
# EX_sl2a6o_c: sl2a6o_c -->
# EX_sl26da_c: sl26da_c -->
# EX_26dap_LL_c: 26dap_LL_c -->
# EX_26dap_M_c: 26dap_M_c -->
# EX_lys__L_c: lys__L_c -->
# EX_hcit_c: hcit_c -->
# EX_uamag_c: uamag_c -->
# EX_lys_D_c: lys_D_c -->
# EX_6a2ohxnt_c: 6a2ohxnt_c -->
# EX_2oxoadp_c: 2oxoadp_c -->
# EX_S_gtrdhdlp_c: S_gtrdhdlp_c -->
# EX_glutcoa_c: glutcoa_c -->
# EX_6apa_c: 6apa_c -->
# EX_acglu_c: acglu_c -->
# EX_acg5p_c: acg5p_c -->
# EX_acg5sa_c: acg5sa_c -->
# EX_acorn_c: acorn_c -->
# EX_orn_c: orn_c -->
# EX_glu5sa_c: glu5sa_c -->
# EX_1pyr5c_c: 1pyr5c_c -->
# EX_pro__L_c: pro__L_c -->
# EX_pepd_c: pepd_c -->
# EX_1p3h5c_c: 1p3h5c_c -->
# EX_4hpro_LT_c: 4hpro_LT_c -->
# EX_e4hglu_c: e4hglu_c -->
# EX_asp_D_c: asp_D_c -->
# EX_agm_c: agm_c -->
# EX_Ncbmpts_c: Ncbmpts_c -->
# EX_glu5p_c: glu5p_c -->
# EX_crtn_c: crtn_c -->
# EX_cspmd_c: cspmd_c -->
# EX_sprm_c: sprm_c -->
# EX_his__L_c: his__L_c -->
# EX_hista_c: hista_c -->
# EX_prbatp_c: prbatp_c -->
# EX_histd_c: histd_c -->
# EX_imacp_c: imacp_c -->
# EX_hisp_c: hisp_c -->
# EX_eig3p_c: eig3p_c -->
# EX_prfp_c: prfp_c -->
# EX_prlp_c: prlp_c -->
# EX_prbamp_c: prbamp_c -->
# EX_34dhoxpeg_c: 34dhoxpeg_c -->
# EX_34dhmald_c: 34dhmald_c -->
# EX_tyr__L_c: tyr__L_c -->
# EX_34hpp_c: 34hpp_c -->
# EX_phaccoa_c: phaccoa_c -->
# EX_pac_c: pac_c -->
# EX_phe__L_c: phe__L_c -->
# EX_phpyr_c: phpyr_c -->
# EX_glu_D_c: glu_D_c -->
# EX_cinnm_c: cinnm_c -->
# EX_cenchddd_c: cenchddd_c -->
# EX_pppn_c: pppn_c -->
# EX_cechddd_c: cechddd_c -->
# EX_indpyr_c: indpyr_c -->
# EX_id3acald_c: id3acald_c -->
# EX_ind3acnl_c: ind3acnl_c -->
# EX_ind3ac_c: ind3ac_c -->
# EX_2dda7p_c: 2dda7p_c -->
# EX_3psme_c: 3psme_c -->
# EX_indole_c: indole_c -->
# EX_2cpr5p_c: 2cpr5p_c -->
# EX_pran_c: pran_c -->
# EX_anth_c: anth_c -->
# EX_pphn_c: pphn_c -->
# EX_Largn_c: Largn_c -->
# EX_skm5p_c: skm5p_c -->
# EX_skm_c: skm_c -->
# EX_3dhsk_c: 3dhsk_c -->
# EX_3dhq_c: 3dhq_c -->
# EX_pnto_R_c: pnto_R_c -->
# EX_ala_B_c: ala_B_c -->
# EX_pant_R_c: pant_R_c -->
# EX_taur_c: taur_c -->
# EX_seln_c: seln_c -->
# EX_selt_c: selt_c -->
# EX_selmeth_c: selmeth_c -->
# EX_trnamet_c: trnamet_c -->
# EX_selcys_c: selcys_c -->
# EX_sel_c: sel_c -->
# EX_adsel_c: adsel_c -->
# EX_selhcys_c: selhcys_c -->
# EX_selcyst_c: selcyst_c -->
# EX_aprop_c: aprop_c -->
# EX_acybut_c: acybut_c -->
# EX_uama_c: uama_c -->
# EX_uamr_c: uamr_c -->
# EX_orn_D_c: orn_D_c -->
# EX_5a2opntn_c: 5a2opntn_c -->
# EX_arg_D_c: arg_D_c -->
# EX_5g2oxpt_c: 5g2oxpt_c -->
# EX_ala_D_c: ala_D_c -->
# EX_gthrd_c: gthrd_c -->
# EX_gthox_c: gthox_c -->
# EX_glucys_c: glucys_c -->
# EX_cgly_c: cgly_c -->
# EX_na15dap_c: na15dap_c -->
# EX_15dap_c: 15dap_c -->
# EX_cellb_c: cellb_c -->
# EX_udpgalur_c: udpgalur_c -->
# EX_adpglc_c: adpglc_c -->
# EX_malt_c: malt_c -->
# EX_tre_c: tre_c -->
# EX_uacgam_c: uacgam_c -->
# EX_acgam1p_c: acgam1p_c -->
# EX_gam1p_c: gam1p_c -->
# EX_uaccg_c: uaccg_c -->
# EX_chtbs_c: chtbs_c -->
# EX_acgam_c: acgam_c -->
# EX_mi3p_D_c: mi3p_D_c -->
# EX_inost_c: inost_c -->
# EX_dtdp4d6dm_c: dtdp4d6dm_c -->
# EX_dtdprmn_c: dtdprmn_c -->
# EX_dtdp4d6dg_c: dtdp4d6dg_c -->
# EX_dtdpglu_c: dtdpglu_c -->
# EX_ckdo_c: ckdo_c -->
# EX_kdo_c: kdo_c -->
# EX_kdo8p_c: kdo8p_c -->
# EX_lipidA_c: lipidA_c -->
# EX_lipidAds_c: lipidAds_c -->
# EX_u23ga_c: u23ga_c -->
# EX_lipidX_c: lipidX_c -->
# EX_gmhep7p_c: gmhep7p_c -->
# EX_gmhep17bp_c: gmhep17bp_c -->
# EX_gmhep1p_c: gmhep1p_c -->
# EX_adphep_DD_c: adphep_DD_c -->
# EX_kdo2lipid4_c: kdo2lipid4_c -->
# EX_kdolipid4_c: kdolipid4_c -->
# EX_ara5p_c: ara5p_c -->
# EX_u3hga_c: u3hga_c -->
# EX_u3aga_c: u3aga_c -->
# EX_udcpdp_c: udcpdp_c -->
# EX_uaaGgla_c: uaaGgla_c -->
# EX_uaGgla_c: uaGgla_c -->
# EX_uGgla_c: uGgla_c -->
# EX_uGgl_c: uGgl_c -->
# EX_uagmda_c: uagmda_c -->
# EX_uaagmda_c: uaagmda_c -->
# EX_acoa_c: acoa_c -->
# EX_glyc1p_c: glyc1p_c -->
# EX_dha_c: dha_c -->
# EX_12dgr_EC_c: 12dgr_EC_c -->
# EX_mi4p_D_c: mi4p_D_c -->
# EX_mi1p__D_c: mi1p__D_c -->
# EX_g3pe_c: g3pe_c -->
# EX_etha_c: etha_c -->
# EX_pgp_EC_c: pgp_EC_c -->
# EX_ptd2meeta_SC_c: ptd2meeta_SC_c -->
# EX_g3pc_c: g3pc_c -->
# EX_chol_c: chol_c -->
# EX_15HPET_c: 15HPET_c -->
# EX_5HPET_c: 5HPET_c -->
# EX_leuktrC4_c: leuktrC4_c -->
# EX_leuktrD4_c: leuktrD4_c -->
# EX_mthgxl_c: mthgxl_c -->
# EX_lgt_S_c: lgt_S_c -->
# EX_lac_D_c: lac_D_c -->
# EX_tol_c: tol_c -->
# EX_4crsol_c: 4crsol_c -->
# EX_fdxrd_c: fdxrd_c -->
# EX_fdxox_c: fdxox_c -->
# EX_bzalc_c: bzalc_c -->
# EX_cl_c: cl_c -->
# EX_4nph_c: 4nph_c -->
# EX_24nph_c: 24nph_c -->
# EX_no2_c: no2_c -->
# EX_catechol_c: catechol_c -->
# EX_phen_c: phen_c -->
# EX_bz_c: bz_c -->
# EX_4h2oglt_c: 4h2oglt_c -->
# EX_glyclt_c: glyclt_c -->
# EX_2pglyc_c: 2pglyc_c -->
# EX_rb15bp_c: rb15bp_c -->
# EX_micit_c: micit_c -->
# EX_2mcacn_c: 2mcacn_c -->
# EX_ppcoa_c: ppcoa_c -->
# EX_ppa_c: ppa_c -->
# EX_ppap_c: ppap_c -->
# EX_fad_c: fad_c -->
# EX_fadh2_c: fadh2_c -->
# EX_actn_R_c: actn_R_c -->
# EX_itacon_c: itacon_c -->
# EX_itaccoa_c: itaccoa_c -->
# EX_methf_c: methf_c -->
# EX_fol_c: fol_c -->
# EX_5fthf_c: 5fthf_c -->
# EX_fmettrna_c: fmettrna_c -->
# EX_mettrna_c: mettrna_c -->
# EX_h2_c: h2_c -->
# EX_focytC_c: focytC_c -->
# EX_meoh_c: meoh_c -->
# EX_ficytC_c: ficytC_c -->
# EX_510mh4mpt_c: 510mh4mpt_c -->
# EX_h4mpt_c: h4mpt_c -->
# EX_510methmpt_c: 510methmpt_c -->
# EX_5fthmpt_c: 5fthmpt_c -->
# EX_formmfr_c: formmfr_c -->
# EX_mfr_c: mfr_c -->
# EX_ch4_c: ch4_c -->
# EX_s17bp_c: s17bp_c -->
# EX_thmmp_c: thmmp_c -->
# EX_dhgly_c: dhgly_c -->
# EX_4mpetz_c: 4mpetz_c -->
# EX_dxyl5p_c: dxyl5p_c -->
# EX_4ahmmp_c: 4ahmmp_c -->
# EX_2mahmp_c: 2mahmp_c -->
# EX_4ampm_c: 4ampm_c -->
# EX_db4p_c: db4p_c -->
# EX_fmn_c: fmn_c -->
# EX_ribflv_c: ribflv_c -->
# EX_25dhpp_c: 25dhpp_c -->
# EX_5apru_c: 5apru_c -->
# EX_5aprbu_c: 5aprbu_c -->
# EX_dmlz_c: dmlz_c -->
# EX_4r5au_c: 4r5au_c -->
# EX_dmbzid_c: dmbzid_c -->
# EX_fmnh2_c: fmnh2_c -->
# EX_phthr_c: phthr_c -->
# EX_4hthr_c: 4hthr_c -->
# EX_ohpb_c: ohpb_c -->
# EX_pdx5p_c: pdx5p_c -->
# EX_iasp_c: iasp_c -->
# EX_quln_c: quln_c -->
# EX_nicrnt_c: nicrnt_c -->
# EX_nicrns_c: nicrns_c -->
# EX_dnad_c: dnad_c -->
# EX_nac_c: nac_c -->
# EX_ncam_c: ncam_c -->
# EX_nmn_c: nmn_c -->
# EX_rnam_c: rnam_c -->
# EX_dpcoa_c: dpcoa_c -->
# EX_pan4p_c: pan4p_c -->
# EX_ptth_c: ptth_c -->
# EX_4ppcys_c: 4ppcys_c -->
# EX_ptcys_c: ptcys_c -->
# EX_4ppan_c: 4ppan_c -->
# EX_2dhp_c: 2dhp_c -->
# EX_apoACP_c: apoACP_c -->
# EX_pap_c: pap_c -->
# EX_btamp_c: btamp_c -->
# EX_btn_c: btn_c -->
# EX_dtbt_c: dtbt_c -->
# EX_dad_5_c: dad_5_c -->
# EX_dann_c: dann_c -->
# EX_8aonn_c: 8aonn_c -->
# EX_amob_c: amob_c -->
# EX_pmcoa_c: pmcoa_c -->
# EX_pimACP_c: pimACP_c -->
# EX_pmeACP_c: pmeACP_c -->
# EX_hgmeACP_c: hgmeACP_c -->
# EX_egmeACP_c: egmeACP_c -->
# EX_gmeACP_c: gmeACP_c -->
# EX_hpmeACP_c: hpmeACP_c -->
# EX_epmeACP_c: epmeACP_c -->
# EX_4adcho_c: 4adcho_c -->
# EX_4abz_c: 4abz_c -->
# EX_thfglu_c: thfglu_c -->
# EX_dhpt_c: dhpt_c -->
# EX_2ahhmd_c: 2ahhmd_c -->
# EX_2ahhmp_c: 2ahhmp_c -->
# EX_dhnpt_c: dhnpt_c -->
# EX_gcald_c: gcald_c -->
# EX_ahdt_c: ahdt_c -->
# EX_ptp_c: ptp_c -->
# EX_pppi_c: pppi_c -->
# EX_6pthp_c: 6pthp_c -->
# EX_cpmp_c: cpmp_c -->
# EX_6ctd_c: 6ctd_c -->
# EX_cdg_c: cdg_c -->
# EX_preq0_c: preq0_c -->
# EX_preq1_c: preq1_c -->
# EX_pppg9_c: pppg9_c -->
# EX_cpppg3_c: cpppg3_c -->
# EX_pheme_c: pheme_c -->
# EX_frdp_c: frdp_c -->
# EX_hemeO_c: hemeO_c -->
# EX_fe2_c: fe2_c -->
# EX_ppp9_c: ppp9_c -->
# EX_uppg3_c: uppg3_c -->
# EX_hmbil_c: hmbil_c -->
# EX_dscl_c: dscl_c -->
# EX_uppg1_c: uppg1_c -->
# EX_cpppg1_c: cpppg1_c -->
# EX_ppbng_c: ppbng_c -->
# EX_5aop_c: 5aop_c -->
# EX_glu1sa_c: glu1sa_c -->
# EX_glutrna_c: glutrna_c -->
# EX_trnaglu_c: trnaglu_c -->
# EX_sheme_c: sheme_c -->
# EX_scl_c: scl_c -->
# EX_copre2_c: copre2_c -->
# EX_copre3_c: copre3_c -->
# EX_copre4_c: copre4_c -->
# EX_copre5_c: copre5_c -->
# EX_pre3a_c: pre3a_c -->
# EX_pre4_c: pre4_c -->
# EX_pre3b_c: pre3b_c -->
# EX_pre5_c: pre5_c -->
# EX_pre8_c: pre8_c -->
# EX_hgbyr_c: hgbyr_c -->
# EX_hgbam_c: hgbam_c -->
# EX_cobya_c: cobya_c -->
# EX_copre8_c: copre8_c -->
# EX_co2dam_c: co2dam_c -->
# EX_co1dam_c: co1dam_c -->
# EX_adcobdam_c: adcobdam_c -->
# EX_adcobhex_c: adcobhex_c -->
# EX_cbi_c: cbi_c -->
# EX_adocbi_c: adocbi_c -->
# EX_adocbip_c: adocbip_c -->
# EX_agdpcbi_c: agdpcbi_c -->
# EX_adocbl_c: adocbl_c -->
# EX_rdmbzi_c: rdmbzi_c -->
# EX_5prdmbz_c: 5prdmbz_c -->
# EX_hemeA__1_c: hemeA__1_c -->
# EX_appl_c: appl_c -->
# EX_applp_c: applp_c -->
# EX_pre6b_c: pre6b_c -->
# EX_copre6_c: copre6_c -->
# EX_codscl5b_c: codscl5b_c -->
# EX_2me4p_c: 2me4p_c -->
# EX_4c2me_c: 4c2me_c -->
# EX_2p4c2me_c: 2p4c2me_c -->
# EX_2mecdp_c: 2mecdp_c -->
# EX_h2mb4p_c: h2mb4p_c -->
# EX_dmpp_c: dmpp_c -->
# EX_ipdp_c: ipdp_c -->
# EX_grdp_c: grdp_c -->
# EX_psqldp_c: psqldp_c -->
# EX_sql_c: sql_c -->
# EX_dplpt_c: dplpt_c -->
# EX_dpterol_c: dpterol_c -->
# EX_ham_c: ham_c -->
# EX_n2_c: n2_c -->
# EX_n2o_c: n2o_c -->
# EX_no_c: no_c -->
# EX_flxr_c: flxr_c -->
# EX_flxso_c: flxso_c -->
# EX_iletrna_c: iletrna_c -->
# EX_trnaile_c: trnaile_c -->
# EX_histrna_c: histrna_c -->
# EX_trnahis_c: trnahis_c -->
# EX_phetrna_c: phetrna_c -->
# EX_trnaphe_c: trnaphe_c -->
# EX_argtrna_c: argtrna_c -->
# EX_trnaarg_c: trnaarg_c -->
# EX_trnacys_c: trnacys_c -->
# EX_cystrna_c: cystrna_c -->
# EX_glytrna_c: glytrna_c -->
# EX_trnagly_c: trnagly_c -->
# EX_trnaasp_c: trnaasp_c -->
# EX_asptrna_c: asptrna_c -->
# EX_sertrna_c: sertrna_c -->
# EX_trnaser_c: trnaser_c -->
# EX_valtrna_c: valtrna_c -->
# EX_trnaval_c: trnaval_c -->
# EX_alatrna_c: alatrna_c -->
# EX_trnaala_c: trnaala_c -->
# EX_lystrna_c: lystrna_c -->
# EX_leutrna_c: leutrna_c -->
# EX_trnaleu_c: trnaleu_c -->
# EX_thrtrna_c: thrtrna_c -->
# EX_trnathr_c: trnathr_c -->
# EX_trptrna_c: trptrna_c -->
# EX_trnatrp_c: trnatrp_c -->
# EX_tyrtrna_c: tyrtrna_c -->
# EX_trnatyr_c: trnatyr_c -->
# EX_protrna_c: protrna_c -->
# EX_trnapro_c: trnapro_c -->
# EX_glntrna_c: glntrna_c -->
# EX_asntrna_c: asntrna_c -->
# EX_sertrna_sec__c: sertrna_sec__c -->
# EX_odecoa_c: odecoa_c -->
# EX_ocdcea_c: ocdcea_c -->
# EX_stcoa_c: stcoa_c -->
# EX_ocdca_c: ocdca_c -->
# EX_3ohodcoa_c: 3ohodcoa_c -->
# EX_3hodcoa_c: 3hodcoa_c -->
# EX_focytb5_c: focytb5_c -->
# EX_ficytb5_c: ficytb5_c -->
# EX_octeACP_c: octeACP_c -->
# EX_glyb_c: glyb_c -->
# EX_dmgly_c: dmgly_c -->
# EX_pqqh2_c: pqqh2_c -->
# EX_pqq_c: pqq_c -->
# EX_trnalys_c: trnalys_c -->
# EX_dolp_c: dolp_c -->
# EX_mser__L_c: mser__L_c -->
# EX_retinal_c: retinal_c -->
# EX_retinol_c: retinol_c -->
# EX_f420_2h2_c: f420_2h2_c -->
# EX_f420_2_c: f420_2_c -->
# EX_q8h2_im: q8h2_im -->
# EX_2mhob_c: 2mhob_c -->
# EX_2mbcoa_c: 2mbcoa_c -->
# EX_bdg2hc_c: bdg2hc_c -->
# EX_2coum_c: 2coum_c -->
# EX_citmcoa__L_c: citmcoa__L_c -->
# EX_na1_c: na1_c -->
# EX_k_c: k_c -->
# EX_mg2_c: mg2_c -->
# EX_ca2_c: ca2_c -->
# EX_ttdca_c_None_: ttdca_c_None_ -->
# EX_ptdca_c_None_: ptdca_c_None_ -->
# EX_hpdca_c_None_: hpdca_c_None_ -->
# EX_ttdcea_c_None_: ttdcea_c_None_ -->
# EX_cpoa2h_c_None_: cpoa2h_c_None_ -->

# %%
model.solve().f
# Out:
# 0.1554925743277103

# %%
exchanges = [rxn for rxn in model.reactions if rxn.id.endswith('_in')]
make_reversible = []
for rxn in exchanges:
    if rxn.products != []:
        new_id = rxn.products[0].id
        descriptive_name = rxn.products[0].name
                
        try: 
            model.reactions.get_by_id('EX_' + new_id)
            make_reversible.append(rxn)
        except KeyError:
            print rxn.id
# Out:
# ch4_in
# glycogen_in
# Fe_in

# %%
rxn = model.reactions.Fe_in
new_id = rxn.products[0].id
descriptive_name = rxn.products[0].name
rxn.id = 'EX_' + new_id
rxn.name = '{} exchange'.format(descriptive_name)

# %%
rxn = model.reactions.glycogen_in
new_id = rxn.products[0].id
descriptive_name = rxn.products[0].name
rxn.id = 'EX_' + new_id
rxn.name = '{} exchange'.format(descriptive_name)

# %%
rxn = model.reactions.ch4_in
new_id = rxn.products[0].id
descriptive_name = rxn.products[0].name
rxn.id = 'EX_' + new_id
rxn.name = '{} exchange'.format(descriptive_name)

# %%
model.solve().f
# Out:
# 0.1554925743277103

# %%
model.remove_reactions(make_reversible[0:2])
make_reversible[2:]
# Out:
# [<Reaction nh3_in at 0x10db46610>,
#  <Reaction na1_in at 0x10db46690>,
#  <Reaction k_in at 0x10db46710>,
#  <Reaction mg2_in at 0x10db46790>,
#  <Reaction ca2_in at 0x10db46810>,
#  <Reaction so4_in at 0x10db46890>,
#  <Reaction cl_in at 0x10db46910>,
#  <Reaction pi_in at 0x10db46990>,
#  <Reaction h_in at 0x10db46a10>,
#  <Reaction h2o_in at 0x10db46a90>,
#  <Reaction co2_in at 0x10db46b10>,
#  <Reaction o2_in at 0x10db46b90>]

# %%
for rxn in make_reversible[2:]:
    rxn.lower_bound = 0
    rxn.upper_bound = 0
    try:
        solution = model.solve()
        print rxn.id,solution.f
    except:
        print rxn.id
    rxn.lower_bound = -1000
    rxn.upper_bound = 1000
# Out:
# nh3_in 0.155492574328
# na1_in 0.22201063896
# k_in 0.22201063896
# mg2_in 0.22201063896
# ca2_in 0.22201063896
# so4_in
# cl_in 0.22201063896
# pi_in
# h_in 0.22201063896
# h2o_in 0.22201063896
# co2_in 0.22201063896
# o2_in

# %%
model.reactions.EX_so4_c.lower_bound = -1000

# %%
model.reactions.EX_pi_c.lower_bound = -1000

# %%
model.reactions.EX_o2_c.lower_bound = -1000

# %%
model.remove_reactions(make_reversible[2:])

# %%
model.solve().f
# Out:
# 0.1554925743277102

# %%
solution = show_uptake_excretion(model,model.reactions.get_by_id('BIOMASS_REACTION'))
# Out:
# EX_co2_c 9.80917347274
# EX_h2o_c 29.839484494
# EX_pi_c -0.0742559453479
# EX_ACP_c 2.23345647532e-17
# EX_hco3_c 2.30021674414
# EX_o2_c -27.6123082969
# EX_trdox_c 4.62223186653e-33
# EX_so4_c -0.0273340396411
# EX_h2o2_c 0.00108844802029
# EX_co_c 4.66477722983e-06
# EX_2dhp_c 0.045398233971
# EX_dhpt_c 8.67361737989e-19
# EX_5prdmbz_c 0.000155492574328
# EX_no3_e -1.3686798476
# EX_ch4_p 18.405
# EX_fe2_p_None_ 0.000951614554886
# BIOMASS_REACTION 0.155492574328

# %%
model.remove_reactions([rxn for rxn in model.reactions if rxn.id.endswith('_out')])

# %% [markdown]
# Fix up those reactions and metabolites that for some reason have a \_None\_ suffix.

# %%
None_reactions = [rxn for rxn in model.reactions if rxn.id.endswith('_None_')]

for rxn in None_reactions:
    print rxn
    rxn.id = rxn.id.replace('_None_','')
    
None_metabolites = [met for met in model.metabolites if met.id.endswith('_None_')]

for met in None_metabolites:
    print met
    met.id = met.id.replace('_None_','')
# Out:
# EX_fe2_p_None_:  --> fe2_p_None_
# EX_ttdca_c_None_: ttdca_c_None_ -->
# EX_ptdca_c_None_: ptdca_c_None_ -->
# EX_hpdca_c_None_: hpdca_c_None_ -->
# EX_ttdcea_c_None_: ttdcea_c_None_ -->
# EX_cpoa2h_c_None_: cpoa2h_c_None_ -->
# ttdca_c_None_
# ptdca_c_None_
# ttdcea_c_None_
# hpdca_c_None_
# cpoa2h_c_None_
# pc_MC_c_None_
# pe_MC_c_None_
# pg_MC_c_None_
# clpn_MC_c_None_
# peptido_MC_c_None_
# colipa_e_None_
# fe2_p_None_
# tdecoa_c_None_
# tdcoa_c_None_
# ppACP_c_None_
# ptdcalACP_c_None_
# hpdcalACP_c_None_
# cpoa2hcoa_c_None_
# 2ombzl_c_None_
# 2ommbl_c_None_
# 2omhmbl_c_None_
# Ssq23epx_c_None_
# codhpre6_c_None_
# thrp_c_None_
# 4hba_c_None_
# mc_fattyacid_c_None_
# mc_fattyacidcoa_c_None_
# 1agpgafa_c_None_
# pa_MC_c_None_
# cdpdag_MC_c_None_
# pgp_MC_c_None_
# ps_MC_c_None_
# pme_c_None_
# pdme_c_None_
# glyc_c_None_
# udcpp_c_None_
# adphep_LD_c_None_

# %%
None_reactions = [rxn for rxn in model.reactions if rxn.id.endswith('_None')]

for rxn in None_reactions:
    print rxn
    rxn.id = rxn.id.replace('_None','')
    
None_metabolites = [met for met in model.metabolites if met.id.endswith('_None')]

for met in None_metabolites:
    print met
    met.id = met.id.replace('_None','')
# Out:
# urea_c_None
# doxopa_c_None
# allphn_c_None
# no3_e_None

# %%
model.solve().f
# Out:
# 0.15549257432771105

# %% [markdown]
# ### Add transport reactions based on HMMER prediction and parsing against TCDB

# %% [markdown]
# Import TMHMM as a pandas dataframe, clean up the 'IDs' which currently are FASTA line markers (>lcl|AE017282.2_prot_MCAXXXX_XXXX), but I want to reduce them to just the gene IDs (MCAXXXX).

# %%
from pandas import read_csv
import pandas as pd

# %%
filepath = '/Users/clie/Desktop/EFPro2/Experimental Data & Standards/Transmembrane Domain Analysis TMHMM/AE017282.2 - TMHMM result short.csv'
TMHMM_raw = read_csv(filepath, delimiter='\t')
TMHMM_raw.ID = TMHMM_raw.ID.apply(lambda x: x.split('_')[-2])

# %% [markdown]
# Import PSORT results as a pandas dataframe, clean up the 'IDs' which currently are FASTA line markers, same as above.

# %%
filepath = '/Users/clie/Desktop/EFPro2/Experimental Data & Standards/PsortB - Compartment Prediction/PSORTb.csv'
PSORT_raw = read_csv(filepath, delimiter=',')
PSORT_raw.SeqID = PSORT_raw.SeqID.apply(lambda x: x.split('_')[-3])

# %% [markdown]
# Reshape the TMHMM_raw pandas dataframe (now with cleaned up IDs) so that it no longer contains:
#
# - Rows with an ExpAA value lower than 18. Any value above that and it is very likely to be a transmembrane protein (OR have a signal peptide) according to the [TMHMM 1.0 User Guide.](/Users/clie/Desktop/EFPro2/Experimental Data & Standards/Transmembrane Domain Analysis TMHMM/TMHMM1.0-UserGuide.pdf)
#
# - Rows with a PredHel value lower than 1. Any value above that and it is very likely to be a transmembrane protein (OR have a signal peptide) according to the [TMHMM 1.0 User Guide.](/Users/clie/Desktop/EFPro2/Experimental Data & Standards/Transmembrane Domain Analysis TMHMM/TMHMM1.0-UserGuide.pdf)
#
# This will give us a list of IDs of putative transporter proteins.

# %%
TMHMM_helix_predicted = TMHMM_raw.loc[(TMHMM_raw['ExpAA'] >= 18) & (TMHMM_raw['PredHel'] >= 1)]
# TMHMM_ID2Index = TMHMM_raw.set_index('ID')
# TMHMM_dictionary = TMHMM_ID2Index.to_dict('index')

# %%
putative_transporter_gene_IDs = list(TMHMM_helix_predicted.set_index('ID').index)

# %% [markdown]
# Next we construct the BLAST DB from the TCDB FAA file using Ipython Magic/ Shell commands. First we move the current working directory to the corresponding folder and then run BLAST+'s makeblastdb shell command.

# %%
# %cd '/Users/clie/Desktop/EFPro2/Experimental Data & Standards/TCDB Exports/'
# Out:
# /Users/clie/Desktop/EFPro2/Experimental Data & Standards/TCDB Exports

# %%
if os.path.isfile('TCDBSeqDB.pin'):
    pass
else:
    # !makeblastdb -in TCDBSeq.faa -dbtype prot -out TCDBSeqDB

# %% [markdown]
# Now for each putative transporter gene ID from the TMHMM_helix_predicted Dataframe, lets grab the AA sequence, then compile them all into a FAA file a preparation to BLAST it against the TCDB BLAST DB.

# %%
full_central_map = pd.read_csv('/Users/clie/Desktop/EFPro2/Genome/UniProtExport/FullCentralMappingOriginalGenBank.csv')

# %%
ID_2_AASeq = full_central_map.set_index('Unnamed: 0').to_dict('index')

# %%
manual_check_bin = []

if os.path.isfile('putative_transporters.faa'):
    pass
else:
    # !touch putative_transporters.faa
    n=60
    for gene_id in putative_transporter_gene_IDs:
        try: 
            sequence = ID_2_AASeq[gene_id]['AA Sequence']
            seq_snippets = [sequence[i:i+n] for i in range(0,len(sequence),n)]
            FASTA_tag = '\>' + gene_id
            # !echo $FASTA_tag >> putative_transporters.faa
            for snippet in seq_snippets:
                # !echo $snippet >> putative_transporters.faa
        except:
            print ("No sequence found for {0}".format(gene_id))
            manual_check_bin.append(gene_id)

# %% [markdown]
# The FASTA file for our query sequences has been created now, so now we BLAST all the query sequences against the TCDBSeqDB, in order to more clearly identify transporters. We will apply strong similarity criteria for the BLAST operation as to avoid getting (m)any false-positives.
#
# The criteria will be:
# - E-value = E^-9
# - Max target sequences = 1 i.e. I am chosing to ignore multiple matches as I want to recieve unambiguous mappings.
# - Max Alignments = 1 i.e. I am chosing to ignore multiple matches as I want to recieve unambiguous mappings.

# %%
if os.path.isfile('annotated_putative_transporters.csv'):
    pass
else:
    # !blastp -db TCDBSeqDB -query putative_transporters.faa -max_hsps 1 -max_target_seqs 1 -evalue 1e-9 -outfmt 10 -out annotated_putative_transporters.csv

# %%
column_IDs = ['qseqid','sseqid','pident','length','mismatch','gapopen','qstart','qend','sstart','send','evalue','bitscore','TC_Number']

# %% [markdown]
# Import the BLAST results back in the form of a Pandas Dataframe.
#
# After a manual check of the matches with the three lowest bitscores and the three lowest identities I decided not to further restrict this selection. This is, because even though the identity/ overall score was low, the descriptions or e.coli gene names of the qseqid on Uniprot matched those from the TCDB of the sseqid.

# %%
BLAST_results = pd.read_csv('annotated_putative_transporters.csv', names = column_IDs)

# %%
BLAST_results.TC_Number = BLAST_results.sseqid.apply(lambda x: x.split('|')[-1])
BLAST_results.sseqid = BLAST_results.sseqid.apply(lambda x: x.split('|')[-2])

# %%
BLAST_results.sort_values('TC_Number', ascending=False)
# Out:
#       qseqid  sseqid  pident  length  mismatch  gapopen  qstart  qend  sstart  \
# 96   MCA0963  B9DIS8  30.114     352       231        9      89   427      14
# 242  MCA2175  V4NQP3  42.241     116        67        0       1   116       1
# 259  MCA2301  A5W2Y3  51.149     174        85        0       7   180      55
# 260  MCA2302  A5W2Y4  50.000      58        28        1      33    89       5
# 4    MCA0019  D5QHE9  36.364     143        85        2       4   146      42
# 320  MCA2966  V5C7X7  64.681     235        80        2       1   235       1
# 183  MCA1650  D4ZZR3  36.538     208       116        5     355   556     196
# 134  MCA1237  D4ZZR3  35.882     170       101        3     275   439     225
# 179  MCA1583  D4ZZR3  32.948     173       107        2     304   470     220
# 174  MCA1533  D4ZZR3  34.104     173       107        2     522   689     221
# 41   MCA0456  D4ZZR3  33.929     168        95        3     285   443     228
# 44   MCA0504  D4ZZR3  30.108     372       223       10      35   384      39
# 51   MCA0547  D4ZZR3  35.359     181       104        4     769   944     221
# 186  MCA1673  D4ZZR3  35.673     171       101        4     902  1066     225
# 323  MCA2989  P60782  45.789     190       101        2       7   196       8
# 60   MCA0636  E1P8P0  43.165     139        70        3       1   138       1
# 301  MCA2742  E4PCL6  36.478     159       101        0       1   159       1
# 63   MCA0667  P0ABP6  52.217     203        95        1       8   208       8
# 6    MCA0055  P0ABP6  28.049     164       113        3      21   180      33
# 95   MCA0957  P22037  41.038     212       110        5      29   233      24
# 19   MCA0147  G0CIY2  43.925     321       163        6     156   464     169
# 282  MCA2490  P08550  41.135     141        81        2      17   156       3
# 196  MCA1725  B2GH49  38.690     168        95        4      92   258     216
# 181  MCA1599  B2GH49  32.184     174       102        6     136   303     217
# 12   MCA0102  P0ABH4  29.375     160       111        2       4   162       3
# 24   MCA0167  A2BTW4  26.415     212       126        6       6   192      18
# 245  MCA2208  Q6MLN2  39.594     197       115        4       1   195      17
# 118  MCA1133  P0AC78  32.673     303       191        5      36   331      26
# 277  MCA2432  P0A6W3  64.444     360       128        0       1   360       1
# 90   MCA0902  G2HLY8  34.821     224       137        2      10   233      70
# ..       ...     ...     ...     ...       ...      ...     ...   ...     ...
# 101  MCA1000  D8KC08  51.271     236       100        6       6   236      14
# 0    MCA0005  B1JFU8  43.333      90        47        2      37   122      37
# 164  MCA1464  Q5ZUD4  30.894     123        79        3       6   122       2
# 225  MCA1980  Q27433  26.923     156       108        4      18   172     137
# 327  MCA3057  B2N0W4  33.219     292       175        4       1   274      18
# 295  MCA2692  B2N0W4  33.929     280       148        9      36   307      62
# 224  MCA1973  F0LJH3  45.283     106        56        1      19   124      15
# 58   MCA0631  Q8F192  32.000     200       124        3       1   194      65
# 36   MCA0437  Q8F192  39.189      74        45        0      66   139     158
# 35   MCA0436  Q8F192  35.606     132        85        0     246   377     125
# 65   MCA0670  Q1D0D2  44.628     121        66        1      13   133      13
# 64   MCA0669  Q1D0D3  34.500     200       117        3      21   211      36
# 133  MCA1227  Q1D0D2  40.625     128        70        2      16   143      13
# 39   MCA0443  Q1D0D2  44.628     121        66        1      13   133      13
# 38   MCA0442  Q1D0D3  33.500     200       119        3      21   211      36
# 37   MCA0438  Q1D0D2  28.448     116        81        2      14   128      16
# 251  MCA2237  Q1D0D2  39.831     118        71        0      12   129      15
# 59   MCA0632  Q1D0D2  31.783     129        84        3      12   140      15
# 252  MCA2238  P0ABU9  32.051     156        97        4     445   597      71
# 132  MCA1226  P0ABU9  53.604     222       103        0       3   224       2
# 14   MCA0108  O34442  27.294     425       305        2      57   479      26
# 182  MCA1632  P77338  28.082     292       201        3     485   769     808
# 289  MCA2608  P77338  34.375     256       168        0     538   793     840
# 145  MCA1308  P0AAC6  55.556     216        92        3      10   225       8
# 333  MCA3086  F8CM01  33.838     198       122        4      76   264     106
# 178  MCA1581  O28528  36.364     418       230        8      42   428      38
# 29   MCA0268  O67997  46.366     399       209        3      27   424      39
# 43   MCA0490  O67997  50.995     402       188        4      28   426      40
# 236  MCA2136  P69681  53.636     440       170        4      40   479      22
# 61   MCA0647  M2TPV1  41.322     121        63        3     130   247     111
#
#      send         evalue  bitscore     TC_Number
# 96    363   8.570000e-34     136.0    9.B.97.5.1
# 242   116   1.750000e-22      84.0    9.B.72.1.6
# 259   228   2.280000e-54     171.0    9.B.69.1.1
# 260    62   1.490000e-10      50.8    9.B.69.1.1
# 4     178   2.480000e-16      71.2    9.B.62.5.2
# 320   232  4.960000e-101     292.0    9.B.43.2.1
# 183   393   1.110000e-26     112.0    9.B.34.1.3
# 134   391   4.580000e-23     100.0    9.B.34.1.3
# 179   389   1.280000e-23     101.0    9.B.34.1.3
# 174   391   2.470000e-20      93.6    9.B.34.1.3
# 41    388   1.060000e-20      92.8    9.B.34.1.3
# 44    395   3.570000e-36     135.0    9.B.34.1.3
# 51    393   3.970000e-22      99.4    9.B.34.1.3
# 186   392   1.150000e-24     107.0    9.B.34.1.3
# 323   195   3.300000e-50     160.0    9.B.31.1.1
# 60    131   2.210000e-27      98.2    9.B.27.3.1
# 301   159   3.820000e-31     111.0    9.B.27.2.7
# 63    210   2.100000e-70     213.0    9.B.27.2.3
# 6     195   1.670000e-12      66.2    9.B.27.2.3
# 95    227   9.150000e-37     128.0    9.B.20.1.1
# 19    484   6.640000e-82     260.0    9.B.18.1.1
# 282   142   2.420000e-30     107.0  9.B.160.1.16
# 196   376   1.180000e-16      79.7  9.B.160.1.10
# 181   380   1.280000e-13      71.2  9.B.160.1.10
# 12    161   1.220000e-20      82.0   9.B.157.1.3
# 24    224   2.030000e-20      84.3   9.B.150.1.3
# 245   211   9.390000e-39     132.0  9.B.149.1.11
# 118   322   1.070000e-49     171.0   9.B.146.1.7
# 277   360  2.590000e-161     454.0   9.B.146.1.6
# 90    284   3.770000e-36     130.0   9.B.146.1.2
# ..    ...            ...       ...           ...
# 101   239   1.700000e-63     198.0    1.A.79.2.1
# 0     126   7.330000e-13      60.1    1.A.77.3.9
# 164   124   1.260000e-14      64.3    1.A.63.2.3
# 225   287   7.950000e-10      58.2     1.A.6.2.2
# 327   307   3.040000e-41     143.0    1.A.46.2.6
# 295   312   1.730000e-38     137.0    1.A.46.2.6
# 224   118   5.590000e-21      83.6    1.A.43.1.7
# 58    258   4.270000e-30     110.0    1.A.30.2.9
# 36    231   3.140000e-10      56.2    1.A.30.2.9
# 35    256   1.460000e-16      78.2    1.A.30.2.9
# 65    132   8.540000e-28      99.4    1.A.30.2.7
# 64    230   3.940000e-29     107.0    1.A.30.2.7
# 133   134   1.010000e-25      94.4    1.A.30.2.7
# 39    132   8.540000e-28      99.4    1.A.30.2.7
# 38    230   1.360000e-30     111.0    1.A.30.2.7
# 37    130   2.890000e-11      56.6    1.A.30.2.7
# 251   132   1.310000e-21      83.2    1.A.30.2.7
# 59    139   4.710000e-14      63.9    1.A.30.2.7
# 252   220   4.390000e-15      73.9    1.A.30.2.2
# 132   223   6.190000e-82     243.0    1.A.30.2.2
# 14    448   4.410000e-56     192.0    1.A.26.1.3
# 182  1097   6.530000e-33     135.0    1.A.23.1.1
# 289  1095   7.880000e-45     173.0    1.A.23.1.1
# 145   219   1.150000e-68     209.0    1.A.14.2.1
# 333   303   1.700000e-19      89.4    1.A.13.4.1
# 178   450   3.720000e-63     209.0    1.A.11.2.7
# 29    433  7.510000e-115     342.0    1.A.11.1.4
# 43    435  2.020000e-124     367.0    1.A.11.1.4
# 236   427  1.010000e-153     443.0    1.A.11.1.1
# 61    226   2.800000e-23      93.2    1.A.1.28.4
#
# [338 rows x 13 columns]

# %% [markdown]
# Now that we have the Gene ID matched with corresponding TC-Numbers, we will group genes with identical functions.

# %%
BLAST_results_refocused = pd.DataFrame([BLAST_results['qseqid'],BLAST_results['TC_Number']]).T

# %%
TC_number_genes_grouped = BLAST_results_refocused.groupby('TC_Number')
TC_to_gene = TC_number_genes_grouped.aggregate(lambda x:list(x))
TC_to_gene_dict = TC_to_gene.to_dict('index')

# %% [markdown]
# Now we will try to find the TC-Numbers in the curated TCDB-extract from MERLIN (Provided by Bruno and Óscar)

# %%
MERLIN_curated_TCDB_export = read_csv('/Users/clie/Desktop/EFPro2/Experimental Data & Standards/TCDB Exports/ MERLIN_metabolites_transport_database-Curated Export.csv')

# %%
TCDB_Dict = MERLIN_curated_TCDB_export.set_index('TCDB ID').to_dict('index')

# %%
non_curated_transporters = []

for key in TC_to_gene_dict.keys():
    if key in TCDB_Dict.keys():
        print key, TCDB_Dict[key]['metabolite'],TCDB_Dict[key]['direction'],TCDB_Dict[key]['reversibility'],TCDB_Dict[key]['reacting_metabolites']
    else:
        non_curated_transporters.append(key) # Check manually at later stage!
# Out:
# 1.A.11.2.7 NH3; methylamine in True --
# 3.A.12.1.2 DNA in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.D.9.1.1 proton out True 1: Oxidized donor || 1:Reduced acceptor
# 2.A.7.3.29 drugs out True --
# 3.D.4.10.2 proton:proton:proton:proton out False 2:nitric oxide; 2:Ferrocytochrome c; 2:proton || 1:nitrous oxide; 2:Ferricytochrome c; 1:water
# 9.B.102.5.2 unknown in True --
# 2.A.9.3.1 protein out False --
# 1.A.77.3.9 Mg2+; Ca2+ in False --
# 1.A.23.1.1 K+ out True --
# 3.A.1.102.1 polysaccharide out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 2.A.3.8.12 L-threonine // L-serine in // out True --
# 3.A.1.107.3 heme out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 2.A.1.42.1 lysophospholipid in True --
# 3.A.3.5.18 copper out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 2.A.4.7.7 proton // Mn2+ in // out False --
# 3.A.3.5.20 gold out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.A.1.114.1 glycolipids out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 9.B.102.5.5 unknown in True --
# 1.B.52.2.2 unknown in True --
# 5.A.1.6.4 electron:electron out False --
# 3.D.1.9.2 proton:proton:proton:proton out False 1:NADH; 1:ubiquinones; 1:proton || 1:DPN; 1:ubiquinol
# 3.D.1.9.1 proton:proton:proton:proton out False 1:NADH; 1:ubiquinones; 1:proton || 1:DPN; 1:ubiquinol
# 2.A.6.4.1 proton // protein in // out False --
# 3.A.1.11.1 putrescine; spermidine in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 2.A.1.6.4 proline; glycine betaine; taurine; ectoine; L-Pipecolate; Proline betaine; N,N-dimethylglycine; carnitine; 1-Carboxymethyl-pyridinium : proton; Na+ in:in True --
# 2.A.3.8.28 Serine // Threonine in // out True --
# 9.B.125.2.1 unknown out True --
# 2.A.69.4.3 auxin in False --
# 2.A.49.5.5 chloride ion:chloride ion // proton in // out True --
# 3.A.1.111.2 subtilin out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 2.A.4.1.3 proton:K+ // cadmium; zinc in // out False --
# 2.A.59.1.5 arsenite out False --
# 3.A.15.2.1 pilin out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 1.A.43.1.7 fluoride out True --
# 3.A.1.105.17 drugs out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 9.B.14.2.4 heme out True --
# 3.A.1.1.4 lactose in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.D.1.1.1 proton:proton:proton:proton out False 1:NADH; 1:ubiquinones; 1:proton || 1:DPN; 1:ubiquinol
# 3.D.6.1.1 proton; Na+ in False 1:NADH; 1:oxidized ferredoxin || 1:DPN; 1:reduced ferredoxin
# 2.A.40.4.2 9H-xanthine:proton in:in False --
# 2.A.21.9.2 proline sensor False --
# 2.A.5.5.2 ferrous ion; cobalt ion; Mn2+; cadmium; zinc in False --
# 2.A.20.1.1 orthophosphate:proton in:in False --
# 3.A.3.2.21 Ca2+ // proton in // out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.A.5.1.1 protein out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.A.1.4.5 urea; thiourea; hydroxyurea in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.A.1.103.1 polysaccharide out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 9.B.69.1.1 cobalt ion in True --
# 2.A.3.3.22 arginine; lysine; histidine; ornithine:proton in:in False --
# 2.A.1.2.60 proton // drugs in // out True --
# 5.A.1.1.1 electron:electron out False --
# 2.A.106.1.4 Ca2+ // proton in // out True --
# 2.A.1.8.2 nitric acid in True --
# 2.A.66.4.1 peptidoglycan in True --
# 3.A.1.125.1 lipoproteins out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 2.A.6.7.5 proton // unknown in // out False --
# 3.A.1.139.3 UDP-D-glucose; ferric iron out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 2.A.1.11.3 oxalate // formate in // out True --
# 3.E.2.1.1 proton:proton out False --
# 2.A.53.3.8 sulfate :proton in:in False --
# 3.A.8.1.1 protein out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 9.B.18.1.1 unknown in True --
# 2.A.53.3.4 molybdenum in True --
# 3.D.3.2.1 proton:proton out False 1:ubiquinol; 2:Ferrocytochrome c || 1:ubiquinones; 2:Ferricytochrome c; 2:proton
# 3.D.4.3.2 proton:proton:proton:proton:proton:proton:proton:proton out False 4:Ferrocytochrome c; 1:O2; 4:proton || 4:Ferricytochrome c; 2:water
# 1.A.14.2.1 Ca2+ in True --
# 2.A.7.1.10 cetyltrimethylammonium bromide; cetylpyridinium chloride; tetraphenylphosphonium; benzalkonium chloride; ethidium bromide; sodium dodecyl sulfate out True --
# 3.A.3.7.2 K+ // Na+ in // out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 1.A.11.1.1 NH3 in True --
# 3.A.1.140.1 -- division False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 1.A.11.1.4 NH3 in True --
# 3.A.3.4.1 nickel; Mg2+ in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 1.B.22.2.1 protein out False --
# 2.A.86.2.1 AI-2 out True --
# 9.B.27.2.3 selenite in True --
# 2.A.64.1.1 protein out False --
# 5.A.3.2.1 proton // electron:electron in // out False 1:formate; 1:ubiquinone; 1:proton || 1:carbon dioxide; 1:ubiquinol
# 9.B.20.1.1 Mg2+ in True --
# 1.A.30.2.7 proton in True --
# 3.A.3.2.4 Ca2+ // proton in // out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 1.A.30.2.2 proton in True --
# 2.A.1.27.1 3-phenylpropionic acid in True --
# 2.A.50.2.1 alanine in False --
# 2.A.6.8.1 proton // unknown in // out False --
# 9.B.150.1.3 unknown out True --
# 3.A.16.1.1 protein out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.A.16.1.2 protein out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 2.A.1.25.2 glycopeptide in True --
# 2.A.28.2.2 pyruvate:Na+ in:in False --
# 2.A.102.4.3 toluene-4-sulfonate in True --
# 3.A.11.2.3 DNA in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 2.A.102.4.5 4-toluene sulfonate in True --
# 2.A.6.3.7 proton // nodulation factor in // out False --
# 2.A.6.3.6 proton // nodulation factor in // out False --
# 3.A.1.1.34 alpha-1,5-arabinooligosaccharides; alpha-1,5-arabinotriose; alpha-1,5-arabinotetraose in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 2.A.6.3.1 proton // nodulation factor in // out False --
# 1.A.13.4.1 chloride ion out True --
# 2.A.6.1.5 proton // zinc; cadmium; lead in // out False --
# 2.A.6.1.4 proton // copper; silver metal in // out False --
# 2.A.6.1.6 proton // zinc in // out False --
# 2.A.95.1.5 alanine; asparagine; cysteine; glutamine; glycine; isoleucine; leucine; methionine; phenylalanine; proline; tryptophan; valine; histidine; tyrosine; threonine; serine; selenocysteine out True --
# 2.A.6.1.2 proton //cobalt ion; zinc; cadmium in // out False --
# 3.D.4.2.1 proton:proton:proton:proton:proton:proton:proton:proton out False 4:Ferrocytochrome c; 1:O2; 4:proton || 4:Ferricytochrome c; 2:water
# 9.B.14.1.7 heme out True --
# 3.D.3.3.1 proton:proton out False 1:ubiquinol; 2:Ferrocytochrome c || 1:ubiquinones; 2:Ferricytochrome c; 2:proton
# 3.D.1.2.1 proton:proton:proton:proton out False 1:NADH; 1:ubiquinones; 1:proton || 1:DPN; 1:ubiquinol
# 2.A.6.1.8 proton // copper in // out False --
# 9.A.4.1.1 K+ in False --
# 2.A.6.2.33 proton // fluoroquinolone; microlides; chloramphenicol; tetracycline in // out False --
# 1.E.40.3.1 murein hydrolase out False --
# 9.B.1.1.2 EC:3.4.24.84 enzyme True --
# 2.A.6.1.11 proton // ferrous ion; zinc; Mn2+; cobalt ion; cadmium; copper; nickel; lead in // out False --
# 2.A.37.1.3 proton // K+ in // out True --
# 3.A.1.5.34 oligopeptides in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 9.A.40.2.2 unknown in True --
# 2.A.99.1.1 nickel in True --
# 3.A.1.7.5 orthophosphate in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 2.A.72.1.1 K+ in True --
# 2.A.86.1.1 AI-2 out True --
# 3.A.3.7.1 K+ // Na+ in // out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 9.B.27.3.1 unknown in True --
# 3.D.2.1.1 proton in True 1:NADP+; 1:NADH || 1:NADPH; 1:DPN
# 9.B.104.1.2 unknown in True --
# 3.B.1.1.5 Na+ in True 1:D-Methylmalonyl-CoA; 1:proton || 1:propanoyl-CoA; 1:carbon dioxide
# 3.A.1.122.15 heavy metal out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.A.1.8.2 molybdate; tungstate in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.A.1.106.2 doxorubicin; verapamil; ethidium; tetraphenylphosphonium; vinblastine out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.A.1.106.1 lipid A; glycerophospholipids; azidopine; daunomycin; vinblastine; ethidium out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 2.A.38.1.3 proton:K+ in:in True --
# 2.A.6.2.20 proton // Toxoflavine in // out False --
# 2.A.6.2.22 proton // ethidium; ciprofloxacin; norfloxacin; tetracycline; cefotaxime; rifampicin; erythromycin; chloramphenicol; salicylate in // out False --
# 2.A.6.2.27 proton // triclosan in // out False --
# 3.A.3.5.5 copper; silver metal out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.A.2.1.1 proton out False 1:ADP; 1:orthophosphate|| 1:ATP; 1:water
# 2.A.1.3.18 proton // phytoalexins; flavonoids; salicylate in // out True --
# 3.A.3.31.1 transition element cation out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 2.A.1.59.2 unknown in True --
# 3.A.1.203.8 long-chain fatty acyl-CoA in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.D.4.8.1 proton:proton:proton:proton:proton:proton:proton:proton out False 4:Ferrocytochrome c; 1:O2; 4:proton || 4:Ferricytochrome c; 2:water
# 2.A.103.1.2 unknown out False --
# 2.A.103.1.1 unknown out False --
# 1.A.6.2.2 Na+ in True --
# 5.A.2.1.1 electron:electron out False --
# 3.A.15.3.1 protein out False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.D.5.1.1 Na+ out False 1:NADH; 1:ubiquinone || 1:DPN; 1:ubiquinol
# 2.A.23.1.7 fumarate; D-malate; L-malate; succinate:proton in:in False --
# 2.A.22.5.3 unknown:Na+ in:in True --
# 2.A.37.4.2 proton // K+ in // out True --
# 9.B.105.1.1 lead out True --
# 3.D.1.6.2 proton:proton:proton:proton out False 1:NADH; 1:ubiquinones; 1:proton || 1:DPN; 1:ubiquinol
# 9.B.31.1.1 unknown in True --
# 2.A.17.4.7 dipeptide; tripeptide:proton in:in False --
# 2.A.19.2.1 proton // ca2+ in // out True --
# 3.D.4.6.1 proton:proton:proton:proton:proton:proton:proton:proton out False 4:Ferrocytochrome c; 1:O2; 4:proton || 4:Ferricytochrome c; 2:water
# 3.D.4.6.2 proton:proton:proton:proton:proton:proton:proton:proton out False 4:Ferrocytochrome c; 1:O2; 4:proton || 4:Ferricytochrome c; 2:water
# 3.D.4.7.1 proton:proton:proton:proton:proton:proton:proton:proton out False 4:Ferrocytochrome c; 1:O2; 4:proton || 4:Ferricytochrome c; 2:water
# 2.A.6.2.16 proton // fluoroquinolone; chloramphenicol; biocides; xenobiotics; chloramphenicol in // out False --
# 2.A.6.2.17 proton // fluoroquinolone; tetracycline; macrolides; chloramphenicol; biocides; triclosan; tetracycline; erythromycin in // out False --
# 3.A.1.5.19 oligopeptides in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 2.A.19.1.1 proton // ca2+; Na+; K+ in // out True --
# 1.B.42.1.2 lipopolysaccharides out True --
# 3.A.1.27.3 phospholipids in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.A.1.27.1 gamma-hexachlorocyclohexane in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 3.A.1.6.1 sulfate; thiosulfate in False 1:ATP; 1:water || 1:ADP; 1:orthophosphate
# 8.A.3.3.3 polysaccharides out True --
# 3.A.2.1.2 Na+ out False 1:ADP; 1:orthophosphate|| 1:ATP; 1:water
# 2.A.7.1.3 tetraphenylphosphonium; erythromycin A; ethidium bromide; acriflavine; safranin; Pyronine Y out True --

# %% [markdown]
# Here should now follow resolving the TC Numbers to Reaction strings and translating the metabolite names to metabolite IDs, but as it turned out I had no clearance to use the MERLIN-curated TCDB export. Hence this is postponed.

# %% [markdown]
# Instead, I will write all entries from the Notes field to the Annotation fields to be included in the most recent version of the SMBL export. Newer, non-legacy formats do not support the Notes field.
#
# I will try to match the MIRIAM nomenclature.

# %%
for met in model.metabolites:
    try:
        len(met.notes.keys()) > 1
        met_notes = met.notes
        anno_dict = {}
        for key in met_notes.keys():
            if key == 'BIGG':
                anno_dict['bigg.metabolite'] = met_notes[key][0].lstrip('\'').rstrip('\'').split(',')[0]
            elif key == 'KEGG':
                    value_entries = met_notes[key][0].lstrip('\'').rstrip('\'').split(',')
                    if len(value_entries) > 1:
                        anno_dict['kegg.compound'] = [x.lstrip(' ') for x in value_entries]
                    else:
                        anno_dict['kegg.compound'] = value_entries[0].lstrip(' ')
            elif key == 'SEED':
                value_entries = met_notes[key][0].lstrip('\'').rstrip('\'').split(',')
                if len(value_entries) > 1:
                    anno_dict['seed.compound'] = [x for x in value_entries]
                else:
                    anno_dict['seed.compound'] = value_entries[0]
            elif key == 'MXNREF':
                value_entries = met_notes[key][0].lstrip('\'').rstrip('\'').split(',')
                if len(value_entries) > 1:
                    anno_dict['metanetx.chemical'] = [key+':'+x.lstrip(' ') for x in value_entries]
                else:
                    anno_dict['metanetx.chemical'] = value_entries[0]
            elif key == 'METACYC':
                value_entries = met_notes[key][0].lstrip('\'').rstrip('\'').split(',')
                if len(value_entries) > 1:
                    anno_dict['biocyc'] = ['META:'+x.lstrip(' ') for x in value_entries]
                else:
                    anno_dict['biocyc'] = 'META:'+ value_entries[0].lstrip(' ')
            elif key == 'SMILES':
                pass
            elif key == 'BRENDA':
                pass
            elif key == 'INCHI':
                value_entries = met_notes[key][0].lstrip('\'').rstrip('\'')
                anno_dict['inchi'] = met_notes[key][0].lstrip('\'').rstrip('\'')
            elif key == 'HMDB':
                value_entries = met_notes[key][0].lstrip('\'').rstrip('\'').split(',')
                if len(value_entries) > 1:
                    anno_dict[key.lower()] = [x.lstrip(' ') for x in value_entries]
                else:
                    anno_dict[key.lower()] = value_entries[0].lstrip(' ')
            else:
                value_entries = met_notes[key][0].lstrip('\'').rstrip('\'').split(',')
                if len(value_entries) > 1:
                    anno_dict[key.lower()] = [key+':'+x.lstrip(' ') for x in value_entries]
                else:
                    anno_dict[key.lower()] = key+':'+value_entries[0].lstrip(' ')
        met.annotation = anno_dict
    except:
        pass

# %%
for rxn in model.reactions:
    try:
        len(rxn.notes.keys()) > 1
        rxn_notes = rxn.notes
        anno_dict = {}
        for key in rxn_notes.keys():
            if key == 'BIGG':
                anno_dict['bigg.reaction'] = rxn_notes[key][0].lstrip('\'').rstrip('\'').split(',')[0]
            elif key == 'KEGG':
                    value_entries = rxn_notes[key][0].lstrip('\'').rstrip('\'').split(',')
                    if len(value_entries) > 1:
                        anno_dict['kegg.reaction'] = [x.lstrip(' ') for x in value_entries]
                    else:
                        anno_dict['kegg.reaction'] = value_entries[0].lstrip(' ')
            elif key == 'SEED':
                value_entries = rxn_notes[key][0].lstrip('\'').rstrip('\'').split(',')
                if len(value_entries) > 1:
                    anno_dict['seed'] = [x.lstrip(' ') for x in value_entries]
                else:
                    anno_dict['seed'] = value_entries[0].lstrip(' ')
            elif key == 'MXNREF':
                value_entries = rxn_notes[key][0].lstrip('\'').rstrip('\'').split(',')
                if len(value_entries) > 1:
                    anno_dict['metanetx.reaction'] = [key+':'+x.lstrip(' ') for x in value_entries]
                else:
                    anno_dict['metanetx.reaction'] = value_entries[0]
            elif key == 'METACYC':
                value_entries = rxn_notes[key][0].lstrip('\'').rstrip('\'').split(',')
                if len(value_entries) > 1:
                    anno_dict['biocyc'] = ['META:'+x.lstrip(' ') for x in value_entries]
                else:
                    anno_dict['biocyc'] = 'META:'+ value_entries[0].lstrip(' ')
            elif key == 'GENE ASSOCIATION':
                pass
            elif key == 'CONFIDENCE SCORE':
                pass
            elif key == 'INHIBITOR':
                pass
            elif key == 'LOCALIZATION':
                pass
            elif key == 'COFACTOR':
                pass
            elif key == 'SUBSYSTEM':
                pass
            elif key == 'BRENDA':
                pass
            elif key == 'EC NUMBER':
                value_entries = rxn_notes[key][0].lstrip('\'').rstrip('\'').split(';')
                if len(value_entries) > 1:
                    anno_dict['brenda'] = [x.lstrip(' ') for x in value_entries]
                else:
                    anno_dict['brenda'] = value_entries[0].lstrip(' ')
            elif key == 'REACTOME':
                value_entries = rxn_notes[key][0].lstrip('\'').rstrip('\'').split(',')
                if len(value_entries) > 1:
                    anno_dict['reactome'] = [x.lstrip(' ') for x in value_entries]
                else:
                    anno_dict['reactome'] = value_entries[0].lstrip(' ')
            elif key == 'RHEA':
                value_entries = rxn_notes[key][0].lstrip('\'').rstrip('\'').split(',')
                if len(value_entries) > 1:
                    anno_dict['rhea'] = [x.lstrip(' ') for x in value_entries]
                else:
                    anno_dict['rhea'] = value_entries[0].lstrip(' ')
            else:
                value_entries = rxn_notes[key][0].lstrip('\'').rstrip('\'').split(',')
                if len(value_entries) > 1:
                    anno_dict[key.lower()] = [key+':'+x.lstrip(' ') for x in value_entries]
                else:
                    anno_dict[key.lower()] = key+':'+value_entries[0].lstrip(' ')
        rxn.annotation = anno_dict
    except:
        pass

# %%
for rxn in model.reactions:
    if type(rxn.notes) == dict:
        for key in rxn.notes.keys():
            if key in ['CONFIDENCE SCORE', 'LOCALIZATION', 'SUBSYSTEM','INHIBITOR','COFACTOR']:
                value_entries = rxn.notes[key][0].strip('\'').split(',')
                if len(value_entries) > 1:
                    rxn.notes[key] = [x.lstrip(' ') for x in value_entries]
                else:
                    rxn.notes[key] = value_entries[0]
            else:
                rxn.notes.pop(key)

# %%
for met in model.metabolites:
    try:
        for key in met.notes.keys():
            if key not in ['SMILES']:
                met.notes.pop(key)
    except:
        print '{1} has no notes section'.format(met)

# %% [markdown]
# Based on errors I recieved with the SMBL Model Validator, here are some last fixes.

# %% [markdown]
# Metabolites must be exported with having a compartment at met.compartment!

# %%
mets_with_missing_compartments = [met for met in model.metabolites if met.compartment == '']

# %%
for met in mets_with_missing_compartments:
    met.compartment = met.id.split('_')[-1]
    #print met.compartment

# %% [markdown]
# All metabolites must have either no formula or a chemically viable one. 'nan' or 'None' or symbols like '(', ')' and '.' are not accepted with fbc:chemicalFormula

# %%
mets_with_faulty_formula = [met for met in model.metabolites if met.formula == 'nan']

# %%
for met in mets_with_faulty_formula:
    met.formula = ''

# %%
mets_with_faulty_formula = [met for met in model.metabolites if ('.' or '(' or ')') in met.formula]

# %%
for met in mets_with_faulty_formula:
    met.formula = ''

# %%
# verify that it still work as it did before:

solution = show_uptake_excretion(model,model.reactions.get_by_id('BIOMASS_REACTION'))
# Out:
# EX_co2_c 9.80917347274
# EX_h2o_c 29.839484494
# EX_pi_c -0.0742559453479
# EX_ACP_c 2.23345647532e-17
# EX_hco3_c 2.30021674414
# EX_o2_c -27.6123082969
# EX_trdox_c 4.62223186653e-33
# EX_so4_c -0.0273340396411
# EX_h2o2_c 0.00108844802029
# EX_co_c 4.66477722983e-06
# EX_2dhp_c 0.045398233971
# EX_dhpt_c 8.67361737989e-19
# EX_5prdmbz_c 0.000155492574328
# EX_no3_e -1.3686798476
# EX_ch4_p 18.405
# EX_fe2_p 0.000951614554886
# BIOMASS_REACTION 0.155492574328

# %% [markdown]
# Export in the model in the most recent SBML version: Level 3, Version 1 and with fbc_package.

# %%
target_filename_json = relative_directory + '/Reconstructions/MethylococcusModel9.json'
target_filename_xml = relative_directory + '/Reconstructions/MethylococcusModel9.xml'
cobra.io.write_sbml_model(model, target_filename_xml, use_fbc_package=True)
cobra.io.save_json_model(model, target_filename_json,pretty = True)
