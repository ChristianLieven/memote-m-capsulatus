# %%
from cameo import load_model
from os import getcwd
from Functions_Modules import curation_tools as ct
from math import isnan
from numpy import zeros
# Out:
# /Users/clie/.virtualenvs/modeling/lib/python2.7/site-packages/cobra/io/sbml3.py:24: UserWarning: Install lxml for faster SBML I/O
#   warn("Install lxml for faster SBML I/O")

# %% [markdown]
# # Transport Reactions

# %% [markdown]
# Second attempt at adding transport reactions. This time in a semi-automatic fashion using only PSORT, TransportDB, TCDB classification and the genome annotation.

# %%
from pandas import read_csv
import pandas as pd

# %% [markdown]
# First, lets import the PsortB Data

# %% [markdown]
# The IDs are the full FASTA SeqIDs hence we need to clean them up a little to obtain them in this format 'MCAXXXX'

# %%
filepath = '/Users/clie/Desktop/EFPro2/Experimental Data & Standards/PsortB - Compartment Prediction/PSORTb.csv'
PSORT_raw = read_csv(filepath, delimiter=',')
PSORT_raw.SeqID = PSORT_raw.SeqID.apply(lambda x: x.split('_')[-3])

# %% [markdown]
# We're only interested in the calculated scores and thus remove all other columns.

# %%
PSORT_reduced = PSORT_raw[['SeqID','Cytoplasmic_Score','CytoplasmicMembrane_Score','OuterMembrane_Score','Extracellular_Score','Final_Localization','Final_Score']]

# %% [markdown]
# PsortB 3.0 Manual:
#
# "PSORTb v.3.0 returns a list of the five localization sites and the associated probability value for each. We consider 7.5 to be a good cutoff above which a single localization can be assigned, and our precision and recall values for the program are calculated using this cutoff.
#
# In certain cases, two localization sites may both exhibit high scores, which may indicate a protein with domains present in neighbouring localization sites. In cases where a localization site has a score between 4.5 (for Gram-negative) and 5.0 (for Gram-positive) and 7.49, the result returned to the user will say "Unknown - This protein may have multiple localization sites". In cases like these, we recommend you examine the long format output of the program's prediction to draw your own conclusion."

# %%
PSORT_reduced = PSORT_reduced.loc[PSORT_reduced['Final_Score']>7.5]

# %%
PSORT_reduced.rename(columns={'SeqID':'ID'}, inplace=True)

# %%
#PSORT_dict = PSORT_reduced.set_index('SeqID').to_dict(orient='index')

# %%
filepath = '/Users/clie/Desktop/EFPro2/Experimental Data & Standards/TCDB Exports/TCDB-MethylococcusCapsulatus.csv'
TDB_raw = read_csv(filepath, delimiter=',',names=['ID','Substrate','Subtype','Family','FamilyName','TransporterClass','TCNumber'])

# %%
TDB_raw
# Out:
#           ID                                       Substrate          Subtype  \
# 0    MCA0093                                    daunorubicin          binding
# 1    MCA0127                                            heme          binding
# 2    MCA0134                                     lipoprotein          binding
# 3    MCA0135                                   cell division         membrane
# 4    MCA0168                                         lipid A          binding
# 5    MCA0169                                    Unclassified         membrane
# 6    MCA0172                               toluene tolerance  binding protein
# 7    MCA0173                                    D-methionine          binding
# 8    MCA0174                               toluene tolerance         membrane
# 9    MCA0300                                    Unclassified  binding protein
# 10   MCA0555                                    daunorubicin          binding
# 11   MCA0557                                       multidrug         membrane
# 12   MCA0609                                            heme          binding
# 13   MCA0625                                    daunorubicin          binding
# 14   MCA0626                           polysaccharide export         membrane
# 15   MCA0742                                    daunorubicin          binding
# 16   MCA0806                               toluene tolerance          binding
# 17   MCA0840     amino acid (glutamine/glutamate/aspartate?)  binding protein
# 18   MCA0869                           spermidine/putrescine  binding protein
# 19   MCA0870                           spermidine/putrescine         membrane
# 20   MCA0871                           spermidine/putrescine         membrane
# 21   MCA0872                                       polyamine          binding
# 22   MCA0894                                         lipid A          binding
# 23   MCA0899                             sulfate/thiosulfate          binding
# 24   MCA0953                                     heme export         membrane
# 25   MCA0954                                            heme          binding
# 26   MCA0964                                         lipid A          binding
# 27   MCA0990                 ? (Fe-S assembly/SufBCD system)         membrane
# 28   MCA0991                 ? (Fe-S assembly/SufBCD system)              ABC
# 29   MCA0992                 ? (Fe-S assembly/SufBCD system)         membrane
# ..       ...                                             ...              ...
# 212  MCA2041                            potassium ion uptake              NaN
# 213  MCA0974                                        zinc ion              NaN
# 214  MCA0975                                        zinc ion              NaN
# 215  MCA1728                                        zinc ion              NaN
# 216  MCA2417                                        zinc ion              NaN
# 217  MCA0268                                        ammonium              NaN
# 218  MCA0490                                        ammonium              NaN
# 219  MCA1581                                        ammonium              NaN
# 220  MCA2136                                        ammonium              NaN
# 221  MCA2692                        Bestrophin anion channel              NaN
# 222  MCA3057                        Bestrophin anion channel              NaN
# 223  MCA0436                                    Unclassified              NaN
# 224  MCA0442                                    Unclassified              NaN
# 225  MCA0631                                    Unclassified              NaN
# 226  MCA0632                                    Unclassified              NaN
# 227  MCA0669                                    Unclassified              NaN
# 228  MCA1226                                    Unclassified              NaN
# 229  MCA1227                                    Unclassified              NaN
# 230  MCA2237                                    Unclassified              NaN
# 231  MCA1632  small-conductance mechanosensitive ion channel              NaN
# 232  MCA2608  small-conductance mechanosensitive ion channel              NaN
# 233  MCA0647                           potassium ion channel              NaN
# 234  MCA1097                                     ferrous ion              NaN
# 235  MCA1925                                    Unclassified              NaN
# 236  MCA1250                      hemolysin C (HlyC) homolog              NaN
# 237  MCA0108                                   magnesium ion              NaN
# 238  MCA2402                                   magnesium ion              NaN
# 239  MCA2757                                    sodium ion/?              NaN
# 240  MCA1534                                    Unclassified              NaN
# 241  MCA1819                                    Unclassified              NaN
#
#          Family                                         FamilyName  \
# 0           ABC         The ATP-binding Cassette (ABC) Superfamily
# 1           ABC         The ATP-binding Cassette (ABC) Superfamily
# 2           ABC         The ATP-binding Cassette (ABC) Superfamily
# 3           ABC         The ATP-binding Cassette (ABC) Superfamily
# 4           ABC         The ATP-binding Cassette (ABC) Superfamily
# 5           ABC         The ATP-binding Cassette (ABC) Superfamily
# 6           ABC         The ATP-binding Cassette (ABC) Superfamily
# 7           ABC         The ATP-binding Cassette (ABC) Superfamily
# 8           ABC         The ATP-binding Cassette (ABC) Superfamily
# 9           ABC         The ATP-binding Cassette (ABC) Superfamily
# 10          ABC         The ATP-binding Cassette (ABC) Superfamily
# 11          ABC         The ATP-binding Cassette (ABC) Superfamily
# 12          ABC         The ATP-binding Cassette (ABC) Superfamily
# 13          ABC         The ATP-binding Cassette (ABC) Superfamily
# 14          ABC         The ATP-binding Cassette (ABC) Superfamily
# 15          ABC         The ATP-binding Cassette (ABC) Superfamily
# 16          ABC         The ATP-binding Cassette (ABC) Superfamily
# 17          ABC         The ATP-binding Cassette (ABC) Superfamily
# 18          ABC         The ATP-binding Cassette (ABC) Superfamily
# 19          ABC         The ATP-binding Cassette (ABC) Superfamily
# 20          ABC         The ATP-binding Cassette (ABC) Superfamily
# 21          ABC         The ATP-binding Cassette (ABC) Superfamily
# 22          ABC         The ATP-binding Cassette (ABC) Superfamily
# 23          ABC         The ATP-binding Cassette (ABC) Superfamily
# 24          ABC         The ATP-binding Cassette (ABC) Superfamily
# 25          ABC         The ATP-binding Cassette (ABC) Superfamily
# 26          ABC         The ATP-binding Cassette (ABC) Superfamily
# 27          ABC         The ATP-binding Cassette (ABC) Superfamily
# 28          ABC         The ATP-binding Cassette (ABC) Superfamily
# 29          ABC         The ATP-binding Cassette (ABC) Superfamily
# ..          ...                                                ...
# 212         Trk                    The K+ Transporter (Trk) Family
# 213         ZIP  The Zinc (Zn2+)-Iron (Fe2+) Permease (ZIP) Family
# 214         ZIP  The Zinc (Zn2+)-Iron (Fe2+) Permease (ZIP) Family
# 215         ZIP  The Zinc (Zn2+)-Iron (Fe2+) Permease (ZIP) Family
# 216         ZIP  The Zinc (Zn2+)-Iron (Fe2+) Permease (ZIP) Family
# 217         Amt       The Ammonia Transporter Channel (Amt) Family
# 218         Amt       The Ammonia Transporter Channel (Amt) Family
# 219         Amt       The Ammonia Transporter Channel (Amt) Family
# 220         Amt       The Ammonia Transporter Channel (Amt) Family
# 221  Bestrophin  The Anion Channel-forming Bestrophin (Bestroph...
# 222  Bestrophin  The Anion Channel-forming Bestrophin (Bestroph...
# 223     Mot/Exb  The H+- or Na+-translocating Bacterial Flagell...
# 224     Mot/Exb  The H+- or Na+-translocating Bacterial Flagell...
# 225     Mot/Exb  The H+- or Na+-translocating Bacterial Flagell...
# 226     Mot/Exb  The H+- or Na+-translocating Bacterial Flagell...
# 227     Mot/Exb  The H+- or Na+-translocating Bacterial Flagell...
# 228     Mot/Exb  The H+- or Na+-translocating Bacterial Flagell...
# 229     Mot/Exb  The H+- or Na+-translocating Bacterial Flagell...
# 230     Mot/Exb  The H+- or Na+-translocating Bacterial Flagell...
# 231        MscS  The Small Conductance Mechanosensitive Ion Cha...
# 232        MscS  The Small Conductance Mechanosensitive Ion Cha...
# 233         VIC    The Voltage-gated Ion Channel (VIC) Superfamily
# 234        FeoB              The Ferrous Iron Uptake (FeoB) Family
# 235         FeT     The Low Affinity Fe2+ Transporter (FeT) Family
# 236         HCC                         The HlyC/CorC (HCC) Family
# 237        MgtE               The Mg2+ Transporter-E (MgtE) Family
# 238        MgtE               The Mg2+ Transporter-E (MgtE) Family
# 239        UBS1       The Unknown BART Superfamily-1 (UBS1) Family
# 240        YggT  The YggT or Fanciful K+ Uptake-B (FkuB; YggT) ...
# 241         OOP                   The OmpA-OmpF Porin (OOP) Family
#
#           TransporterClass TCNumber
# 0            ATP-Dependent    3.A.1
# 1            ATP-Dependent    3.A.1
# 2            ATP-Dependent    3.A.1
# 3            ATP-Dependent    3.A.1
# 4            ATP-Dependent    3.A.1
# 5            ATP-Dependent    3.A.1
# 6            ATP-Dependent    3.A.1
# 7            ATP-Dependent    3.A.1
# 8            ATP-Dependent    3.A.1
# 9            ATP-Dependent    3.A.1
# 10           ATP-Dependent    3.A.1
# 11           ATP-Dependent    3.A.1
# 12           ATP-Dependent    3.A.1
# 13           ATP-Dependent    3.A.1
# 14           ATP-Dependent    3.A.1
# 15           ATP-Dependent    3.A.1
# 16           ATP-Dependent    3.A.1
# 17           ATP-Dependent    3.A.1
# 18           ATP-Dependent    3.A.1
# 19           ATP-Dependent    3.A.1
# 20           ATP-Dependent    3.A.1
# 21           ATP-Dependent    3.A.1
# 22           ATP-Dependent    3.A.1
# 23           ATP-Dependent    3.A.1
# 24           ATP-Dependent    3.A.1
# 25           ATP-Dependent    3.A.1
# 26           ATP-Dependent    3.A.1
# 27           ATP-Dependent    3.A.1
# 28           ATP-Dependent    3.A.1
# 29           ATP-Dependent    3.A.1
# ..                     ...      ...
# 212  Secondary Transporter   2.A.38
# 213  Secondary Transporter    2.A.5
# 214  Secondary Transporter    2.A.5
# 215  Secondary Transporter    2.A.5
# 216  Secondary Transporter    2.A.5
# 217           Ion Channels   1.A.11
# 218           Ion Channels   1.A.11
# 219           Ion Channels   1.A.11
# 220           Ion Channels   1.A.11
# 221           Ion Channels   1.A.46
# 222           Ion Channels   1.A.46
# 223           Ion Channels   1.A.30
# 224           Ion Channels   1.A.30
# 225           Ion Channels   1.A.30
# 226           Ion Channels   1.A.30
# 227           Ion Channels   1.A.30
# 228           Ion Channels   1.A.30
# 229           Ion Channels   1.A.30
# 230           Ion Channels   1.A.30
# 231           Ion Channels   1.A.23
# 232           Ion Channels   1.A.23
# 233           Ion Channels    1.A.1
# 234           Unclassified    9.A.8
# 235           Unclassified    9.A.9
# 236           Unclassified   9.A.40
# 237           Unclassified   9.A.19
# 238           Unclassified   9.A.19
# 239           Unclassified   9.A.43
# 240           Unclassified    9.A.4
# 241  Outer Membrane Porins    1.B.6
#
# [242 rows x 7 columns]

# %%
result = pd.merge(TDB_raw, PSORT_reduced, on='ID', how='inner')

# %%
result = result.loc[result['Substrate']!='Unclassified']

# %%
result
# Out:
#           ID                                       Substrate          Subtype  \
# 0    MCA0093                                    daunorubicin          binding
# 1    MCA0127                                            heme          binding
# 2    MCA0134                                     lipoprotein          binding
# 3    MCA0135                                   cell division         membrane
# 4    MCA0168                                         lipid A          binding
# 6    MCA0173                                    D-methionine          binding
# 7    MCA0174                               toluene tolerance         membrane
# 9    MCA0555                                    daunorubicin          binding
# 10   MCA0557                                       multidrug         membrane
# 11   MCA0609                                            heme          binding
# 12   MCA0625                                    daunorubicin          binding
# 13   MCA0626                           polysaccharide export         membrane
# 14   MCA0742                                    daunorubicin          binding
# 15   MCA0840     amino acid (glutamine/glutamate/aspartate?)  binding protein
# 16   MCA0869                           spermidine/putrescine  binding protein
# 17   MCA0870                           spermidine/putrescine         membrane
# 18   MCA0871                           spermidine/putrescine         membrane
# 19   MCA0872                                       polyamine          binding
# 20   MCA0894                                         lipid A          binding
# 21   MCA0899                             sulfate/thiosulfate          binding
# 22   MCA0953                                     heme export         membrane
# 23   MCA0954                                            heme          binding
# 24   MCA0964                                         lipid A          binding
# 25   MCA0990                 ? (Fe-S assembly/SufBCD system)         membrane
# 26   MCA0991                 ? (Fe-S assembly/SufBCD system)              ABC
# 27   MCA0992                 ? (Fe-S assembly/SufBCD system)         membrane
# 28   MCA1072                                       phosphate         membrane
# 29   MCA1073                                       phosphate         membrane
# 30   MCA1074                                       phosphate          binding
# 31   MCA1181                                         sulfate          binding
# ..       ...                                             ...              ...
# 191  MCA2324  cobalt/zinc/cadmium ion efflux (HME subfamily)              HME
# 192  MCA2720  cobalt/zinc/cadmium ion efflux (HME subfamily)              HME
# 193  MCA2758       multidrug/solvent efflux (HAE3 subfamily)             HAE3
# 194  MCA2815       multidrug/solvent efflux (HAE1 subfamily)             HAE1
# 195  MCA2214                    sodium ion:proline symporter              NaN
# 196  MCA2473                    sodium ion:proline symporter              NaN
# 197  MCA2847                    sodium ion:proline symporter              NaN
# 198  MCA1443                                         sulfate              NaN
# 199  MCA2472                                         sulfate              NaN
# 200  MCA1486                                  protein export              NaN
# 201  MCA1487                                  protein export              NaN
# 202  MCA1488                                  protein export              NaN
# 204  MCA2041                            potassium ion uptake              NaN
# 205  MCA0974                                        zinc ion              NaN
# 206  MCA0975                                        zinc ion              NaN
# 207  MCA1728                                        zinc ion              NaN
# 208  MCA2417                                        zinc ion              NaN
# 209  MCA0268                                        ammonium              NaN
# 210  MCA0490                                        ammonium              NaN
# 211  MCA1581                                        ammonium              NaN
# 212  MCA2136                                        ammonium              NaN
# 213  MCA2692                        Bestrophin anion channel              NaN
# 214  MCA3057                        Bestrophin anion channel              NaN
# 223  MCA1632  small-conductance mechanosensitive ion channel              NaN
# 224  MCA2608  small-conductance mechanosensitive ion channel              NaN
# 225  MCA0647                           potassium ion channel              NaN
# 226  MCA1097                                     ferrous ion              NaN
# 228  MCA1250                      hemolysin C (HlyC) homolog              NaN
# 229  MCA0108                                   magnesium ion              NaN
# 230  MCA2402                                   magnesium ion              NaN
#
#          Family                                         FamilyName  \
# 0           ABC         The ATP-binding Cassette (ABC) Superfamily
# 1           ABC         The ATP-binding Cassette (ABC) Superfamily
# 2           ABC         The ATP-binding Cassette (ABC) Superfamily
# 3           ABC         The ATP-binding Cassette (ABC) Superfamily
# 4           ABC         The ATP-binding Cassette (ABC) Superfamily
# 6           ABC         The ATP-binding Cassette (ABC) Superfamily
# 7           ABC         The ATP-binding Cassette (ABC) Superfamily
# 9           ABC         The ATP-binding Cassette (ABC) Superfamily
# 10          ABC         The ATP-binding Cassette (ABC) Superfamily
# 11          ABC         The ATP-binding Cassette (ABC) Superfamily
# 12          ABC         The ATP-binding Cassette (ABC) Superfamily
# 13          ABC         The ATP-binding Cassette (ABC) Superfamily
# 14          ABC         The ATP-binding Cassette (ABC) Superfamily
# 15          ABC         The ATP-binding Cassette (ABC) Superfamily
# 16          ABC         The ATP-binding Cassette (ABC) Superfamily
# 17          ABC         The ATP-binding Cassette (ABC) Superfamily
# 18          ABC         The ATP-binding Cassette (ABC) Superfamily
# 19          ABC         The ATP-binding Cassette (ABC) Superfamily
# 20          ABC         The ATP-binding Cassette (ABC) Superfamily
# 21          ABC         The ATP-binding Cassette (ABC) Superfamily
# 22          ABC         The ATP-binding Cassette (ABC) Superfamily
# 23          ABC         The ATP-binding Cassette (ABC) Superfamily
# 24          ABC         The ATP-binding Cassette (ABC) Superfamily
# 25          ABC         The ATP-binding Cassette (ABC) Superfamily
# 26          ABC         The ATP-binding Cassette (ABC) Superfamily
# 27          ABC         The ATP-binding Cassette (ABC) Superfamily
# 28          ABC         The ATP-binding Cassette (ABC) Superfamily
# 29          ABC         The ATP-binding Cassette (ABC) Superfamily
# 30          ABC         The ATP-binding Cassette (ABC) Superfamily
# 31          ABC         The ATP-binding Cassette (ABC) Superfamily
# ..          ...                                                ...
# 191         RND  The Resistance-Nodulation-Cell Division (RND) ...
# 192         RND  The Resistance-Nodulation-Cell Division (RND) ...
# 193         RND  The Resistance-Nodulation-Cell Division (RND) ...
# 194         RND  The Resistance-Nodulation-Cell Division (RND) ...
# 195         SSS           The Solute:Sodium Symporter (SSS) Family
# 196         SSS           The Solute:Sodium Symporter (SSS) Family
# 197         SSS           The Solute:Sodium Symporter (SSS) Family
# 198        SulP                 The Sulfate Permease (SulP) Family
# 199        SulP                 The Sulfate Permease (SulP) Family
# 200         Tat           The Twin Arginine Targeting (Tat) Family
# 201         Tat           The Twin Arginine Targeting (Tat) Family
# 202         Tat           The Twin Arginine Targeting (Tat) Family
# 204         Trk                    The K+ Transporter (Trk) Family
# 205         ZIP  The Zinc (Zn2+)-Iron (Fe2+) Permease (ZIP) Family
# 206         ZIP  The Zinc (Zn2+)-Iron (Fe2+) Permease (ZIP) Family
# 207         ZIP  The Zinc (Zn2+)-Iron (Fe2+) Permease (ZIP) Family
# 208         ZIP  The Zinc (Zn2+)-Iron (Fe2+) Permease (ZIP) Family
# 209         Amt       The Ammonia Transporter Channel (Amt) Family
# 210         Amt       The Ammonia Transporter Channel (Amt) Family
# 211         Amt       The Ammonia Transporter Channel (Amt) Family
# 212         Amt       The Ammonia Transporter Channel (Amt) Family
# 213  Bestrophin  The Anion Channel-forming Bestrophin (Bestroph...
# 214  Bestrophin  The Anion Channel-forming Bestrophin (Bestroph...
# 223        MscS  The Small Conductance Mechanosensitive Ion Cha...
# 224        MscS  The Small Conductance Mechanosensitive Ion Cha...
# 225         VIC    The Voltage-gated Ion Channel (VIC) Superfamily
# 226        FeoB              The Ferrous Iron Uptake (FeoB) Family
# 228         HCC                         The HlyC/CorC (HCC) Family
# 229        MgtE               The Mg2+ Transporter-E (MgtE) Family
# 230        MgtE               The Mg2+ Transporter-E (MgtE) Family
#
#           TransporterClass TCNumber  Cytoplasmic_Score  \
# 0            ATP-Dependent    3.A.1               2.11
# 1            ATP-Dependent    3.A.1               9.26
# 2            ATP-Dependent    3.A.1               2.11
# 3            ATP-Dependent    3.A.1               0.00
# 4            ATP-Dependent    3.A.1               0.15
# 6            ATP-Dependent    3.A.1               0.00
# 7            ATP-Dependent    3.A.1               0.00
# 9            ATP-Dependent    3.A.1               0.00
# 10           ATP-Dependent    3.A.1               0.00
# 11           ATP-Dependent    3.A.1               9.97
# 12           ATP-Dependent    3.A.1               2.11
# 13           ATP-Dependent    3.A.1               0.00
# 14           ATP-Dependent    3.A.1               9.12
# 15           ATP-Dependent    3.A.1               0.00
# 16           ATP-Dependent    3.A.1               0.00
# 17           ATP-Dependent    3.A.1               0.00
# 18           ATP-Dependent    3.A.1               0.00
# 19           ATP-Dependent    3.A.1               0.01
# 20           ATP-Dependent    3.A.1               0.00
# 21           ATP-Dependent    3.A.1               0.00
# 22           ATP-Dependent    3.A.1               0.00
# 23           ATP-Dependent    3.A.1               2.11
# 24           ATP-Dependent    3.A.1               0.00
# 25           ATP-Dependent    3.A.1               8.96
# 26           ATP-Dependent    3.A.1               9.97
# 27           ATP-Dependent    3.A.1               8.96
# 28           ATP-Dependent    3.A.1               0.00
# 29           ATP-Dependent    3.A.1               0.00
# 30           ATP-Dependent    3.A.1               2.11
# 31           ATP-Dependent    3.A.1               2.11
# ..                     ...      ...                ...
# 191  Secondary Transporter    2.A.6               0.00
# 192  Secondary Transporter    2.A.6               0.00
# 193  Secondary Transporter    2.A.6               0.00
# 194  Secondary Transporter    2.A.6               0.00
# 195  Secondary Transporter   2.A.21               0.00
# 196  Secondary Transporter   2.A.21               2.11
# 197  Secondary Transporter   2.A.21               0.00
# 198  Secondary Transporter   2.A.53               0.00
# 199  Secondary Transporter   2.A.53               0.00
# 200  Secondary Transporter   2.A.64               0.00
# 201  Secondary Transporter   2.A.64               0.15
# 202  Secondary Transporter   2.A.64               0.15
# 204  Secondary Transporter   2.A.38               0.00
# 205  Secondary Transporter    2.A.5               0.00
# 206  Secondary Transporter    2.A.5               0.00
# 207  Secondary Transporter    2.A.5               0.00
# 208  Secondary Transporter    2.A.5               0.00
# 209           Ion Channels   1.A.11               0.00
# 210           Ion Channels   1.A.11               0.00
# 211           Ion Channels   1.A.11               0.00
# 212           Ion Channels   1.A.11               0.00
# 213           Ion Channels   1.A.46               0.68
# 214           Ion Channels   1.A.46               0.04
# 223           Ion Channels   1.A.23               0.00
# 224           Ion Channels   1.A.23               0.00
# 225           Ion Channels    1.A.1               0.00
# 226           Unclassified    9.A.8               0.00
# 228           Unclassified   9.A.40               2.11
# 229           Unclassified   9.A.19               0.00
# 230           Unclassified   9.A.19               0.00
#
#      CytoplasmicMembrane_Score  OuterMembrane_Score  Extracellular_Score  \
# 0                         7.88                 0.00                 0.00
# 1                         0.24                 0.01                 0.01
# 2                         7.88                 0.00                 0.00
# 3                        10.00                 0.00                 0.00
# 4                         9.82                 0.01                 0.01
# 6                        10.00                 0.00                 0.00
# 7                        10.00                 0.00                 0.00
# 9                        10.00                 0.00                 0.00
# 10                       10.00                 0.00                 0.00
# 11                        0.01                 0.00                 0.00
# 12                        7.88                 0.00                 0.00
# 13                       10.00                 0.00                 0.00
# 14                        0.88                 0.00                 0.00
# 15                        0.12                 0.00                 0.11
# 16                        0.12                 0.00                 0.11
# 17                       10.00                 0.00                 0.00
# 18                       10.00                 0.00                 0.00
# 19                        9.99                 0.00                 0.00
# 20                       10.00                 0.00                 0.00
# 21                        0.00                 0.00                 0.00
# 22                       10.00                 0.00                 0.00
# 23                        7.88                 0.00                 0.00
# 24                       10.00                 0.00                 0.00
# 25                        0.51                 0.01                 0.26
# 26                        0.01                 0.00                 0.00
# 27                        0.51                 0.01                 0.26
# 28                       10.00                 0.00                 0.00
# 29                       10.00                 0.00                 0.00
# 30                        7.88                 0.00                 0.00
# 31                        7.88                 0.00                 0.00
# ..                         ...                  ...                  ...
# 191                      10.00                 0.00                 0.00
# 192                      10.00                 0.00                 0.00
# 193                      10.00                 0.00                 0.00
# 194                      10.00                 0.00                 0.00
# 195                      10.00                 0.00                 0.00
# 196                       7.88                 0.00                 0.00
# 197                      10.00                 0.00                 0.00
# 198                      10.00                 0.00                 0.00
# 199                      10.00                 0.00                 0.00
# 200                      10.00                 0.00                 0.00
# 201                       9.82                 0.01                 0.01
# 202                       9.82                 0.01                 0.01
# 204                      10.00                 0.00                 0.00
# 205                      10.00                 0.00                 0.00
# 206                      10.00                 0.00                 0.00
# 207                      10.00                 0.00                 0.00
# 208                      10.00                 0.00                 0.00
# 209                      10.00                 0.00                 0.00
# 210                      10.00                 0.00                 0.00
# 211                      10.00                 0.00                 0.00
# 212                      10.00                 0.00                 0.00
# 213                       9.16                 0.00                 0.12
# 214                       9.46                 0.18                 0.25
# 223                      10.00                 0.00                 0.00
# 224                      10.00                 0.00                 0.00
# 225                      10.00                 0.00                 0.00
# 226                      10.00                 0.00                 0.00
# 228                       7.88                 0.00                 0.00
# 229                      10.00                 0.00                 0.00
# 230                      10.00                 0.00                 0.00
#
#       Final_Localization  Final_Score
# 0    CytoplasmicMembrane         7.88
# 1            Cytoplasmic         9.26
# 2    CytoplasmicMembrane         7.88
# 3    CytoplasmicMembrane        10.00
# 4    CytoplasmicMembrane         9.82
# 6    CytoplasmicMembrane        10.00
# 7    CytoplasmicMembrane        10.00
# 9    CytoplasmicMembrane        10.00
# 10   CytoplasmicMembrane        10.00
# 11           Cytoplasmic         9.97
# 12   CytoplasmicMembrane         7.88
# 13   CytoplasmicMembrane        10.00
# 14           Cytoplasmic         9.12
# 15           Periplasmic         9.76
# 16           Periplasmic         9.76
# 17   CytoplasmicMembrane        10.00
# 18   CytoplasmicMembrane        10.00
# 19   CytoplasmicMembrane         9.99
# 20   CytoplasmicMembrane        10.00
# 21           Periplasmic        10.00
# 22   CytoplasmicMembrane        10.00
# 23   CytoplasmicMembrane         7.88
# 24   CytoplasmicMembrane        10.00
# 25           Cytoplasmic         8.96
# 26           Cytoplasmic         9.97
# 27           Cytoplasmic         8.96
# 28   CytoplasmicMembrane        10.00
# 29   CytoplasmicMembrane        10.00
# 30   CytoplasmicMembrane         7.88
# 31   CytoplasmicMembrane         7.88
# ..                   ...          ...
# 191  CytoplasmicMembrane        10.00
# 192  CytoplasmicMembrane        10.00
# 193  CytoplasmicMembrane        10.00
# 194  CytoplasmicMembrane        10.00
# 195  CytoplasmicMembrane        10.00
# 196  CytoplasmicMembrane         7.88
# 197  CytoplasmicMembrane        10.00
# 198  CytoplasmicMembrane        10.00
# 199  CytoplasmicMembrane        10.00
# 200  CytoplasmicMembrane        10.00
# 201  CytoplasmicMembrane         9.82
# 202  CytoplasmicMembrane         9.82
# 204  CytoplasmicMembrane        10.00
# 205  CytoplasmicMembrane        10.00
# 206  CytoplasmicMembrane        10.00
# 207  CytoplasmicMembrane        10.00
# 208  CytoplasmicMembrane        10.00
# 209  CytoplasmicMembrane        10.00
# 210  CytoplasmicMembrane        10.00
# 211  CytoplasmicMembrane        10.00
# 212  CytoplasmicMembrane        10.00
# 213  CytoplasmicMembrane         9.16
# 214  CytoplasmicMembrane         9.46
# 223  CytoplasmicMembrane        10.00
# 224  CytoplasmicMembrane        10.00
# 225  CytoplasmicMembrane        10.00
# 226  CytoplasmicMembrane        10.00
# 228  CytoplasmicMembrane         7.88
# 229  CytoplasmicMembrane        10.00
# 230  CytoplasmicMembrane        10.00
#
# [211 rows x 13 columns]

# %%
full_central_map = pd.read_csv('/Users/clie/Desktop/EFPro2/Genome/UniProtExport/FullCentralMappingOriginalGenBank.csv')

# %%
full_central_map = full_central_map[['Unnamed: 0','Common Name (Long)','EColiGeneCodeGenbank','UniProtKB']]

# %%
full_central_map.rename(columns={'Unnamed: 0':'ID'}, inplace=True)

# %%
result2 = pd.merge(result, full_central_map, on='ID', how='inner')

# %%
result2 = result2.set_index('ID')

# %%
result2
# Out:
#                                               Substrate          Subtype  \
# ID
# MCA0093                                    daunorubicin          binding
# MCA0127                                            heme          binding
# MCA0134                                     lipoprotein          binding
# MCA0135                                   cell division         membrane
# MCA0168                                         lipid A          binding
# MCA0173                                    D-methionine          binding
# MCA0174                               toluene tolerance         membrane
# MCA0555                                    daunorubicin          binding
# MCA0557                                       multidrug         membrane
# MCA0609                                            heme          binding
# MCA0625                                    daunorubicin          binding
# MCA0626                           polysaccharide export         membrane
# MCA0742                                    daunorubicin          binding
# MCA0840     amino acid (glutamine/glutamate/aspartate?)  binding protein
# MCA0869                           spermidine/putrescine  binding protein
# MCA0870                           spermidine/putrescine         membrane
# MCA0871                           spermidine/putrescine         membrane
# MCA0872                                       polyamine          binding
# MCA0894                                         lipid A          binding
# MCA0899                             sulfate/thiosulfate          binding
# MCA0953                                     heme export         membrane
# MCA0954                                            heme          binding
# MCA0964                                         lipid A          binding
# MCA0990                 ? (Fe-S assembly/SufBCD system)         membrane
# MCA0991                 ? (Fe-S assembly/SufBCD system)              ABC
# MCA0992                 ? (Fe-S assembly/SufBCD system)         membrane
# MCA1072                                       phosphate         membrane
# MCA1073                                       phosphate         membrane
# MCA1074                                       phosphate          binding
# MCA1181                                         sulfate          binding
# ...                                                 ...              ...
# MCA2324  cobalt/zinc/cadmium ion efflux (HME subfamily)              HME
# MCA2720  cobalt/zinc/cadmium ion efflux (HME subfamily)              HME
# MCA2758       multidrug/solvent efflux (HAE3 subfamily)             HAE3
# MCA2815       multidrug/solvent efflux (HAE1 subfamily)             HAE1
# MCA2214                    sodium ion:proline symporter              NaN
# MCA2473                    sodium ion:proline symporter              NaN
# MCA2847                    sodium ion:proline symporter              NaN
# MCA1443                                         sulfate              NaN
# MCA2472                                         sulfate              NaN
# MCA1486                                  protein export              NaN
# MCA1487                                  protein export              NaN
# MCA1488                                  protein export              NaN
# MCA2041                            potassium ion uptake              NaN
# MCA0974                                        zinc ion              NaN
# MCA0975                                        zinc ion              NaN
# MCA1728                                        zinc ion              NaN
# MCA2417                                        zinc ion              NaN
# MCA0268                                        ammonium              NaN
# MCA0490                                        ammonium              NaN
# MCA1581                                        ammonium              NaN
# MCA2136                                        ammonium              NaN
# MCA2692                        Bestrophin anion channel              NaN
# MCA3057                        Bestrophin anion channel              NaN
# MCA1632  small-conductance mechanosensitive ion channel              NaN
# MCA2608  small-conductance mechanosensitive ion channel              NaN
# MCA0647                           potassium ion channel              NaN
# MCA1097                                     ferrous ion              NaN
# MCA1250                      hemolysin C (HlyC) homolog              NaN
# MCA0108                                   magnesium ion              NaN
# MCA2402                                   magnesium ion              NaN
#
#              Family                                         FamilyName  \
# ID
# MCA0093         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0127         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0134         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0135         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0168         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0173         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0174         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0555         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0557         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0609         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0625         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0626         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0742         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0840         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0869         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0870         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0871         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0872         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0894         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0899         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0953         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0954         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0964         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0990         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0991         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA0992         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA1072         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA1073         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA1074         ABC         The ATP-binding Cassette (ABC) Superfamily
# MCA1181         ABC         The ATP-binding Cassette (ABC) Superfamily
# ...             ...                                                ...
# MCA2324         RND  The Resistance-Nodulation-Cell Division (RND) ...
# MCA2720         RND  The Resistance-Nodulation-Cell Division (RND) ...
# MCA2758         RND  The Resistance-Nodulation-Cell Division (RND) ...
# MCA2815         RND  The Resistance-Nodulation-Cell Division (RND) ...
# MCA2214         SSS           The Solute:Sodium Symporter (SSS) Family
# MCA2473         SSS           The Solute:Sodium Symporter (SSS) Family
# MCA2847         SSS           The Solute:Sodium Symporter (SSS) Family
# MCA1443        SulP                 The Sulfate Permease (SulP) Family
# MCA2472        SulP                 The Sulfate Permease (SulP) Family
# MCA1486         Tat           The Twin Arginine Targeting (Tat) Family
# MCA1487         Tat           The Twin Arginine Targeting (Tat) Family
# MCA1488         Tat           The Twin Arginine Targeting (Tat) Family
# MCA2041         Trk                    The K+ Transporter (Trk) Family
# MCA0974         ZIP  The Zinc (Zn2+)-Iron (Fe2+) Permease (ZIP) Family
# MCA0975         ZIP  The Zinc (Zn2+)-Iron (Fe2+) Permease (ZIP) Family
# MCA1728         ZIP  The Zinc (Zn2+)-Iron (Fe2+) Permease (ZIP) Family
# MCA2417         ZIP  The Zinc (Zn2+)-Iron (Fe2+) Permease (ZIP) Family
# MCA0268         Amt       The Ammonia Transporter Channel (Amt) Family
# MCA0490         Amt       The Ammonia Transporter Channel (Amt) Family
# MCA1581         Amt       The Ammonia Transporter Channel (Amt) Family
# MCA2136         Amt       The Ammonia Transporter Channel (Amt) Family
# MCA2692  Bestrophin  The Anion Channel-forming Bestrophin (Bestroph...
# MCA3057  Bestrophin  The Anion Channel-forming Bestrophin (Bestroph...
# MCA1632        MscS  The Small Conductance Mechanosensitive Ion Cha...
# MCA2608        MscS  The Small Conductance Mechanosensitive Ion Cha...
# MCA0647         VIC    The Voltage-gated Ion Channel (VIC) Superfamily
# MCA1097        FeoB              The Ferrous Iron Uptake (FeoB) Family
# MCA1250         HCC                         The HlyC/CorC (HCC) Family
# MCA0108        MgtE               The Mg2+ Transporter-E (MgtE) Family
# MCA2402        MgtE               The Mg2+ Transporter-E (MgtE) Family
#
#               TransporterClass TCNumber  Cytoplasmic_Score  \
# ID
# MCA0093          ATP-Dependent    3.A.1               2.11
# MCA0127          ATP-Dependent    3.A.1               9.26
# MCA0134          ATP-Dependent    3.A.1               2.11
# MCA0135          ATP-Dependent    3.A.1               0.00
# MCA0168          ATP-Dependent    3.A.1               0.15
# MCA0173          ATP-Dependent    3.A.1               0.00
# MCA0174          ATP-Dependent    3.A.1               0.00
# MCA0555          ATP-Dependent    3.A.1               0.00
# MCA0557          ATP-Dependent    3.A.1               0.00
# MCA0609          ATP-Dependent    3.A.1               9.97
# MCA0625          ATP-Dependent    3.A.1               2.11
# MCA0626          ATP-Dependent    3.A.1               0.00
# MCA0742          ATP-Dependent    3.A.1               9.12
# MCA0840          ATP-Dependent    3.A.1               0.00
# MCA0869          ATP-Dependent    3.A.1               0.00
# MCA0870          ATP-Dependent    3.A.1               0.00
# MCA0871          ATP-Dependent    3.A.1               0.00
# MCA0872          ATP-Dependent    3.A.1               0.01
# MCA0894          ATP-Dependent    3.A.1               0.00
# MCA0899          ATP-Dependent    3.A.1               0.00
# MCA0953          ATP-Dependent    3.A.1               0.00
# MCA0954          ATP-Dependent    3.A.1               2.11
# MCA0964          ATP-Dependent    3.A.1               0.00
# MCA0990          ATP-Dependent    3.A.1               8.96
# MCA0991          ATP-Dependent    3.A.1               9.97
# MCA0992          ATP-Dependent    3.A.1               8.96
# MCA1072          ATP-Dependent    3.A.1               0.00
# MCA1073          ATP-Dependent    3.A.1               0.00
# MCA1074          ATP-Dependent    3.A.1               2.11
# MCA1181          ATP-Dependent    3.A.1               2.11
# ...                        ...      ...                ...
# MCA2324  Secondary Transporter    2.A.6               0.00
# MCA2720  Secondary Transporter    2.A.6               0.00
# MCA2758  Secondary Transporter    2.A.6               0.00
# MCA2815  Secondary Transporter    2.A.6               0.00
# MCA2214  Secondary Transporter   2.A.21               0.00
# MCA2473  Secondary Transporter   2.A.21               2.11
# MCA2847  Secondary Transporter   2.A.21               0.00
# MCA1443  Secondary Transporter   2.A.53               0.00
# MCA2472  Secondary Transporter   2.A.53               0.00
# MCA1486  Secondary Transporter   2.A.64               0.00
# MCA1487  Secondary Transporter   2.A.64               0.15
# MCA1488  Secondary Transporter   2.A.64               0.15
# MCA2041  Secondary Transporter   2.A.38               0.00
# MCA0974  Secondary Transporter    2.A.5               0.00
# MCA0975  Secondary Transporter    2.A.5               0.00
# MCA1728  Secondary Transporter    2.A.5               0.00
# MCA2417  Secondary Transporter    2.A.5               0.00
# MCA0268           Ion Channels   1.A.11               0.00
# MCA0490           Ion Channels   1.A.11               0.00
# MCA1581           Ion Channels   1.A.11               0.00
# MCA2136           Ion Channels   1.A.11               0.00
# MCA2692           Ion Channels   1.A.46               0.68
# MCA3057           Ion Channels   1.A.46               0.04
# MCA1632           Ion Channels   1.A.23               0.00
# MCA2608           Ion Channels   1.A.23               0.00
# MCA0647           Ion Channels    1.A.1               0.00
# MCA1097           Unclassified    9.A.8               0.00
# MCA1250           Unclassified   9.A.40               2.11
# MCA0108           Unclassified   9.A.19               0.00
# MCA2402           Unclassified   9.A.19               0.00
#
#          CytoplasmicMembrane_Score  OuterMembrane_Score  Extracellular_Score  \
# ID
# MCA0093                       7.88                 0.00                 0.00
# MCA0127                       0.24                 0.01                 0.01
# MCA0134                       7.88                 0.00                 0.00
# MCA0135                      10.00                 0.00                 0.00
# MCA0168                       9.82                 0.01                 0.01
# MCA0173                      10.00                 0.00                 0.00
# MCA0174                      10.00                 0.00                 0.00
# MCA0555                      10.00                 0.00                 0.00
# MCA0557                      10.00                 0.00                 0.00
# MCA0609                       0.01                 0.00                 0.00
# MCA0625                       7.88                 0.00                 0.00
# MCA0626                      10.00                 0.00                 0.00
# MCA0742                       0.88                 0.00                 0.00
# MCA0840                       0.12                 0.00                 0.11
# MCA0869                       0.12                 0.00                 0.11
# MCA0870                      10.00                 0.00                 0.00
# MCA0871                      10.00                 0.00                 0.00
# MCA0872                       9.99                 0.00                 0.00
# MCA0894                      10.00                 0.00                 0.00
# MCA0899                       0.00                 0.00                 0.00
# MCA0953                      10.00                 0.00                 0.00
# MCA0954                       7.88                 0.00                 0.00
# MCA0964                      10.00                 0.00                 0.00
# MCA0990                       0.51                 0.01                 0.26
# MCA0991                       0.01                 0.00                 0.00
# MCA0992                       0.51                 0.01                 0.26
# MCA1072                      10.00                 0.00                 0.00
# MCA1073                      10.00                 0.00                 0.00
# MCA1074                       7.88                 0.00                 0.00
# MCA1181                       7.88                 0.00                 0.00
# ...                            ...                  ...                  ...
# MCA2324                      10.00                 0.00                 0.00
# MCA2720                      10.00                 0.00                 0.00
# MCA2758                      10.00                 0.00                 0.00
# MCA2815                      10.00                 0.00                 0.00
# MCA2214                      10.00                 0.00                 0.00
# MCA2473                       7.88                 0.00                 0.00
# MCA2847                      10.00                 0.00                 0.00
# MCA1443                      10.00                 0.00                 0.00
# MCA2472                      10.00                 0.00                 0.00
# MCA1486                      10.00                 0.00                 0.00
# MCA1487                       9.82                 0.01                 0.01
# MCA1488                       9.82                 0.01                 0.01
# MCA2041                      10.00                 0.00                 0.00
# MCA0974                      10.00                 0.00                 0.00
# MCA0975                      10.00                 0.00                 0.00
# MCA1728                      10.00                 0.00                 0.00
# MCA2417                      10.00                 0.00                 0.00
# MCA0268                      10.00                 0.00                 0.00
# MCA0490                      10.00                 0.00                 0.00
# MCA1581                      10.00                 0.00                 0.00
# MCA2136                      10.00                 0.00                 0.00
# MCA2692                       9.16                 0.00                 0.12
# MCA3057                       9.46                 0.18                 0.25
# MCA1632                      10.00                 0.00                 0.00
# MCA2608                      10.00                 0.00                 0.00
# MCA0647                      10.00                 0.00                 0.00
# MCA1097                      10.00                 0.00                 0.00
# MCA1250                       7.88                 0.00                 0.00
# MCA0108                      10.00                 0.00                 0.00
# MCA2402                      10.00                 0.00                 0.00
#
#           Final_Localization  Final_Score  \
# ID
# MCA0093  CytoplasmicMembrane         7.88
# MCA0127          Cytoplasmic         9.26
# MCA0134  CytoplasmicMembrane         7.88
# MCA0135  CytoplasmicMembrane        10.00
# MCA0168  CytoplasmicMembrane         9.82
# MCA0173  CytoplasmicMembrane        10.00
# MCA0174  CytoplasmicMembrane        10.00
# MCA0555  CytoplasmicMembrane        10.00
# MCA0557  CytoplasmicMembrane        10.00
# MCA0609          Cytoplasmic         9.97
# MCA0625  CytoplasmicMembrane         7.88
# MCA0626  CytoplasmicMembrane        10.00
# MCA0742          Cytoplasmic         9.12
# MCA0840          Periplasmic         9.76
# MCA0869          Periplasmic         9.76
# MCA0870  CytoplasmicMembrane        10.00
# MCA0871  CytoplasmicMembrane        10.00
# MCA0872  CytoplasmicMembrane         9.99
# MCA0894  CytoplasmicMembrane        10.00
# MCA0899          Periplasmic        10.00
# MCA0953  CytoplasmicMembrane        10.00
# MCA0954  CytoplasmicMembrane         7.88
# MCA0964  CytoplasmicMembrane        10.00
# MCA0990          Cytoplasmic         8.96
# MCA0991          Cytoplasmic         9.97
# MCA0992          Cytoplasmic         8.96
# MCA1072  CytoplasmicMembrane        10.00
# MCA1073  CytoplasmicMembrane        10.00
# MCA1074  CytoplasmicMembrane         7.88
# MCA1181  CytoplasmicMembrane         7.88
# ...                      ...          ...
# MCA2324  CytoplasmicMembrane        10.00
# MCA2720  CytoplasmicMembrane        10.00
# MCA2758  CytoplasmicMembrane        10.00
# MCA2815  CytoplasmicMembrane        10.00
# MCA2214  CytoplasmicMembrane        10.00
# MCA2473  CytoplasmicMembrane         7.88
# MCA2847  CytoplasmicMembrane        10.00
# MCA1443  CytoplasmicMembrane        10.00
# MCA2472  CytoplasmicMembrane        10.00
# MCA1486  CytoplasmicMembrane        10.00
# MCA1487  CytoplasmicMembrane         9.82
# MCA1488  CytoplasmicMembrane         9.82
# MCA2041  CytoplasmicMembrane        10.00
# MCA0974  CytoplasmicMembrane        10.00
# MCA0975  CytoplasmicMembrane        10.00
# MCA1728  CytoplasmicMembrane        10.00
# MCA2417  CytoplasmicMembrane        10.00
# MCA0268  CytoplasmicMembrane        10.00
# MCA0490  CytoplasmicMembrane        10.00
# MCA1581  CytoplasmicMembrane        10.00
# MCA2136  CytoplasmicMembrane        10.00
# MCA2692  CytoplasmicMembrane         9.16
# MCA3057  CytoplasmicMembrane         9.46
# MCA1632  CytoplasmicMembrane        10.00
# MCA2608  CytoplasmicMembrane        10.00
# MCA0647  CytoplasmicMembrane        10.00
# MCA1097  CytoplasmicMembrane        10.00
# MCA1250  CytoplasmicMembrane         7.88
# MCA0108  CytoplasmicMembrane        10.00
# MCA2402  CytoplasmicMembrane        10.00
#
#                                         Common Name (Long)  \
# ID
# MCA0093                                                NaN
# MCA0127                                                NaN
# MCA0134                                                NaN
# MCA0135                                                NaN
# MCA0168                                                NaN
# MCA0173                                                NaN
# MCA0174                                                NaN
# MCA0555                                                NaN
# MCA0557                                                NaN
# MCA0609                                                NaN
# MCA0625                                                NaN
# MCA0626                     ['Transport permease protein']
# MCA0742                                                NaN
# MCA0840                                                NaN
# MCA0869         ['Putrescine-binding periplasmic protein']
# MCA0870                                                NaN
# MCA0871                                                NaN
# MCA0872                                                NaN
# MCA0894                                                NaN
# MCA0899                                                NaN
# MCA0953                        ['Heme exporter protein B']
# MCA0954  ['Cytochrome c biogenesis ATP-binding export p...
# MCA0964  ['Lipid A export ATP-binding/permease protein ...
# MCA0990                                                NaN
# MCA0991                                                NaN
# MCA0992                                                NaN
# MCA1072                                                NaN
# MCA1073                                                NaN
# MCA1074                                                NaN
# MCA1181  ['Sulfate/thiosulfate import ATP-binding prote...
# ...                                                    ...
# MCA2324                                                NaN
# MCA2720                                                NaN
# MCA2758                                                NaN
# MCA2815                                                NaN
# MCA2214                               ['Histidine kinase']
# MCA2473                               ['Histidine kinase']
# MCA2847                               ['Histidine kinase']
# MCA1443                                                NaN
# MCA2472                                                NaN
# MCA1486                                                NaN
# MCA1487  ['Sec-independent protein translocase protein ...
# MCA1488  ['Sec-independent protein translocase protein ...
# MCA2041                                                NaN
# MCA0974                                                NaN
# MCA0975                                                NaN
# MCA1728                                                NaN
# MCA2417                                                NaN
# MCA0268                           ['Ammonium transporter']
# MCA0490                                                NaN
# MCA1581                                                NaN
# MCA2136                           ['Ammonium transporter']
# MCA2692                                                NaN
# MCA3057                                                NaN
# MCA1632                                                NaN
# MCA2608                                                NaN
# MCA0647                                                NaN
# MCA1097                                                NaN
# MCA1250                                                NaN
# MCA0108                     ['Magnesium transporter MgtE']
# MCA2402                                                NaN
#
#         EColiGeneCodeGenbank UniProtKB
# ID
# MCA0093                  NaN    Q60CL3
# MCA0127                  NaN       NaN
# MCA0134                 ftsE    Q60CH2
# MCA0135                  NaN       NaN
# MCA0168                  NaN    Q60CE0
# MCA0173                  NaN    Q60CD5
# MCA0174                  NaN    Q60CD4
# MCA0555                  NaN    Q60BC2
# MCA0557                  NaN    Q60BC0
# MCA0609                  NaN    Q60B72
# MCA0625                  NaN    Q60B56
# MCA0626                  NaN    Q60B55
# MCA0742                  NaN    Q60AV2
# MCA0840                  NaN    Q60AL1
# MCA0869                 potD    Q60AI4
# MCA0870                 potC    Q60AI3
# MCA0871                 potB       NaN
# MCA0872                 potA       NaN
# MCA0894                  NaN    Q60AG4
# MCA0899                  NaN    Q60AG2
# MCA0953                 ccmB    Q60AB4
# MCA0954                 ccmA    Q60AB3
# MCA0964                 msbA    Q60AA3
# MCA0990                 sufD    Q60A79
# MCA0991                 sufC       NaN
# MCA0992                 sufB    Q60A77
# MCA1072                 pstC    Q60A00
# MCA1073                 pstA    Q609Z9
# MCA1074                 pstB       NaN
# MCA1181                 cysA    Q609Q1
# ...                      ...       ...
# MCA2324                  NaN    Q605G0
# MCA2720                  NaN    Q603S9
# MCA2758                  NaN    Q603P5
# MCA2815                  NaN    Q603J0
# MCA2214                 kdpD    Q605R4
# MCA2473                  NaN    Q604R4
# MCA2847                  NaN    Q603F9
# MCA1443                  NaN    Q608P7
# MCA2472                  NaN    Q604R5
# MCA1486                 tatC       NaN
# MCA1487                 tatB    Q608K3
# MCA1488                 tatA    Q608K2
# MCA2041                  NaN       NaN
# MCA0974                  NaN       NaN
# MCA0975                  NaN       NaN
# MCA1728                  NaN    Q607N1
# MCA2417                  NaN       NaN
# MCA0268                amt-1    Q60C43
# MCA0490                amt-2       NaN
# MCA1581                  NaN       NaN
# MCA2136                amt-3    Q605Y6
# MCA2692                  NaN    Q603V4
# MCA3057                  NaN    Q602K6
# MCA1632                  NaN       NaN
# MCA2608                  NaN       NaN
# MCA0647                  NaN       NaN
# MCA1097                 feoB    Q609X9
# MCA1250                  NaN    Q609I4
# MCA0108                 mgtE    Q60CJ8
# MCA2402                  NaN       NaN
#
# [211 rows x 15 columns]

# %%
result2.to_csv('/Users/clie/Desktop/EFPro2/Experimental Data & Standards/TCDB Exports/Filtered_and_enriched_TCDB_data.csv')

# %% [markdown]
# I'll filter through the list in Excel. Hence saving it above and reimporting the filtered results below. The selecation was made according to the following criteria:
#
# The metabolite has to exist/ be relevant in the model.

# %%
TDB_selected_results = pd.read_csv('/Users/clie/Desktop/EFPro2/Experimental Data & Standards/TCDB Exports/subselected_transport_genes_reimport.csv',delimiter='\t')

# %% [markdown]
# To get a bit more accurate than just the general type of transporter, I am also taking into accountthe results of a previous BLAST run against TCDB in addition to the putative hits generated as part of the TransportDB pipepline for Methylococcus.

# %%
column_IDs = ['qseqid','sseqid','pident','length','mismatch','gapopen','qstart','qend','sstart','send','evalue','bitscore','TC_Number']
BLAST_results = pd.read_csv('/Users/clie/Desktop/EFPro2/Experimental Data & Standards/TCDB Exports/annotated_putative_transporters.csv', names = column_IDs)
BLAST_results.TC_Number = BLAST_results.sseqid.apply(lambda x: x.split('|')[-1])
BLAST_results.sseqid = BLAST_results.sseqid.apply(lambda x: x.split('|')[-2])

# %%
BLAST_results
# Out:
#       qseqid  sseqid  pident  length  mismatch  gapopen  qstart  qend  sstart  \
# 0    MCA0005  B1JFU8  43.333      90        47        2      37   122      37
# 1    MCA0006  P0AB98  59.770     261        90        3      14   259      11
# 2    MCA0007  P68699  61.364      44        17        0      33    76      34
# 3    MCA0008  P0ABA0  48.077     156        81        0       1   156       1
# 4    MCA0019  D5QHE9  36.364     143        85        2       4   146      42
# 5    MCA0023  A6VFN3  29.508     244       159        8      28   262      30
# 6    MCA0055  P0ABP6  28.049     164       113        3      21   180      33
# 7    MCA0070  M7AKZ4  25.079     315       214        5       6   311       8
# 8    MCA0079  Q88RT6  31.155    1056       674       18       1  1021       1
# 9    MCA0086  Q60148  41.912     136        71        4      20   148       6
# 10   MCA0091  Q51528  28.571     168       111        6       2   168       4
# 11   MCA0095  A9BJX0  42.777     886       474        8      17   872       2
# 12   MCA0102  P0ABH4  29.375     160       111        2       4   162       3
# 13   MCA0104  P0ABG7  52.113     355       169        1      22   375      12
# 14   MCA0108  O34442  27.294     425       305        2      57   479      26
# 15   MCA0120  B1LE48  31.871     342       223        6      12   349      12
# 16   MCA0133  P10121  59.752     323       127        3     342   663     177
# 17   MCA0135  P0AC31  33.448     290       193        0      11   300      63
# 18   MCA0142  P74072  47.632     359       176        2      14   360      11
# 19   MCA0147  G0CIY2  43.925     321       163        6     156   464     169
# 20   MCA0149  B0RRH8  24.775     444       304        7      10   428      25
# 21   MCA0163  T2K6Q3  50.000     218       107        2       5   221      28
# 22   MCA0164  P27650  48.026     152        78        1       9   160       9
# 23   MCA0166  T2K7C6  69.688     353       106        1       8   359       5
# 24   MCA0167  A2BTW4  26.415     212       126        6       6   192      18
# 25   MCA0169  H9UM46  40.435     230       135        2      30   259      30
# 26   MCA0172  A4PCH9  27.599     279       178        8      38   293      39
# 27   MCA0174  A4PCH7  40.435     230       137        0     175   404      85
# 28   MCA0178  Q1CZ65  33.711    1059       640       13       4  1042       3
# 29   MCA0268  O67997  46.366     399       209        3      27   424      39
# ..       ...     ...     ...     ...       ...      ...     ...   ...     ...
# 308  MCA2815  Q9HXW4  52.148    1024       481        1       3  1017       2
# 309  MCA2819  P97055  62.857     210        78        0       1   210       1
# 310  MCA2821  V8GWS1  52.035     344       162        2       9   352      10
# 311  MCA2823  P77223  44.828     174        90        3       3   171       4
# 312  MCA2824  P0A766  69.474     190        58        0       1   190       1
# 313  MCA2830  K1M2K1  30.144     418       270        4       1   405       1
# 314  MCA2847  Q9HV74  31.771     384       212       15     344   702     599
# 315  MCA2893  P0A766  75.000     192        48        0       1   192       1
# 316  MCA2894  P77223  58.480     171        70        1       2   171       6
# 317  MCA2896  P76182  55.874     349       146        3       1   341       1
# 318  MCA2897  P77285  46.629     178        90        3      15   190      12
# 319  MCA2898  P97055  53.774     212        98        0       6   217       5
# 320  MCA2966  V5C7X7  64.681     235        80        2       1   235       1
# 321  MCA2967  O34416  24.150     294       208        9       2   287       3
# 322  MCA2977  Q9HV74  29.268     246       149        9     220   449     744
# 323  MCA2989  P60782  45.789     190       101        2       7   196       8
# 324  MCA3016  E7BBJ1  45.926     135        69        2      36   168       5
# 325  MCA3017  E7BBJ2  47.368     133        70        0       1   133       1
# 326  MCA3037  P25714  40.761     552       300       10       1   540       1
# 327  MCA3057  B2N0W4  33.219     292       175        4       1   274      18
# 328  MCA3059  P0A6M2  32.593     135        82        4      19   150      24
# 329  MCA3074  P39580  27.372     274       183        5     123   386     119
# 330  MCA3076  F9Z892  24.517     518       285       21       3   440     271
# 331  MCA3077  F9Z892  32.549     255       157        6       4   250       5
# 332  MCA3080  E5AN59  40.206      97        58        0      15   111      14
# 333  MCA3086  F8CM01  33.838     198       122        4      76   264     106
# 334  MCA3093  P62517  41.810     696       364        8      15   679     137
# 335  MCA3099  Q9HV74  29.752     242       158        5     354   584     734
# 336  MCA3104  Q9HV74  26.923     260       161        9     182   424     727
# 337  MCA3112  P0AA53  65.878     296       101        0       6   301       3
#
#      send         evalue  bitscore    TC_Number
# 0     126   7.330000e-13      60.1   1.A.77.3.9
# 1     271  5.270000e-100     291.0    3.A.2.1.1
# 2      77   3.330000e-14      60.5    3.A.2.1.1
# 3     156   6.240000e-46     146.0    3.A.2.1.1
# 4     178   2.480000e-16      71.2   9.B.62.5.2
# 5     269   1.760000e-24      98.6  2.A.102.4.3
# 6     195   1.670000e-12      66.2   9.B.27.2.3
# 7     309   6.150000e-17      82.8   2.A.58.2.2
# 8    1038  4.590000e-143     454.0    2.A.6.1.5
# 9     140   6.260000e-28      99.8   3.A.15.2.1
# 10    163   1.670000e-13      64.3   3.A.15.2.1
# 11    884   0.000000e+00     731.0   3.A.3.2.21
# 12    161   1.220000e-20      82.0  9.B.157.1.3
# 13    366  6.820000e-116     340.0  2.A.103.1.2
# 14    448   4.410000e-56     192.0   1.A.26.1.3
# 15    347   5.670000e-46     160.0   2.A.86.2.1
# 16    497  4.240000e-114     350.0    3.A.5.1.1
# 17    352   1.410000e-52     174.0  3.A.1.140.1
# 18    369   1.950000e-92     280.0   2.A.19.2.1
# 19    484   6.640000e-82     260.0   9.B.18.1.1
# 20    463   4.950000e-34     132.0    8.A.3.1.3
# 21    244   3.280000e-71     216.0    3.D.7.2.3
# 22    159   1.200000e-37     127.0   2.A.99.1.1
# 23    357   0.000000e+00     535.0    3.D.7.2.3
# 24    224   2.030000e-20      84.3  9.B.150.1.3
# 25    257   4.920000e-45     151.0  3.A.1.139.3
# 26    316   1.240000e-16      77.8   3.A.1.27.1
# 27    314   1.340000e-51     174.0   3.A.1.27.1
# 28   1019  3.230000e-177     545.0    2.A.6.3.7
# 29    433  7.510000e-115     342.0   1.A.11.1.4
# ..    ...            ...       ...          ...
# 308  1025   0.000000e+00    1011.0   2.A.6.2.17
# 309   210   6.080000e-92     269.0    3.D.6.1.1
# 310   350  1.220000e-111     328.0    3.D.6.1.1
# 311   176   7.030000e-51     161.0    3.D.6.1.4
# 312   190   4.890000e-93     268.0    3.D.6.1.4
# 313   409   4.230000e-56     190.0   2.A.3.8.28
# 314   957   8.580000e-29     122.0   2.A.21.9.1
# 315   192  5.820000e-105     298.0    3.D.6.1.4
# 316   176   2.430000e-69     207.0    3.D.6.1.4
# 317   349  8.440000e-124     358.0    3.D.6.1.4
# 318   186   1.110000e-47     154.0    3.D.6.1.4
# 319   216   5.570000e-75     226.0    3.D.6.1.1
# 320   232  4.960000e-101     292.0   9.B.43.2.1
# 321   289   2.620000e-16      76.3   2.A.7.3.29
# 322   980   2.940000e-17      83.6   2.A.21.9.1
# 323   195   3.300000e-50     160.0   9.B.31.1.1
# 324   137   5.270000e-27      98.2  9.B.102.5.2
# 325   133   1.360000e-34     117.0  9.B.102.5.5
# 326   537  1.760000e-141     418.0    2.A.9.3.1
# 327   307   3.040000e-41     143.0   1.A.46.2.6
# 328   152   2.010000e-10      55.5    5.A.2.1.1
# 329   386   2.750000e-27     112.0   2.A.50.2.1
# 330   762   7.690000e-18      85.1  3.A.1.132.9
# 331   252   8.490000e-25     101.0  3.A.1.132.9
# 332   110   3.780000e-21      80.5   1.E.40.3.1
# 333   303   1.700000e-19      89.4   1.A.13.4.1
# 334   822  1.600000e-176     523.0    4.D.3.1.1
# 335   974   7.210000e-27     115.0   2.A.21.9.1
# 336   974   2.960000e-12      67.8   2.A.21.9.1
# 337   298  2.220000e-147     415.0   8.A.21.2.2
#
# [338 rows x 13 columns]

# %%
BLAST_results.rename(columns={'qseqid':'ID'}, inplace=True)
BLAST_results = BLAST_results[['ID','TC_Number','pident','evalue']]

# %%
result3 = pd.merge(TDB_selected_results, BLAST_results, on='ID', how='inner')

# %%
result3 = result3[['ID','EColiGeneCodeGenbank','Substrate','TCNumber','TC_Number','pident','evalue','Final_Localization']]

# %%
result3.to_csv('/Users/clie/Desktop/EFPro2/Experimental Data & Standards/TCDB Exports/final_selection_extended_with_blastresults.csv')

# %% [markdown]
# Based on the above file, we will now add the individual transport reactions. First we'll check the general description for that specific transport class, and then consider the BLAST result to read about a given transporter in more detail especially with regards to finding the specific substrates. We will try to stick to the simplest, smallest set of substrates. In case of conflicts between our own BLAST results and the automatic TransportDB transporter annotation, we will preferably trust the BLAST results.
#
# The criteria for the BLAST were:
# - E-value = E^-9
# - Max target sequences = 1 i.e. I am chosing to ignore multiple matches as I want to recieve unambiguous mappings.
# - Max Alignments = 1 i.e. I am chosing to ignore multiple matches as I want to recieve unambiguous mappings.
#
# And after a manual check of the matches with the three lowest bitscores and the three lowest identities I decided not to further restrict this selection. This is, because even though the identity/ overall score was low, the descriptions or e.coli gene names of the qseqid on Uniprot matched those from the TCDB of the sseqid.

# %% [markdown]
# Import the model, to begin working on the transport implementation.

# %%
relative_directory = getcwd()
model = load_model(relative_directory + '/Reconstructions/MethylococcusModel12.json')

# %%
model.medium
# Out:
#      reaction_id       reaction_name  lower_bound  upper_bound
# 0        EX_pi_c  phosphate exchange     -1000.00       1000.0
# 1        EX_o2_c   dioxygen exchange     -1000.00       1000.0
# 2       EX_nh3_c     NH4(+) exchange     -1000.00       1000.0
# 3       EX_so4_c    sulfate exchange     -1000.00       1000.0
# 4        EX_cl_c      Cl(-) exchange     -1000.00       1000.0
# 5       EX_na1_c      Na(+) exchange        -1.00       1000.0
# 6         EX_k_c       K(+) exchange     -1000.00       1000.0
# 7       EX_mg2_c     Mg(2+) exchange     -1000.00       1000.0
# 8       EX_ca2_c     Ca(2+) exchange     -1000.00       1000.0
# 9       EX_ch4_p    methane exchange       -18.46         -0.1
# 10  EX_cobalt2_c       Co2+ exchange     -1000.00       1000.0
# 11       EX_cu_c        Cu+ exchange     -1000.00       1000.0

# %%
model.change_objective(model.reactions.BIOMASS_Mcapsulatus)

# %%
model.solve().f
# Out:
# 0.260266147291089

# %%
from cameo import Reaction,Metabolite

# %%
model.reactions.ATPSNaipp.gene_reaction_rule = u'((MCA0005 and MCA0006 and MCA0007 and MCA0008 and MCA0009 and MCA0010 and MCA0011 and MCA0012 and MCA0013) or (MCA2699 and MCA2700 and MCA2701 and MCA2707 and MCA2708 and MCA1556 and MCA3021))'
model.reactions.ATPSipp.gene_reaction_rule = u'((MCA0005 and MCA0006 and MCA0007 and MCA0008 and MCA0009 and MCA0010 and MCA0011 and MCA0012 and MCA0013) or (MCA2699 and MCA2700 and MCA2701 and MCA2707 and MCA2708 and MCA1556 and MCA3021))'

# %%
model.metabolites.nh3_c.annotation['metanetx.chemical'] = 'MNXM84'
model.metabolites.nh3_c.name = 'Ammonium'
model.metabolites.nh3_c.id = 'nh4_c'

# %%
model.metabolites.nh3_p.annotation['metanetx.chemical'] = 'MNXM84'
model.metabolites.nh3_p.name = 'Ammonium'
model.metabolites.nh3_p.id = 'nh4_p'

# %%
model.reactions.NH3tpp.id = 'NH4tpp'

# %%
model.reactions.NH4tpp.gene_reaction_rule = '(MCA0268 and MCA0490 and MCA2136) or MCA1581'

# %%
model.solve().f
# Out:
# 0.260266147291089

# %%
met = Metabolite(id='aso3_c',name='Arsenite',formula='AsO3',charge=0,compartment='c')
met.annotation={'metanetx.chemical':'MNXM658',
               'kegg.compound':'C06697',
               'seed.compound':'cpd04098',
               'biocyc':['META:CPD0-2040', 'META:CPD-763'],
               'bigg.metabolite':'aso3_c'}
model.add_metabolite(met)

# %%
met = Metabolite(id='aso3_p',name='Arsenite',formula='AsO3',charge=0,compartment='p')
met.annotation={'metanetx.chemical':'MNXM658',
               'kegg.compound':'C06697',
               'seed.compound':'cpd04098',
               'biocyc':['META:CPD0-2040', 'META:CPD-763'],
               'bigg.metabolite':'aso3_c'}
model.add_metabolite(met)

# %%
rxn = Reaction(id='ASO3t8pp',name='Arsenite efflux via ATP hydrolysis (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1346 and MCA0791'
rxn.add_metabolites({model.metabolites.aso3_c:-1,
                    model.metabolites.atp_c:-1,
                    model.metabolites.h2o_c:-1,
                    model.metabolites.aso3_p:1,
                    model.metabolites.adp_c:1,
                    model.metabolites.pi_c:1,
                    model.metabolites.h_c:1},combine=False)
model.add_reaction(rxn)

# %%
rxn = Reaction(id='ASO3tpp',name='Arsenite transport via proton antiport (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0791'
rxn.add_metabolites({model.metabolites.aso3_c:-1,
                    model.metabolites.h_p:-1,
                    model.metabolites.aso3_p:1,
                    model.metabolites.h_c:1},combine=False)
model.add_reaction(rxn)

# %%
cl_p = model.metabolites.cl_c.copy()

# %%
cl_p.compartment = 'p'
cl_p.id = 'cl_p'
model.add_metabolite(cl_p)

# %%
rxn = Reaction(id='CLtpp',name='Chloride transport via Bestrophin channel',lower_bound=0,upper_bound=0)
rxn.gene_reaction_rule = 'MCA2692 or MCA3057'
rxn.add_metabolites({model.metabolites.cl_p:-1,
                    model.metabolites.cl_c:1},combine=False)
model.add_reaction(rxn)

# lb = ub = 0 because the real function is unclear

# %%
met = Metabolite(id='mn2_c',name='Manganese(2+)',formula='Mn',charge=0,compartment='c')
met.annotation={'metanetx.chemical':'MNXM2255',
               'kegg.compound':['C00034', 'C19610'],
               'seed.compound':'cpd00030'}
model.add_metabolite(met)

# %%
met = Metabolite(id='mn2_p',name='Manganese(2+)',formula='Mn',charge=0,compartment='p')
met.annotation={'metanetx.chemical':'MNXM2255',
               'kegg.compound':['C00034', 'C19610'],
               'seed.compound':'cpd00030'}
model.add_metabolite(met)

# %%
ca2_p = model.metabolites.ca2_c.copy()
ca2_p.compartment = 'p'
ca2_p.id = 'ca2_p'
model.add_metabolite(ca2_p)

# %%
rxn = Reaction(id='CA2abcpp',name='Calcium efflux via ABC system (periplasm)',lower_bound=0,upper_bound=1000)
rxn.annotation = {'metanetx.reaction':'MNXR1035','brenda':'3.6.3.8'}
rxn.gene_reaction_rule = 'MCA0095 or MCA0449 or MCA1004 or MCA1761'
rxn.add_metabolites({model.metabolites.ca2_c:-1,
                    model.metabolites.atp_c:-1,
                    model.metabolites.h2o_c:-1,
                    model.metabolites.ca2_p:1,
                    model.metabolites.adp_c:1,
                    model.metabolites.pi_c:1,
                    model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
rxn = Reaction(id='MN2t3pp',name='Manganese (Mn+2) transport out via proton antiport (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1801'
rxn.add_metabolites({model.metabolites.mn2_c:-1,
                     model.metabolites.mn2_p:1,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
model.solve().f
# Out:
# 0.2602661472910852

# %%
k_p = model.metabolites.k_c.copy()
k_p.compartment = 'p'
k_p.id = 'k_p'
model.add_metabolite(k_p)

# %%
met = Metabolite(id='zn2_c',name='Zinc',formula='Zn',charge=2,compartment='c')
met.annotation={'metanetx.chemical':'MNXM149',
               'kegg.compound':'C00038',
               'seed.compound':'cpd00034'}
model.add_metabolite(met)

# %%
zn2_p = model.metabolites.zn2_c.copy()
zn2_p.compartment = 'p'
zn2_p.id = 'zn2_p'
model.add_metabolite(zn2_p)

# %%
rxn = Reaction(id='ZN2t4pp',name='Zinc transport out via antiport (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1900'
rxn.annotation = {'metanetx.reaction':'MNXR27629'}
rxn.add_metabolites({model.metabolites.zn2_c:-1,
                     model.metabolites.zn2_p:1,
                     model.metabolites.h_p:-1,
                     model.metabolites.k_p:-1,
                     model.metabolites.h_c:1,
                    model.metabolites.k_c:1},combine=False)

model.add_reaction(rxn)

# %%
met = Metabolite(id='cd2_c',name='Cadmium',formula='Cd',charge=2,compartment='c')
met.annotation={'metanetx.chemical':'MNXM4505',
               'kegg.compound':'C01413',
               'seed.compound':'cpd01012'}
model.add_metabolite(met)

# %%
cd2_p = model.metabolites.cd2_c.copy()
cd2_p.compartment = 'p'
cd2_p.id = 'cd2_p'
model.add_metabolite(cd2_p)

# %%
rxn = Reaction(id='CD2t4pp',name='Cadmium transport out via antiport (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1900'
rxn.annotation = {'metanetx.reaction':'MNXR79902'}
rxn.add_metabolites({model.metabolites.cd2_c:-1,
                     model.metabolites.cd2_p:1,
                     model.metabolites.h_p:-1,
                     model.metabolites.k_p:-1,
                     model.metabolites.h_c:1,
                    model.metabolites.k_c:1},combine=False)

model.add_reaction(rxn)

# %%
rxn = Reaction(id='CLt3_2pp',name='Chloride transport out via proton antiport (2:1) (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA2509'
rxn.annotation = {'metanetx.reaction':'MNXR1217'}
rxn.add_metabolites({model.metabolites.cl_p:-2,
                     model.metabolites.cl_c:2,
                     model.metabolites.h_p:1,
                     model.metabolites.h_c:-1},combine=False)

model.add_reaction(rxn)

# %%
cobalt2_p = model.metabolites.cobalt2_c.copy()
cobalt2_p.compartment = 'p'
cobalt2_p.id = 'cobalt2_p'
model.add_metabolite(cobalt2_p)

# %%
rxn = Reaction(id='COBALT2t3pp',name='Cobalt (Co+2) transport out via proton antiport (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0079 or MCA1239 or MCA1298 or MCA1767 or MCA0978 or MCA2720'
rxn.annotation = {'metanetx.reaction':'MNXR82020'}
rxn.add_metabolites({model.metabolites.cobalt2_c:-2,
                     model.metabolites.cobalt2_p:2,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
rxn = Reaction(id='ZN2t3pp',name='Zinc (Zn+2) transport out via proton antiport (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0079 or MCA1239 or MCA1298 or MCA1767 or MCA0978 or MCA2324'
rxn.annotation = {'metanetx.reaction':'MNXR5386'}
rxn.add_metabolites({model.metabolites.zn2_c:-2,
                     model.metabolites.zn2_p:2,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
rxn = Reaction(id='CD2t3pp',name='Cadmium (Cd+2) transport out via proton antiport (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0079 or MCA1239 or MCA1298 or MCA1767 or MCA0978'
rxn.annotation = {'metanetx.reaction':'MNXR68486'}
rxn.add_metabolites({model.metabolites.cd2_c:-2,
                     model.metabolites.cd2_p:2,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
met = Metabolite(id='ni2_c',name='Nickel',formula='Ni',charge=0,compartment='c')
met.annotation={'metanetx.chemical':'MNXM3673',
               'kegg.compound':['C00291', 'C19609'],
               'seed.compound':'cpd00244'}
model.add_metabolite(met)

# %%
ni2_p = model.metabolites.ni2_c.copy()
ni2_p.compartment = 'p'
ni2_p.id = 'ni2_p'
model.add_metabolite(ni2_p)

# %%
rxn = Reaction(id='NI2t3pp',name='Nickel (Ni+2) transport out via proton antiport (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA2720'
rxn.annotation = {'metanetx.reaction':'MNXR69538'}
rxn.add_metabolites({model.metabolites.ni2_c:-2,
                     model.metabolites.ni2_p:2,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
mg2_p = model.metabolites.mg2_c.copy()
mg2_p.compartment = 'p'
mg2_p.id = 'mg2_p'
model.add_metabolite(mg2_p)

# %%
rxn = Reaction(id='MG2tpp',name='Magnesium (+2) transport in via diffusion',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0108'
rxn.annotation = {'metanetx.reaction':'MNXR3516','biocyc':'META:TRANS-RXN-141'}
rxn.add_metabolites({model.metabolites.mg2_p:-1,
                     model.metabolites.mg2_c:1},combine=False)

model.add_reaction(rxn)

# %%
model.reactions.NO3abcpp.add_metabolites({model.metabolites.h_p:-1,
                                         model.metabolites.no3_p:-1,
                                         model.metabolites.h_c:1,
                                         model.metabolites.no3_c:1},combine=False)
model.reactions.NO3abcpp.name = 'Nitrate transport in via proton symport (periplasm)'
model.reactions.NO3abcpp.annotation = {'metanetx.reaction':'MNXR3846'}
model.reactions.NO3abcpp.gene_reaction_rule= 'MCA0589 or MCA0594'
model.reactions.NO3abcpp.id = 'NO3t2pp'

# %%
model.reactions.NO3t7pp.gene_reaction_rule = 'MCA0589 or MCA0594'

# %%
rxn = Reaction(id='CA2t3pp',name='Calcium (Ca+2) transport out via proton antiport (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0545 or MCA0142 or MCA1907'
rxn.annotation = {'metanetx.reaction':'MNXR1036'}
rxn.add_metabolites({model.metabolites.ca2_c:-1,
                     model.metabolites.ca2_p:1,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
rxn = Reaction(id='Kt3pp',name='Potassium transport out via proton antiport (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0545'
rxn.annotation = {'metanetx.reaction':'MNXR3188'}
rxn.add_metabolites({model.metabolites.k_c:-1,
                     model.metabolites.k_p:1,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
rxn = Reaction(id='NAt3pp',name='Sodium transport out via proton antiport (cytoplasm to periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0545'
rxn.annotation = {'metanetx.reaction':'MNXR3783'}
rxn.add_metabolites({model.metabolites.na1_c:-1,
                     model.metabolites.na1_p:1,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
pi_p = model.metabolites.pi_c.copy()
pi_p.compartment = 'p'
pi_p.id = 'pi_p'
model.add_metabolite(pi_p)

# %%
model.solve().f
# Out:
# 0.2602661472910852

# %%
rxn = Reaction(id='PIt2rpp',name='Phosphate reversible transport via symport (periplasm)',lower_bound=-1000,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1005'
rxn.annotation = {'metanetx.reaction':'MNXR4295', 'biocyc':'META:TRANS-RXN-114'}
rxn.add_metabolites({model.metabolites.pi_c:1,
                     model.metabolites.pi_p:-1,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
asp__L_p = model.metabolites.asp__L_c.copy()
asp__L_p.compartment = 'p'
asp__L_p.id = 'asp__L_p'
model.add_metabolite(asp__L_p)

# %%
rxn = Reaction(id='ASPt2_2pp',name='Aspartate transport via proton symport (2 H) (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1872'
rxn.annotation = {'metanetx.reaction':'MNXR874', 'biocyc':'META:TRANS-RXN-122A'}
rxn.add_metabolites({model.metabolites.asp__L_c:1,
                     model.metabolites.asp__L_p:-1,
                     model.metabolites.h_p:-2,
                     model.metabolites.h_c:2},combine=False)

model.add_reaction(rxn)

# %%
fum_p = model.metabolites.fum_c.copy()
fum_p.compartment = 'p'
fum_p.id = 'fum_p'
model.add_metabolite(fum_p)

# %%
rxn = Reaction(id='FUMt2_2pp',name='Fumarate transport via proton symport (2 H) (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1872'
rxn.annotation = {'metanetx.reaction':'MNXR2343', 'biocyc':'META:TRANS-RXN-121B'}
rxn.add_metabolites({model.metabolites.fum_c:1,
                     model.metabolites.fum_p:-1,
                     model.metabolites.h_p:-2,
                     model.metabolites.h_c:2},combine=False)

model.add_reaction(rxn)

# %%
mal__L_p = model.metabolites.mal__L_c.copy()
mal__L_p.compartment = 'p'
mal__L_p.id = 'mal__L_p'
model.add_metabolite(mal__L_p)

# %%
rxn = Reaction(id='MALt2_2pp',name='Malate transport via proton symport (2 H) (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1872'
rxn.annotation = {'metanetx.reaction':'MNXR3407', 'biocyc':'META:TRANS-RXN-121A'}
rxn.add_metabolites({model.metabolites.mal__L_c:1,
                     model.metabolites.mal__L_p:-1,
                     model.metabolites.h_p:-2,
                     model.metabolites.h_c:2},combine=False)

model.add_reaction(rxn)

# %%
orot_p = model.metabolites.orot_c.copy()
orot_p.compartment = 'p'
orot_p.id = 'orot_p'
model.add_metabolite(orot_p)

# %%
rxn = Reaction(id='OROTt2_2pp',name='Orotate transport via proton symport (2 H) (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1872'
rxn.annotation = {'metanetx.reaction':'MNXR3994', 'biocyc':'META:TRANS-RXN-121C'}
rxn.add_metabolites({model.metabolites.orot_c:1,
                     model.metabolites.orot_p:-1,
                     model.metabolites.h_p:-2,
                     model.metabolites.h_c:2},combine=False)

model.add_reaction(rxn)

# %%
succ_p = model.metabolites.succ_c.copy()
succ_p.compartment = 'p'
succ_p.id = 'succ_p'
model.add_metabolite(succ_p)

# %%
rxn = Reaction(id='SUCCt2_2pp',name='Succinate transport via proton symport (2 H) (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1872'
rxn.annotation = {'metanetx.reaction':'MNXR4947', 'biocyc':'META:TRANS-RXN-121'}
rxn.add_metabolites({model.metabolites.succ_c:1,
                     model.metabolites.succ_p:-1,
                     model.metabolites.h_p:-2,
                     model.metabolites.h_c:2},combine=False)

model.add_reaction(rxn)

# %%
pyr_p = model.metabolites.pyr_c.copy()
pyr_p.compartment = 'p'
pyr_p.id = 'pyr_p'
model.add_metabolite(pyr_p)

# %%
rxn = Reaction(id='PYRt4pp',name='Pyruvate transport via sodium symport',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1875'
rxn.annotation = {'metanetx.reaction':'MNXR84090'}
rxn.add_metabolites({model.metabolites.pyr_c:1,
                     model.metabolites.pyr_p:-1,
                     model.metabolites.na1_p:-1,
                     model.metabolites.na1_c:1},combine=False)

model.add_reaction(rxn)

# %%
ser__L_p = model.metabolites.ser__L_c.copy()
ser__L_p.compartment = 'p'
ser__L_p.id = 'ser__L_p'
model.add_metabolite(ser__L_p)

# %%
thr__L_p = model.metabolites.thr__L_c.copy()
thr__L_p.compartment = 'p'
thr__L_p.id = 'thr__L_p'
model.add_metabolite(thr__L_p)

# %%
rxn = Reaction(id='SERTHRtpp',name='Serine/Threonine exchanger SteT (periplasm)',lower_bound=-1000,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0718 or MCA2830'
rxn.add_metabolites({model.metabolites.ser__L_c:-1,
                     model.metabolites.thr__L_p:-1,
                     model.metabolites.ser__L_p:1,
                     model.metabolites.thr__L_c:1},combine=False)

model.add_reaction(rxn)

# %%
model.reactions.Kt3pp.gene_reaction_rule = 'MCA0545 or MCA1519 or MCA1760 or MCA0928'

# %%
model.solve().f
# Out:
# 0.2602661472910852

# %%
rxn = Reaction(id='Kt2pp',name='Potassium transport in via proton symport (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA2041'
rxn.annotation = {'metanetx.reaction':'MNXR3188', 'biocyc':['META:TRANS-RXN-3', 'META:TRANS-RXN-42']}
rxn.add_metabolites({model.metabolites.k_c:1,
                     model.metabolites.k_p:-1,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
ade_p = model.metabolites.ade_c.copy()
ade_p.compartment = 'p'
ade_p.id = 'ade_p'
model.add_metabolite(ade_p)

# %%
rxn = Reaction(id='ADEt2rpp',name='Adenine transport via proton symport (reversible) (periplasm)',lower_bound=-1000,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1664'
rxn.annotation = {'metanetx.reaction':'MNXR475', 'biocyc':['META:TRANS-RXN0-447', 'META:TRANS-RXN-198']}
rxn.add_metabolites({model.metabolites.ade_c:1,
                     model.metabolites.ade_p:-1,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
gua_p = model.metabolites.gua_c.copy()
gua_p.compartment = 'p'
gua_p.id = 'gua_p'
model.add_metabolite(gua_p)

# %%
rxn = Reaction(id='GUAt2pp',name='Guanine transport in via proton symport (periplasm)',lower_bound=-1000,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1664'
rxn.annotation = {'metanetx.reaction':'MNXR2847'}
rxn.add_metabolites({model.metabolites.gua_c:1,
                     model.metabolites.gua_p:-1,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
xan_p = model.metabolites.xan_c.copy()
xan_p.compartment = 'p'
xan_p.id = 'xan_p'
model.add_metabolite(xan_p)

# %%
rxn = Reaction(id='XANt2pp',name='Xanthine transport in via proton symport (periplasm)',lower_bound=-1000,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1664'
rxn.annotation = {'metanetx.reaction':'MNXR5350', 'biocyc':['META:RXN-5076', 'META:TRANS-RXN-206']}
rxn.add_metabolites({model.metabolites.gua_c:1,
                     model.metabolites.gua_p:-1,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
rxn = Reaction(id='ZN2tpp',name='Zinc transport in via permease (no H+)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0974 or MCA0975 or MCA1728 or MCA2417'
rxn.annotation = {'metanetx.reaction':'MNXR5387', 'biocyc':'META:RXN0-12'}
rxn.add_metabolites({model.metabolites.zn2_p:-1,
                     model.metabolites.zn2_c:1},combine=False)

model.add_reaction(rxn)

# %%
rxn = Reaction(id='CD2tpp',name='Cadmium (+2) transport in via permease (no H+)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0974 or MCA0975 or MCA1728 or MCA2417'
rxn.annotation = {'metanetx.reaction':'MNXR68487', 'biocyc':'META:RXN0-10'}
rxn.add_metabolites({model.metabolites.cd2_p:-1,
                     model.metabolites.cd2_c:1},combine=False)

model.add_reaction(rxn)

# %%
rxn = Reaction(id='COBALT2tpp',name='Cobalt transport in via permease (no H+)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0974 or MCA0975 or MCA1728 or MCA2417'
rxn.annotation = {'metanetx.reaction':'MNXR82021', 'biocyc':'META:TRANS-RXN-141A'}
rxn.add_metabolites({model.metabolites.cobalt2_p:-1,
                     model.metabolites.cobalt2_c:1},combine=False)

model.add_reaction(rxn)

# %%
model.metabolites.cu_c.annotation = {u'bigg.metabolite': u'cu2',
 u'biocyc': u'META:CU+2',
 u'chebi': ['CHEBI:20882', 'CHEBI:23380', 'CHEBI:29036', 'CHEBI:49550'],
 u'metanetx.chemical': u'MNXM632',
u'kegg.compound':u'C00070',u'seed.compound':u'cpd00058'}
model.metabolites.cu_c.charge = 2
model.metabolites.cu_c.name = 'Cu2+'
model.metabolites.cu_c.id = 'cu2_c'

# %%
cu2_p = model.metabolites.cu2_c.copy()
cu2_p.compartment = 'p'
cu2_p.id = 'cu2_p'
model.add_metabolite(cu2_p)

# %%
model.solve().f
# Out:
# 0.2602661472910852

# %%
rxn = Reaction(id='CU2tpp',name='Copper transport in via permease (no H+)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0975 or MCA1728 or MCA2417'
rxn.annotation = {'metanetx.reaction':'MNXR25169', 'biocyc':'META:RXN0-14'}
rxn.add_metabolites({model.metabolites.cu2_p:-1,
                     model.metabolites.cu2_c:1},combine=False)

model.add_reaction(rxn)

# %%
model.reactions.FE2tpp.name = 'Iron (+2) transport in via permease (no H+)'
model.reactions.FE2tpp.lower_bound = 0
model.reactions.FE2tpp.upper_bound = 1000
model.reactions.FE2tpp.gene_reaction_rule = 'MCA0974 or MCA0975 or MCA1728 or MCA2417'
model.reactions.FE2tpp.annotation = {'metanetx.reaction':'MNXR2212', 'biocyc':'META:TRANS-RXN-8'}
model.reactions.FE2tpp.add_metabolites({model.metabolites.fe2_p:-1,
                     model.metabolites.fe2_c:1},combine=False)

# %%
rxn = Reaction(id='MN2tpp',name='Manganese transport in via permease (no H+)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0974 or MCA0975 or MCA1728 or MCA2417'
rxn.annotation = {'metanetx.reaction':'MNXR69477', 'biocyc':['META:RXN0-16', 'META:TRANS-RXN0-487']}
rxn.add_metabolites({model.metabolites.mn2_p:-1,
                     model.metabolites.mn2_c:1},combine=False)

model.add_reaction(rxn)

# %%
glyc_p = model.metabolites.glyc_c.copy()
glyc_p.compartment = 'p'
glyc_p.id = 'glyc_p'
model.add_metabolite(glyc_p)

# %%
rxn = Reaction(id='GLYCt3',name='Glycerol transport via symport',lower_bound=-1000,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0615 or MCA1162 or MCA3074'
rxn.annotation = {'metanetx.reaction':'MNXR80849'}
rxn.add_metabolites({model.metabolites.glyc_c:1,
                     model.metabolites.glyc_p:-1,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1},combine=False)

model.add_reaction(rxn)

# %%
model.solve().f
# Out:
# 0.2602661472910852

# %%
so4_p = model.metabolites.so4_c.copy()
so4_p.compartment = 'p'
so4_p.id = 'so4_p'
model.add_metabolite(so4_p)

# %%
rxn = Reaction(id='PIt7ipp',name='Phosphate transport in via three Na+ symporter (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0070'
rxn.annotation = {'metanetx.reaction':'MNXR4297'}
rxn.add_metabolites({model.metabolites.na1_p:-3,
                     model.metabolites.pi_p:-1,
                     model.metabolites.na1_c:3,
                     model.metabolites.pi_c:1},combine=False)

model.add_reaction(rxn)

# %%
model.reactions.NAt3pp.gene_reaction_rule = 'MCA0545 or MCA1700 or MCA1762 or MCA2058 or MCA2735'

# %%
fol_p = model.metabolites.fol_c.copy()
fol_p.compartment = 'p'
fol_p.id = 'fol_p'
model.add_metabolite(fol_p)

# %%
rxn = Reaction(id='FOLtipp',name='Folate transport in via symport (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1506'
rxn.annotation = {'metanetx.reaction':'MNXR2270'}
rxn.add_metabolites({model.metabolites.fol_p:-1,
                     model.metabolites.h_p:-1,
                     model.metabolites.h_c:1,
                     model.metabolites.fol_c:1},combine=False)

model.add_reaction(rxn)

# %%
model.reactions.Kt2pp.gene_reaction_rule = 'MCA2041 or MCA0976'

# %%
pheme_p = model.metabolites.pheme_c.copy()
pheme_p.compartment = 'p'
pheme_p.id = 'pheme_p'
model.add_metabolite(pheme_p)

# %%
rxn = Reaction(id='PHEMEabcpp',name='Protoheme transport via ABC system (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0952 and MCA0953 and MCA0954'
rxn.annotation = {'metanetx.reaction':'MNXR76153','biocyc':'META:TRANS-RXN0-162','brenda':'3.6.3.41'}
rxn.add_metabolites({model.metabolites.pheme_c:-1,
                    model.metabolites.atp_c:-1,
                    model.metabolites.h2o_c:-1,
                    model.metabolites.pheme_p:1,
                    model.metabolites.adp_c:1,
                    model.metabolites.pi_c:1,
                    model.metabolites.h_c:1},combine=False)
model.add_reaction(rxn)

# %%
ptrc_p = model.metabolites.ptrc_c.copy()
ptrc_p.compartment = 'p'
ptrc_p.id = 'ptrc_p'
model.add_metabolite(ptrc_p)

# %%
rxn = Reaction(id='PTRCabcpp',name='Putrescine transport via ABC system (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0869 and MCA0870 and MCA0871'
rxn.annotation = {'metanetx.reaction':'MNXR4519','biocyc':'META:ABC-25-RXN','brenda':'3.6.3.31'}
rxn.add_metabolites({model.metabolites.ptrc_p:-1,
                    model.metabolites.atp_c:-1,
                    model.metabolites.h2o_c:-1,
                    model.metabolites.ptrc_c:1,
                    model.metabolites.adp_c:1,
                    model.metabolites.pi_c:1,
                    model.metabolites.h_c:1},combine=False)
model.add_reaction(rxn)

# %%
model.solve().f
# Out:
# 0.2602661472910852

# %%
spmd_p = model.metabolites.spmd_c.copy()
spmd_p.compartment = 'p'
spmd_p.id = 'spmd_p'
model.add_metabolite(spmd_p)

# %%
rxn = Reaction(id='SPMDabcpp',name='Spermidine transport via ABC system (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0869 and MCA0870 and MCA0871'
rxn.annotation = {'metanetx.reaction':'MNXR4889','biocyc':'META:ABC-24-RXN','brenda':'3.6.3.31'}
rxn.add_metabolites({model.metabolites.spmd_p:-1,
                    model.metabolites.atp_c:-1,
                    model.metabolites.h2o_c:-1,
                    model.metabolites.spmd_c:1,
                    model.metabolites.adp_c:1,
                    model.metabolites.pi_c:1,
                    model.metabolites.h_c:1},combine=False)
model.add_reaction(rxn)

# %%
urea_p = model.metabolites.urea_c.copy()
urea_p.compartment = 'p'
urea_p.id = 'urea_p'
model.add_metabolite(urea_p)

# %%
rxn = Reaction(id='UREAabcpp',name='Urea transport via ABC system (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1662'
rxn.add_metabolites({model.metabolites.urea_p:-1,
                    model.metabolites.atp_c:-1,
                    model.metabolites.h2o_c:-1,
                    model.metabolites.urea_c:1,
                    model.metabolites.adp_c:1,
                    model.metabolites.pi_c:1,
                    model.metabolites.h_c:1},combine=False)
model.add_reaction(rxn)

# %%
rxn = Reaction(id='SULabcpp',name='Sulfate transport via ABC system (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1181 and MCA1182 and MCA1183'
rxn.annotation = {'metanetx.reaction':'MNXR4968','biocyc':['META:3.6.3.25-RXN', 'META:ABC-70-RXN'],'brenda':'3.6.3.25'}
rxn.add_metabolites({model.metabolites.so4_p:-1,
                    model.metabolites.atp_c:-1,
                    model.metabolites.h2o_c:-1,
                    model.metabolites.so4_c:1,
                    model.metabolites.adp_c:1,
                    model.metabolites.pi_c:1,
                    model.metabolites.h_c:1},combine=False)
model.add_reaction(rxn)

# %%
tsul_p = model.metabolites.tsul_c.copy()
tsul_p.compartment = 'p'
tsul_p.id = 'tsul_p'
model.add_metabolite(tsul_p)

# %%
rxn = Reaction(id='TSULabcpp',name='Thiosulfate transport via ABC system (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1181 and MCA1182 and MCA1183'
rxn.annotation = {'metanetx.reaction':'MNXR5156','biocyc':'META:ABC-7-RXN','brenda':'3.6.3.25'}
rxn.add_metabolites({model.metabolites.tsul_p:-1,
                    model.metabolites.atp_c:-1,
                    model.metabolites.h2o_c:-1,
                    model.metabolites.tsul_c:1,
                    model.metabolites.adp_c:1,
                    model.metabolites.pi_c:1,
                    model.metabolites.h_c:1},combine=False)
model.add_reaction(rxn)

# %%
rxn = Reaction(id='PIuabcpp',name='Phosphate transport via ABC system (uptake, periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1072 and MCA1073 and MCA1074'
rxn.annotation = {'metanetx.reaction':'MNXR4293','biocyc':'META:ABC-27-RXN','brenda':'3.6.3.27'}
rxn.add_metabolites({model.metabolites.pi_p:-1,
                    model.metabolites.atp_c:-1,
                    model.metabolites.h2o_c:-1,
                    model.metabolites.adp_c:1,
                    model.metabolites.pi_c:2,
                    model.metabolites.h_c:1},combine=False)
model.add_reaction(rxn)

# %%
model.repair()

# %%
rxn = Reaction(id='MG2uabcpp',name='Magnesium (Mg+2) ABC transporter (ubtake, periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1929'
rxn.annotation = {'metanetx.reaction':'MNXR3513','biocyc':['META:3.6.3.2-RXN', 'META:TRANS-RXN-250'],'brenda':'3.6.3.2'}
rxn.add_metabolites({model.metabolites.mg2_p:-1,
                    model.metabolites.atp_c:-1,
                    model.metabolites.h2o_c:-1,
                    model.metabolites.mg2_c:1,
                    model.metabolites.adp_c:1,
                    model.metabolites.pi_c:1,
                    model.metabolites.h_c:1},combine=False)
model.add_reaction(rxn)

# %%
rxn = Reaction(id='NI2uabcpp',name='Nickel transport via ABC system (uptake, periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1929'
rxn.annotation = {'metanetx.reaction':'MNXR19978','biocyc':['META:3.6.3.24-RXN', 'META:ABC-20-RXN'],'brenda':'3.6.3.24'}
rxn.add_metabolites({model.metabolites.ni2_p:-1,
                    model.metabolites.atp_c:-1,
                    model.metabolites.h2o_c:-1,
                    model.metabolites.ni2_c:1,
                    model.metabolites.adp_c:1,
                    model.metabolites.pi_c:1,
                    model.metabolites.h_c:1},combine=False)
model.add_reaction(rxn)

# %%
rxn = Reaction(id='CU2abcpp',name='Copper (Cu+2) ABC transporter (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0705 or MCA2072 or MCA2264'
rxn.annotation = {'metanetx.reaction':'MNXR19990','biocyc':['META:3.6.3.4-RXN', 'META:TRANS-RXN-178'],'brenda':'3.6.3.4'}
rxn.add_metabolites({model.metabolites.cu2_c:-1,
                    model.metabolites.atp_c:-1,
                    model.metabolites.h2o_c:-1,
                    model.metabolites.cu2_p:1,
                    model.metabolites.adp_c:1,
                    model.metabolites.pi_c:1,
                    model.metabolites.h_c:1},combine=False)
model.add_reaction(rxn)

# %%
rxn = Reaction(id='Kabcpp',name='Potassium ABC transporter (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA2216 and MCA2215 and MCA2217'
rxn.annotation = {'metanetx.reaction':'MNXR2979','biocyc':['META:3.6.3.12-RXN', 'META:TRANS-RXN-2'],'brenda':'3.6.3.12'}
rxn.add_metabolites({model.metabolites.k_p:-1,
                    model.metabolites.atp_c:-1,
                    model.metabolites.h2o_c:-1,
                    model.metabolites.k_c:1,
                    model.metabolites.adp_c:1,
                    model.metabolites.pi_c:1,
                    model.metabolites.h_c:1},combine=False)
model.add_reaction(rxn)

# %%
rxn = Reaction(id='FE2Gabcpp',name='Iron (II) transport via ABC system (GTP) (periplasm)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA1097'
rxn.annotation = {'metanetx.reaction':'MNXR82823'}
rxn.add_metabolites({model.metabolites.fe2_p:-1,
                    model.metabolites.gtp_c:-1,
                    model.metabolites.h2o_c:-1,
                    model.metabolites.fe2_c:1,
                    model.metabolites.gdp_c:1,
                    model.metabolites.pi_c:1,
                    model.metabolites.h_c:1},combine=False)
model.add_reaction(rxn)

# %%
model.reactions.PPA3ipp.gene_reaction_rule = 'MCA1252 or MCA1188'

# %%
rxn = Reaction(id='CAt6pp',name='Calcium / sodium antiporter (1:1)',lower_bound=0,upper_bound=1000)
rxn.gene_reaction_rule = 'MCA0850'
rxn.annotation = {'metanetx.reaction':'MNXR1050'}
rxn.add_metabolites({model.metabolites.na1_p:-1,
                     model.metabolites.ca2_c:-1,
                     model.metabolites.na1_c:1,
                     model.metabolites.ca2_p:1},combine=False)

model.add_reaction(rxn)

# %%
transported_mets = [met for met in model.metabolites if met.compartment == 'p']

# %%
model.solve().f
# Out:
# 0.2602661472910852

# %%
ecoli = load_model('/Users/clie/Downloads/iJO1366.xml')

# %%
for met in transported_mets:
    if met.id[:-1]+'e' in model.metabolites:
        rxn_name = '{} transport via diffusion (extracellular to periplasm)'.format(met.name)
        rxn_id = '{}tex'.format(met.id[:-2].upper())
            
        if rxn_id not in model.reactions:
            rxn = Reaction(id=rxn_id,name=rxn_name,lower_bound=-1000,upper_bound=1000)
            try:
                rxn.annotation = ecoli.reactions.get_by_id(rxn_id).annotation
            except:
                pass
            rxn.add_metabolites({model.metabolites.get_by_id(met.id):1,
                         model.metabolites.get_by_id(met.id[:-1]+'e'):-1},combine=False)

            model.add_reaction(rxn)

    else:
        met_e = model.metabolites.get_by_id(met.id).copy()
        met_e.compartment = 'e'
        met_e.id = met.id[:-1]+'e'
        model.add_metabolite(met_e)
        
        rxn_name = '{} transport via diffusion (extracellular to periplasm)'.format(met.name)
        rxn_id = '{}tex'.format(met.id[:-2].upper())

        if rxn_id not in model.reactions:
            rxn = Reaction(id=rxn_id,name=rxn_name,lower_bound=-1000,upper_bound=1000)
            try:
                rxn.annotation = ecoli.reactions.get_by_id(rxn_id).annotation
            except:
                pass
            rxn.add_metabolites({model.metabolites.get_by_id(met.id):1,
                         model.metabolites.get_by_id(met.id[:-1]+'e'):-1},combine=False)

            model.add_reaction(rxn)

# %%
model.solve().f
# Out:
# 0.2602661472910852

# %%
model.remove_reactions([model.reactions.FICYTCC553tex,
                    model.reactions.FOCYTCC553tex,
                    model.reactions.FICYTCC555tex,
                    model.reactions.FOCYTCC555tex,
                    model.reactions.UDCPPtex,
                    model.reactions.COLIPAtex,
                    model.reactions.ULA4Ntex,
                    model.reactions.ACOLIPAtex,
                    model.reactions.LIPA_COLDtex,
                    model.reactions.ECA4COLIPAtex,
                    model.reactions.ENLIPAtex,
                    model.reactions.O16A4COLIPAtex],remove_orphans=True)

# %%
model.solve().f
# Out:
# 0.26026614729108966

# %%
co2_e = model.metabolites.co2_c.copy()
co2_e.compartment = 'e'
co2_e.id = 'co2_e'
model.add_metabolite(co2_e)

# %%
rxn = Reaction(id='CO2t',name='CO2 transporter via diffusion',lower_bound=-1000,upper_bound=1000)
rxn.annotation = {'metanetx.reaction':'MNXR1225'}
rxn.add_metabolites({model.metabolites.co2_c:-1,
                     model.metabolites.co2_e:1},combine=False)

model.add_reaction(rxn)

# %%
model.solve().f
# Out:
# 0.2602661472910852

# %%
modelc = model.copy()

# %%
model = modelc.copy()

# %%
model.reactions.BIOMASS_Mcapsulatus.change_bounds(0,1000)

# %%
old_exchanges = model.exchanges

# %%
mets_2b_exchanged = [met for met in model.metabolites if met.compartment == 'e'][6:]

# %%
from cameo.util import TimeMachine
with TimeMachine() as tm:
    for rxn in model.exchanges: 
        if rxn.id.startswith('EX_'):
            rxn.change_bounds(0,0, time_machine=tm)
    try:
        model.solve().f
    except Exception as e:
        print(e)
model.solve().f
# Out:
# Solving model BMID000000141026 did not return an optimal solution. The returned solution status is "infeasible"
# 0.26026614729109

# %%
with TimeMachine() as tm:
    for met in mets_2b_exchanged:
        try:
            rxn = model.add_exchange(met,prefix='TEST_',time_machine = tm)
            rxn.change_bounds(-10,10,tm)
            try:
                model.solve().f
                print '{} the last one that passed'.format(met.id)
            except Exception as e:
                print(e)
                print met.id
        except:
            pass
# Out:
# no3_e the last one that passed
# ch4_e the last one that passed
# h2o_e the last one that passed
# o2_e the last one that passed
# meoh_e the last one that passed
# fald_e the last one that passed
# h_e the last one that passed
# na1_e the last one that passed
# fe2_e the last one that passed
# nh4_e the last one that passed
# ham_e the last one that passed
# no_e the last one that passed
# n2o_e the last one that passed
# no2_e the last one that passed
# aso3_e the last one that passed
# cl_e the last one that passed
# mn2_e the last one that passed
# ca2_e the last one that passed
# k_e the last one that passed
# zn2_e the last one that passed
# cd2_e the last one that passed
# cobalt2_e the last one that passed
# ni2_e the last one that passed
# mg2_e the last one that passed
# pi_e the last one that passed
# asp__L_e the last one that passed
# fum_e the last one that passed
# mal__L_e the last one that passed
# orot_e the last one that passed
# succ_e the last one that passed
# pyr_e the last one that passed
# ser__L_e the last one that passed
# thr__L_e the last one that passed
# ade_e the last one that passed
# gua_e the last one that passed
# xan_e the last one that passed
# cu2_e the last one that passed
# glyc_e the last one that passed
# so4_e the last one that passed
# fol_e the last one that passed
# pheme_e the last one that passed
# ptrc_e the last one that passed
# spmd_e the last one that passed
# urea_e the last one that passed
# tsul_e the last one that passed
# co2_e the last one that passed

# %%
with TimeMachine() as tm:
    for met in mets_2b_exchanged:
        try:
            rxn = model.add_exchange(met,prefix='TEST_',time_machine = tm)
            rxn.change_bounds(-100,100,tm)
            try:
                model.solve().f
                print '{} the last one that passed'.format(met.id)
            except Exception as e:
                print(e)
                print met.id
        except:
            pass
# Out:
# no3_e the last one that passed
# ch4_e the last one that passed
# h2o_e the last one that passed
# o2_e the last one that passed
# meoh_e the last one that passed
# fald_e the last one that passed
# h_e the last one that passed
# na1_e the last one that passed
# fe2_e the last one that passed
# nh4_e the last one that passed
# ham_e the last one that passed
# no_e the last one that passed
# n2o_e the last one that passed
# no2_e the last one that passed
# aso3_e the last one that passed
# cl_e the last one that passed
# mn2_e the last one that passed
# ca2_e the last one that passed
# k_e the last one that passed
# zn2_e the last one that passed
# cd2_e the last one that passed
# cobalt2_e the last one that passed
# ni2_e the last one that passed
# mg2_e the last one that passed
# pi_e the last one that passed
# asp__L_e the last one that passed
# fum_e the last one that passed
# mal__L_e the last one that passed
# orot_e the last one that passed
# succ_e the last one that passed
# pyr_e the last one that passed
# ser__L_e the last one that passed
# thr__L_e the last one that passed
# ade_e the last one that passed
# gua_e the last one that passed
# xan_e the last one that passed
# cu2_e the last one that passed
# glyc_e the last one that passed
# so4_e the last one that passed
# fol_e the last one that passed
# pheme_e the last one that passed
# ptrc_e the last one that passed
# spmd_e the last one that passed
# urea_e the last one that passed
# tsul_e the last one that passed
# co2_e the last one that passed

# %%
with TimeMachine() as tm:
    for met in mets_2b_exchanged:
        try:
            rxn = model.add_exchange(met,prefix='TEST_',time_machine = tm)
            rxn.change_bounds(-1000,1000,tm)
            try:
                model.solve().f
                print '{} the last one that passed'.format(met.id)
            except Exception as e:
                print(e)
                print met.id
        except:
            pass
# Out:
# no3_e the last one that passed
# ch4_e the last one that passed
# h2o_e the last one that passed
# o2_e the last one that passed
# meoh_e the last one that passed
# fald_e the last one that passed
# h_e the last one that passed
# na1_e the last one that passed
# fe2_e the last one that passed
# nh4_e the last one that passed
# ham_e the last one that passed
# no_e the last one that passed
# n2o_e the last one that passed
# no2_e the last one that passed
# aso3_e the last one that passed
# cl_e the last one that passed
# mn2_e the last one that passed
# ca2_e the last one that passed
# k_e the last one that passed
# zn2_e the last one that passed
# cd2_e the last one that passed
# cobalt2_e the last one that passed
# ni2_e the last one that passed
# mg2_e the last one that passed
# pi_e the last one that passed
# asp__L_e the last one that passed
# fum_e the last one that passed
# mal__L_e the last one that passed
# orot_e the last one that passed
# succ_e the last one that passed
# pyr_e the last one that passed
# ser__L_e the last one that passed
# thr__L_e the last one that passed
# ade_e the last one that passed
# gua_e the last one that passed
# xan_e the last one that passed
# cu2_e the last one that passed
# glyc_e the last one that passed
# so4_e the last one that passed
# fol_e the last one that passed
# pheme_e the last one that passed
# ptrc_e the last one that passed
# spmd_e the last one that passed
# urea_e the last one that passed
# tsul_e the last one that passed
# co2_e the last one that passed

# %%
for met in mets_2b_exchanged:
    rxn_name = '{} exchange'.format(met.name)
    rxn_id = 'EX_{}'.format(met.id)

    if rxn_id not in model.reactions:
        rxn = Reaction(id=rxn_id,name=rxn_name,lower_bound=-10,upper_bound=10)
        try:
            rxn.annotation = ecoli.reactions.get_by_id(rxn_id).annotation
        except:
            pass
        rxn.add_metabolites({model.metabolites.get_by_id(met.id):-1})

        model.add_reaction(rxn)

# %%
model.solver.optimize()
# Out:
# 'optimal'

# %%
model.solve().f
# Out:
# 4.958578871076368

# %%
model.reactions.EX_ch4_p.change_bounds(0, 0)

# %%
model.reactions.EX_ch4_e.change_bounds(-18.46,0)

# %%
model.solve().f
# Out:
# 4.721410692475985

# %%
with TimeMachine() as tm:
    for rxn in old_exchanges: 
        if rxn.id.startswith('EX_'):
            try:
                rxn.change_bounds(0,0)
                try:
                    model.solve().f
                    print '{} passed'.format(rxn.id)
                except Exception as e:
                    print(e)
                    print rxn.id, 'failed'
            except:
                pass
            rxn.change_bounds(-100,100)
# Out:
# EX_h_c passed
# EX_co2_c passed
# EX_h2o_c passed
# EX_pi_c passed
# EX_o2_c passed
# EX_nh3_c passed
# EX_so4_c passed
# EX_h2o2_c passed
# EX_co_c passed
# EX_cl_c passed
# EX_na1_c passed
# EX_k_c passed
# EX_mg2_c passed
# EX_ca2_c passed
# EX_ch4_p passed
# EX_fe2_p passed
# EX_cobalt2_c passed
# EX_cu_c passed

# %%
model.reactions.CAt6pp.change_bounds(-1000,1000)

# %%
model.reactions.EX_h2o2_c.id = 'DM_h2o2_c'

# %%
co_e = model.metabolites.co_c.copy()
co_e.compartment = 'e'
co_e.id = 'co_e'
model.add_metabolite(co_e)

# %%
rxn = Reaction(id='COt',name='CO transporter via diffusion',lower_bound=-1000,upper_bound=1000)
rxn.annotation = {'metanetx.reaction':'MNXR1256'}
rxn.add_metabolites({model.metabolites.co_c:-1,
                     model.metabolites.co_e:1},combine=False)

model.add_reaction(rxn)

# %%
rxn = Reaction(id='EX_co_e',name='CO exchange',lower_bound=-1000,upper_bound=1000)
rxn.annotation = {'metanetx.reaction':'MNXR1256'}
rxn.add_metabolites({model.metabolites.co_e:-1},combine=False)

model.add_reaction(rxn)

# %%
old_exchanges
# Out:
# [<Reaction EX_h_c at 0x11c079290>,
#  <Reaction EX_co2_c at 0x11c0792d0>,
#  <Reaction EX_h2o_c at 0x11c079310>,
#  <Reaction EX_pi_c at 0x11c079350>,
#  <Reaction EX_o2_c at 0x11c079390>,
#  <Reaction EX_nh3_c at 0x11c0793d0>,
#  <Reaction EX_so4_c at 0x11c079410>,
#  <Reaction DM_h2o2_c at 0x11c079450>,
#  <Reaction EX_co_c at 0x11c079490>,
#  <Reaction EX_cl_c at 0x11c0794d0>,
#  <Reaction DM_rdmbzi_c at 0x11c079510>,
#  <Reaction EX_na1_c at 0x11c079550>,
#  <Reaction EX_k_c at 0x11c079590>,
#  <Reaction EX_mg2_c at 0x11c0795d0>,
#  <Reaction EX_ca2_c at 0x11c079610>,
#  <Reaction EX_ch4_p at 0x11c0797d0>,
#  <Reaction EX_fe2_p at 0x11c079d50>,
#  <Reaction EX_cobalt2_c at 0x11c058550>,
#  <Reaction DM_4hba_c at 0x11c058710>,
#  <Reaction DM_doxopa_c at 0x11c03a090>,
#  <Reaction EX_cu_c at 0x11c03a450>]

# %%
model.solve().f
# Out:
# 4.454751510174534

# %%
model.remove_reactions([rxn for rxn in old_exchanges if rxn.id.startswith('EX_')])

# %%
model.solve().f
# Out:
# 0.5670553609446055

# %%
model.medium
# Out:
#      reaction_id                          reaction_name  lower_bound  \
# 0      DM_h2o2_c             hydrogen peroxide exchange      -100.00
# 1       EX_no3_e                         no3_e exchange       -10.00
# 2       EX_ch4_e                       methane exchange       -18.46
# 3       EX_h2o_e                           H2O exchange       -10.00
# 4        EX_o2_e                      dioxygen exchange       -10.00
# 5      EX_meoh_e                      methanol exchange       -10.00
# 6      EX_fald_e                  formaldehyde exchange       -10.00
# 7         EX_h_e                          H(+) exchange       -10.00
# 8       EX_na1_e                         Na(+) exchange       -10.00
# 9       EX_fe2_e                         fe2_p exchange       -10.00
# 10      EX_nh4_e                      Ammonium exchange       -10.00
# 11      EX_ham_e                 hydroxylamine exchange       -10.00
# 12       EX_no_e                  nitric oxide exchange       -10.00
# 13      EX_n2o_e              dinitrogen oxide exchange       -10.00
# 14      EX_no2_e                       nitrite exchange       -10.00
# 15     EX_aso3_e                      Arsenite exchange       -10.00
# 16       EX_cl_e                         Cl(-) exchange       -10.00
# 17      EX_mn2_e                 Manganese(2+) exchange       -10.00
# 18      EX_ca2_e                        Ca(2+) exchange       -10.00
# 19        EX_k_e                          K(+) exchange       -10.00
# 20      EX_zn2_e                          Zinc exchange       -10.00
# 21      EX_cd2_e                       Cadmium exchange       -10.00
# 22  EX_cobalt2_e                        Co(2+) exchange       -10.00
# 23      EX_ni2_e                        Nickel exchange       -10.00
# 24      EX_mg2_e                        Mg(2+) exchange       -10.00
# 25       EX_pi_e                     phosphate exchange       -10.00
# 26   EX_asp__L_e               L-aspartate(1-) exchange       -10.00
# 27      EX_fum_e                  fumarate(2-) exchange       -10.00
# 28   EX_mal__L_e                    (S)-malate exchange       -10.00
# 29     EX_orot_e                       orotate exchange       -10.00
# 30     EX_succ_e                 succinate(2-) exchange       -10.00
# 31      EX_pyr_e                      pyruvate exchange       -10.00
# 32   EX_ser__L_e                      L-serine exchange       -10.00
# 33   EX_thr__L_e        L-threonine zwitterion exchange       -10.00
# 34      EX_ade_e                       adenine exchange       -10.00
# 35      EX_gua_e                       guanine exchange       -10.00
# 36      EX_xan_e                   9H-xanthine exchange       -10.00
# 37      EX_cu2_e                          Cu2+ exchange       -10.00
# 38     EX_glyc_e                      Glycerol exchange       -10.00
# 39      EX_so4_e                       sulfate exchange       -10.00
# 40      EX_fol_e                        folate exchange       -10.00
# 41    EX_pheme_e                        heme b exchange       -10.00
# 42     EX_ptrc_e                    putrescine exchange       -10.00
# 43     EX_spmd_e                spermidine(3+) exchange       -10.00
# 44     EX_urea_e                        urea_c exchange       -10.00
# 45     EX_tsul_e  trioxidosulfanidosulfate(1-) exchange       -10.00
# 46      EX_co2_e                         CO(2) exchange       -10.00
# 47       EX_co_e                            CO exchange     -1000.00
#
#     upper_bound
# 0           100
# 1            10
# 2             0
# 3            10
# 4            10
# 5            10
# 6            10
# 7            10
# 8            10
# 9            10
# 10           10
# 11           10
# 12           10
# 13           10
# 14           10
# 15           10
# 16           10
# 17           10
# 18           10
# 19           10
# 20           10
# 21           10
# 22           10
# 23           10
# 24           10
# 25           10
# 26           10
# 27           10
# 28           10
# 29           10
# 30           10
# 31           10
# 32           10
# 33           10
# 34           10
# 35           10
# 36           10
# 37           10
# 38           10
# 39           10
# 40           10
# 41           10
# 42           10
# 43           10
# 44           10
# 45           10
# 46           10
# 47         1000

# %% [markdown]
# Default carbon source should be Methane:

# %%
model.solve().f
# Out:
# 0.5670553609446055

# %%
potential_c_sources = [model.reactions.EX_glyc_e,
model.reactions.EX_asp__L_e,
model.reactions.EX_fum_e,
model.reactions.EX_glyc_e,
model.reactions.EX_mal__L_e,
model.reactions.EX_fald_e,
model.reactions.EX_meoh_e,
model.reactions.EX_orot_e,
model.reactions.EX_ptrc_e,
model.reactions.EX_ser__L_e,
model.reactions.EX_spmd_e,
model.reactions.EX_succ_e,
model.reactions.EX_pyr_e]

# %%
modeld = model.copy()

# %%
with TimeMachine() as tm:
    for rxn in potential_c_sources: 
        if rxn.id.startswith('EX_'):
            try:
                rxn.change_bounds(0,0)
                try:
                    model.solve().f
                    print '{} passed'.format(rxn.id)
                except Exception as e:
                    print(e)
                    print rxn.id, 'failed'
            except:
                pass
            rxn.change_bounds(-100,100)
# Out:
# EX_glyc_e passed
# EX_asp__L_e passed
# EX_fum_e passed
# EX_glyc_e passed
# EX_mal__L_e passed
# EX_fald_e passed
# EX_meoh_e passed
# EX_orot_e passed
# EX_ptrc_e passed
# EX_ser__L_e passed
# EX_spmd_e passed
# EX_succ_e passed
# EX_pyr_e passed

# %%
model.reactions.EX_glyc_e.change_bounds(0,0)
model.reactions.EX_asp__L_e.change_bounds(0,0)
model.reactions.EX_fum_e.change_bounds(0,0)
model.reactions.EX_glyc_e.change_bounds(0,0)
model.reactions.EX_mal__L_e.change_bounds(0,0)
model.reactions.EX_fald_e.change_bounds(0,0)
model.reactions.EX_meoh_e.change_bounds(0,0)
model.reactions.EX_orot_e.change_bounds(0,0)
model.reactions.EX_ptrc_e.change_bounds(0,0)
model.reactions.EX_ser__L_e.change_bounds(0,0)
model.reactions.EX_spmd_e.change_bounds(0,0)
model.reactions.EX_succ_e.change_bounds(0,0)
model.reactions.EX_pyr_e.change_bounds(0,0)
model.reactions.EX_ch4_e.change_bounds(-18.46,0)

# %%
model.solve().f
# Out:
# 0.09341587109467335

# %% [markdown]
# Carbon limited growth:

# %%
model.reactions.EX_o2_e.change_bounds(-100,10)

# %%
model.solve().f
# Out:
# 0.12115935099416131

# %% [markdown]
# Nitrogen source should be Ammonia:

# %%
model.reactions.EX_nh4_e.change_bounds(-100,100)

# %%
model.reactions.EX_ade_e.change_bounds(0,100)
model.reactions.EX_xan_e.change_bounds(0,100)
model.reactions.EX_gua_e.change_bounds(0,100)
model.reactions.EX_ham_e.change_bounds(0,100)
model.reactions.EX_no2_e.change_bounds(0,100)
model.reactions.EX_urea_e.change_bounds(0,100)

# %%
model.solve().f
# Out:
# 0.0782435590192313

# %%
for rxn in [rxn for rxn in model.reactions if abs(rxn.flux) > 0 and rxn.id.startswith('EX')]:
    print rxn.id, rxn.flux
# Out:
# EX_ch4_e -5.54961193239
# EX_h2o_e 10.0
# EX_o2_e -8.37583144096
# EX_h_e 0.641260644371
# EX_na1_e -0.00306306711195
# EX_fe2_e -0.000478850581198
# EX_nh4_e -0.641167477378
# EX_cl_e -0.0167743596359
# EX_ca2_e -0.00546639001129
# EX_k_e -0.0138082871519
# EX_cobalt2_e -4.51387091982e-06
# EX_mg2_e -0.00965771124829
# EX_pi_e -0.0431396590346
# EX_cu2_e -0.000118204109482
# EX_so4_e -0.0132066246981
# EX_co2_e 2.91581019169
# EX_co_e 2.2416779659e-06

# %%
for rxn in [rxn for rxn in model.reactions if abs(rxn.flux) > 0 and rxn.id.startswith('DM_')]:
    print rxn.id, rxn.flux
# Out:
# DM_h2o2_c 0.0251355958912
# DM_rdmbzi_c 8.33051348522e-05
# DM_4hba_c 2.2416779659e-06
# DM_doxopa_c 8.33051348522e-05

# %%
model.solve().f
# Out:
# 0.0782435590192313

# %%
for met in [model.metabolites.ni2_c,model.metabolites.mn2_c,model.metabolites.zn2_c]: 
    with TimeMachine() as tm:
        rxn = model.add_demand(met,prefix='TEST_',time_machine=tm)
        try:
            model.change_objective(rxn,time_machine=tm)
            model.solve().f
            print '{} passed'.format(rxn.id)
        except Exception as e:
            print(e)
            print rxn.id, 'failed'
# Out:
# TEST_ni2_c passed
# TEST_mn2_c passed
# TEST_zn2_c passed

# %%
model.reactions.BIOMASS_Mcapsulatus.add_metabolites({model.metabolites.mn2_c: -0.000018
                                                     ,model.metabolites.zn2_c: -0.001
                                                     ,model.metabolites.ni2_c: -0.000034
                                                    },combine=False)

# %%
model.solve().f
# Out:
# 0.0782435590195188

# %%
model.reactions.BIOMASS_Mcapsulatus.lower_bound = 0
model.reactions.BIOMASS_Mcapsulatus.upper_bound = 1000
model.reactions.EX_ch4_e.lower_bound = -1000
model.reactions.EX_o2_e.lower_bound = -1000
model.reactions.EX_nh4_e.lower_bound = -1000

# %%
for rxn in model.reactions:
    if rxn.lower_bound < 0 and abs(rxn.lower_bound) != 1000:
        print rxn.id, rxn.lower_bound, rxn.upper_bound
        rxn.lower_bound = -1000
# Out:
# DM_h2o2_c -100 100
# EX_no3_e -10 10
# EX_h2o_e -10 10
# EX_h_e -10 10
# EX_na1_e -10 10
# EX_fe2_e -10 10
# EX_no_e -10 10
# EX_n2o_e -10 10
# EX_aso3_e -10 10
# EX_cl_e -10 10
# EX_mn2_e -10 10
# EX_ca2_e -10 10
# EX_k_e -10 10
# EX_zn2_e -10 10
# EX_cd2_e -10 10
# EX_cobalt2_e -10 10
# EX_ni2_e -10 10
# EX_mg2_e -10 10
# EX_pi_e -10 10
# EX_thr__L_e -10 10
# EX_cu2_e -10 10
# EX_so4_e -10 10
# EX_fol_e -10 10
# EX_pheme_e -10 10
# EX_tsul_e -10 10
# EX_co2_e -10 10

# %%
for rxn in model.reactions:
    if rxn.upper_bound > 0 and abs(rxn.upper_bound) != 1000:
        print rxn.id, rxn.lower_bound, rxn.upper_bound
        rxn.upper_bound = 1000
# Out:
# ATPM 8.39 8.39
# DM_h2o2_c -1000 100
# EX_no3_e -1000 10
# EX_h2o_e -1000 10
# EX_o2_e -1000 10
# EX_h_e -1000 10
# EX_na1_e -1000 10
# EX_fe2_e -1000 10
# EX_nh4_e -1000 100
# EX_ham_e 0 100
# EX_no_e -1000 10
# EX_n2o_e -1000 10
# EX_no2_e 0 100
# EX_aso3_e -1000 10
# EX_cl_e -1000 10
# EX_mn2_e -1000 10
# EX_ca2_e -1000 10
# EX_k_e -1000 10
# EX_zn2_e -1000 10
# EX_cd2_e -1000 10
# EX_cobalt2_e -1000 10
# EX_ni2_e -1000 10
# EX_mg2_e -1000 10
# EX_pi_e -1000 10
# EX_thr__L_e -1000 10
# EX_ade_e 0 100
# EX_gua_e 0 100
# EX_xan_e 0 100
# EX_cu2_e -1000 10
# EX_so4_e -1000 10
# EX_fol_e -1000 10
# EX_pheme_e -1000 10
# EX_urea_e 0 100
# EX_tsul_e -1000 10
# EX_co2_e -1000 10

# %%
model.reactions.ATPM.upper_bound = 8.39
model.reactions.DM_h2o2_c.lower_bound = 0
model.reactions.EX_n2o_e.lower_bound = 0
model.reactions.EX_aso3_e.lower_bound = 0
model.reactions.EX_thr__L_e.lower_bound = 0
model.reactions.EX_fol_e.lower_bound = 0
model.reactions.EX_pheme_e.lower_bound = 0
model.reactions.EX_tsul_e.lower_bound = 0
model.reactions.EX_co2_e.lower_bound = 0
model.reactions.EX_no_e.lower_bound = 0

# %%
model.solve().f
# Out:
# 7.04946219416958

# %%
model.reactions.EX_asp__L_e.upper_bound = 1000
model.reactions.EX_fum_e.upper_bound = 1000
model.reactions.EX_mal__L_e.upper_bound = 1000
model.reactions.EX_orot_e.upper_bound = 1000
model.reactions.EX_succ_e.upper_bound = 1000
model.reactions.EX_pyr_e.upper_bound = 1000
model.reactions.EX_ser__L_e.upper_bound = 1000
model.reactions.EX_ptrc_e.upper_bound = 1000
model.reactions.EX_spmd_e.upper_bound = 1000
model.reactions.EX_glyc_e.upper_bound = 1000
model.reactions.EX_meoh_e.upper_bound = 1000
model.reactions.EX_fald_e.upper_bound = 1000

# %%
for rxn in model.exchanges:
    print rxn.id, rxn.lower_bound, rxn.upper_bound
# Out:
# DM_h2o2_c 0 1000
# DM_rdmbzi_c 0.0 1000.0
# DM_4hba_c 0.0 1000.0
# DM_doxopa_c 0.0 1000.0
# EX_no3_e -1000 1000
# EX_ch4_e -1000 0
# EX_h2o_e -1000 1000
# EX_o2_e -1000 1000
# EX_meoh_e 0 1000
# EX_fald_e 0 1000
# EX_h_e -1000 1000
# EX_na1_e -1000 1000
# EX_fe2_e -1000 1000
# EX_nh4_e -1000 1000
# EX_ham_e 0 1000
# EX_no_e 0 1000
# EX_n2o_e 0 1000
# EX_no2_e 0 1000
# EX_aso3_e 0 1000
# EX_cl_e -1000 1000
# EX_mn2_e -1000 1000
# EX_ca2_e -1000 1000
# EX_k_e -1000 1000
# EX_zn2_e -1000 1000
# EX_cd2_e -1000 1000
# EX_cobalt2_e -1000 1000
# EX_ni2_e -1000 1000
# EX_mg2_e -1000 1000
# EX_pi_e -1000 1000
# EX_asp__L_e 0 1000
# EX_fum_e 0 1000
# EX_mal__L_e 0 1000
# EX_orot_e 0 1000
# EX_succ_e 0 1000
# EX_pyr_e 0 1000
# EX_ser__L_e 0 1000
# EX_thr__L_e 0 1000
# EX_ade_e 0 1000
# EX_gua_e 0 1000
# EX_xan_e 0 1000
# EX_cu2_e -1000 1000
# EX_glyc_e 0 1000
# EX_so4_e -1000 1000
# EX_fol_e 0 1000
# EX_pheme_e 0 1000
# EX_ptrc_e 0 1000
# EX_spmd_e 0 1000
# EX_urea_e 0 1000
# EX_tsul_e 0 1000
# EX_co2_e 0 1000
# EX_co_e -1000 1000

# %%
model.reactions.EX_ch4_e.lower_bound = -18.46

# %%
model.solve().f
# Out:
# 0.26026614420880523

# %%
import cobra

target_filename_json = relative_directory + '/Reconstructions/MethylococcusModel13.json'
target_filename_xml = relative_directory + '/Reconstructions/MethylococcusModel13.xml'
cobra.io.write_sbml_model(model, target_filename_xml, use_fbc_package=True)
cobra.io.save_json_model(model, target_filename_json,pretty = True)
